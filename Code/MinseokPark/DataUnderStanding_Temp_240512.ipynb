# %%
# 기본 패키지 불러오기 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
plt.style.use("seaborn")
sns.set(font_scale=1)
sns.set_style("whitegrid")

# %%
newyork_lists = pd.read_csv('./Data/Newyork/listings.csv')
newyork_lists_summary = pd.read_csv('./Data/Newyork/listings_summary.csv')
newyork_neighbourhoods = pd.read_csv('./Data/Newyork/neighbourhoods.csv')
newyork_reviews = pd.read_csv('./Data/Newyork/reviews.csv')
newyork_reviews_summary = pd.read_csv('./Data/Newyork/reviews_summary.csv')

# %%
newyork_lists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38377 entries, 0 to 38376
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            38377 non-null  int64
#  1   listing_url                                   38377 non-null  object
#  2   scrape_id                                     38377 non-null  int64
#  3   last_scraped                                  38377 non-null  object
#  4   source                                        38377 non-null  object
#  5   name                                          38375 non-null  object
#  6   description                                   37339 non-null  object
#  7   neighborhood_overview                         21705 non-null  object
#  8   picture_url                                   38377 non-null  object
# ...

# %%
newyork_lists
# Out:
#                        id                                      listing_url  \
# 0                30314819            https://www.airbnb.com/rooms/30314819
# 1                30391955            https://www.airbnb.com/rooms/30391955
# 2                30378211            https://www.airbnb.com/rooms/30378211
# 3                30459160            https://www.airbnb.com/rooms/30459160
# 4                30746536            https://www.airbnb.com/rooms/30746536
# ...                   ...                                              ...
# 38372            27015594            https://www.airbnb.com/rooms/27015594
# 38373              276021              https://www.airbnb.com/rooms/276021
# 38374  729637842867055103  https://www.airbnb.com/rooms/729637842867055103
# 38375             1327940             https://www.airbnb.com/rooms/1327940
# 38376            51100458            https://www.airbnb.com/rooms/51100458
#
#             scrape_id last_scraped           source  \
# ...

# %%
newyork_lists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38377 entries, 0 to 38376
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            38377 non-null  int64
#  1   listing_url                                   38377 non-null  object
#  2   scrape_id                                     38377 non-null  int64
#  3   last_scraped                                  38377 non-null  object
#  4   source                                        38377 non-null  object
#  5   name                                          38375 non-null  object
#  6   description                                   37339 non-null  object
#  7   neighborhood_overview                         21705 non-null  object
#  8   picture_url                                   38377 non-null  object
# ...

# %%
newyork_lists.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
newyork_reviews.head(30)
# Out:
#     listing_id       id        date  reviewer_id reviewer_name  \
# 0         5121     3271  2009-05-28         2995         Misha
# 1         5121     5018  2009-07-04        23868      Yevgeniy
# 2         5121    15342  2009-10-27        39813        Gisela
# 3         5121    17869  2009-11-21        52256          Shri
# 4         5121    20382  2009-12-14        62040       Kristen
# 5         5121    21588  2009-12-28        53299        Dorine
# 6         5121    25622  2010-02-07        68126          Anne
# 7         5121    27570  2010-02-25        81438          Sean
# 8         5121    31806  2010-03-28        83361     Franziska
# 9         5121    52894  2010-06-14        93061         James
# 10        5121    66432  2010-07-19       138152       Maartje
# 11        5121    69098  2010-07-25       146471     Charlotte
# 12        5121    69984  2010-07-27       175725         Emily
# 13        5121    72313  2010-08-01       178070         Erica
# ...

# %%
newyork_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 