# %%
# 기본 패키지 불러오기 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
plt.style.use("seaborn")
sns.set(font_scale=1)
sns.set_style("whitegrid")

# %% [markdown]
# ### 캐글 데이터_Airbnb Listing Data 2023

# %%
# airbnb_desert = pd.read_csv('../../Data/KaggleData/Airbnb Listing Data 2023/airnb_desert.csv', encoding='cp949')
# airbnb_luxe = pd.read_csv('../../Data/KaggleData/Airbnb Listing Data 2023/airnb_luxe.csv', encoding='cp949')
airbnb = pd.read_csv('../../Data/KaggleData/Airbnb Listing Data 2023/airnb.csv')

# %%
airbnb
# Out:
#                                    Title  \
# 0    Chalet in Skykomish, Washington, US
# 1         Cabin in Hancock, New York, US
# 2     Cabin in West Farmington, Ohio, US
# 3        Home in Blue Ridge, Georgia, US
# 4      Treehouse in Grandview, Texas, US
# ..                                   ...
# 948            Guest suite in Lake Worth
# 949                    Room in Kissimmee
# 950            Guesthouse in San Antonio
# 951               Apartment in Englewood
# 952                   Room in Long Beach
#
#                                                 Detail         Date  \
# 0                             Sky Haus - A-Frame Cabin  Jun 11 - 16
# 1      The Catskill A-Frame - Mid-Century Modern Cabin   Jun 6 - 11
# 2    The Triangle: A-Frame Cabin for your city retreat   Jul 9 - 14
# 3    *Summer Sizzle* 5 Min to Blue Ridge* Pets* Hot...  Jun 11 - 16
# 4    Luxury Treehouse Couples Getaway w/ Peaceful V...    Jun 4 - 9
# ...

# %% [markdown]
# ### Inside airbnb 데이터

# %%
newyork_lists = pd.read_csv('../../../../data_weekly/inside_airbnb/Newyork/listings.csv')
newyork_lists_summary = pd.read_csv('../../../../data_weekly/inside_airbnb/Newyork/listings_summary.csv')
newyork_neighbourhoods = pd.read_csv('../../../../data_weekly/inside_airbnb/Newyork/neighbourhoods.csv')
newyork_reviews = pd.read_csv('../../../../data_weekly/inside_airbnb/Newyork/reviews.csv')
newyork_reviews_summary = pd.read_csv('../../../../data_weekly/inside_airbnb/Newyork/reviews_summary.csv')

# %%
newyork_lists
# Out:
#                        id                                      listing_url  \
# 0                30314819            https://www.airbnb.com/rooms/30314819
# 1                30391955            https://www.airbnb.com/rooms/30391955
# 2                30378211            https://www.airbnb.com/rooms/30378211
# 3                30459160            https://www.airbnb.com/rooms/30459160
# 4                30746536            https://www.airbnb.com/rooms/30746536
# ...                   ...                                              ...
# 38372            27015594            https://www.airbnb.com/rooms/27015594
# 38373              276021              https://www.airbnb.com/rooms/276021
# 38374  729637842867055103  https://www.airbnb.com/rooms/729637842867055103
# 38375             1327940             https://www.airbnb.com/rooms/1327940
# 38376            51100458            https://www.airbnb.com/rooms/51100458
#
#             scrape_id last_scraped           source  \
# ...

# %%
newyork_lists.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
newyork_reviews
# Out:
#                  listing_id                   id        date  reviewer_id  \
# 0                      5121                 3271  2009-05-28         2995
# 1                      5121                 5018  2009-07-04        23868
# 2                      5121                15342  2009-10-27        39813
# 3                      5121                17869  2009-11-21        52256
# 4                      5121                20382  2009-12-14        62040
# ...                     ...                  ...         ...          ...
# 972067  1118148174507368445  1123236488806829825  2024-03-29    568065473
# 972068  1118148174507368445  1127561944746351439  2024-04-04    146345378
# 972069  1120267212254262726  1122496336265942511  2024-03-28    133302822
# 972070  1120267212254262726  1124680436286753276  2024-03-31     75814820
# 972071  1126177454614590742  1128341794862859003  2024-04-05    570639200
#
#        reviewer_name                                           comments
# ...

# %%
newyork_reviews['comments'][:30]
# Out:
# 0                         Simple place, super nice guy.
# 1     Great guy with a basic room. Clean sheets and ...
# 2     Garon gave me the opportunity to share some of...
# 3     garon is a sweet person with a lot of knowledg...
# 4     Garon - your home was very cozy and comfortabl...
# 5     We had a lovely stay at Garon's although he wa...
# 6     was my first time with airbnb, I enjoy the sta...
# 7     Garon is a really great guy. I can't recommend...
# 8     I can definately recommend Garon's place. he's...
# 9     Where do I start with Garon?  We stayed with h...
# 10    Garon is a very warm and friendly guy, willing...
# 11    Garon was very open and helpful, we felt very ...
# 12    Garon was like an angel! He got back to us qui...
# 13    We had a great time here!  Garon was extremely...
# 14    Many thanks to Garon for a wonderful stay. He ...
# 15    WELLL... Firstly Garon is a gemmm... Full of s...
# 16    Wonderfully, nice guy and a great host! This i...
# ...
