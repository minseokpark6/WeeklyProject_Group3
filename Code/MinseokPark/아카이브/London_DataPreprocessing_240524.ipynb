# %%
# 기본 패키지 불러오기 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
plt.style.use("seaborn")
sns.set(font_scale=1)
sns.set_style("whitegrid")

# 그래프를 노트북 안에 그리기 위해 설정
# %matplotlib inline

# 맥 OS 폰트 깨짐 방지 코드
from matplotlib import rc
import matplotlib as mpl 
import matplotlib.font_manager as fm 

rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## Inside Airbnb: London Data

# %% [markdown]
# ### 데이터 불러오기

# %%
# 데이터 불러오기
london_lists_raw = pd.read_csv('../../../../data_weekly/inside_airbnb/London/listings.csv')
london_lists_summary_raw = pd.read_csv('../../../../data_weekly/inside_airbnb/London/listings_outline.csv')
london_neighbourhoods_raw = pd.read_csv('../../../../data_weekly/inside_airbnb/London/neighbourhoods.csv')
london_reviews_raw = pd.read_csv('../../../../data_weekly/inside_airbnb/London/reviews.csv')
london_reviews_summary_raw = pd.read_csv('../../../../data_weekly/inside_airbnb/London/reviews_outline.csv')

# 분석할 df 별도 복사
london_lists = london_lists_raw.copy()
london_reviews = london_reviews_raw.copy()

# 불러온 df 확인
london_lists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90852 entries, 0 to 90851
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            90852 non-null  int64
#  1   listing_url                                   90852 non-null  object
#  2   scrape_id                                     90852 non-null  int64
#  3   last_scraped                                  90852 non-null  object
#  4   source                                        90852 non-null  object
#  5   name                                          90852 non-null  object
#  6   description                                   87851 non-null  object
#  7   neighborhood_overview                         47521 non-null  object
#  8   picture_url                                   90842 non-null  object
#  9   host_id                                       90852 non-null  int64
#  10  host_url                                      90852 non-null  object
#  11  host_name                                     90847 non-null  object
#  12  host_since                                    90847 non-null  object
#  13  host_location                                 70566 non-null  object
#  14  host_about                                    46814 non-null  object
#  15  host_response_time                            57797 non-null  object
#  16  host_response_rate                            57797 non-null  object
#  17  host_acceptance_rate                          65213 non-null  object
#  18  host_is_superhost                             90463 non-null  object
#  19  host_thumbnail_url                            90847 non-null  object
#  20  host_picture_url                              90847 non-null  object
#  21  host_neighbourhood                            46955 non-null  object
#  22  host_listings_count                           90847 non-null  float64
#  23  host_total_listings_count                     90847 non-null  float64
#  24  host_verifications                            90852 non-null  object
#  25  host_has_profile_pic                          90847 non-null  object
#  26  host_identity_verified                        90847 non-null  object
#  27  neighbourhood                                 47522 non-null  object
#  28  neighbourhood_cleansed                        90852 non-null  object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      90852 non-null  float64
#  31  longitude                                     90852 non-null  float64
#  32  property_type                                 90852 non-null  object
#  33  room_type                                     90852 non-null  object
#  34  accommodates                                  90852 non-null  int64
#  35  bathrooms                                     57894 non-null  float64
#  36  bathrooms_text                                90722 non-null  object
#  37  bedrooms                                      78118 non-null  float64
#  38  beds                                          57837 non-null  float64
#  39  amenities                                     90852 non-null  object
#  40  price                                         57885 non-null  object
#  41  minimum_nights                                90852 non-null  int64
#  42  maximum_nights                                90852 non-null  int64
#  43  minimum_minimum_nights                        90851 non-null  float64
#  44  maximum_minimum_nights                        90851 non-null  float64
#  45  minimum_maximum_nights                        90851 non-null  float64
#  46  maximum_maximum_nights                        90851 non-null  float64
#  47  minimum_nights_avg_ntm                        90851 non-null  float64
#  48  maximum_nights_avg_ntm                        90851 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              86773 non-null  object
#  51  availability_30                               90852 non-null  int64
#  52  availability_60                               90852 non-null  int64
#  53  availability_90                               90852 non-null  int64
#  54  availability_365                              90852 non-null  int64
#  55  calendar_last_scraped                         90852 non-null  object
#  56  number_of_reviews                             90852 non-null  int64
#  57  number_of_reviews_ltm                         90852 non-null  int64
#  58  number_of_reviews_l30d                        90852 non-null  int64
#  59  first_review                                  65869 non-null  object
#  60  last_review                                   65869 non-null  object
#  61  review_scores_rating                          65869 non-null  float64
#  62  review_scores_accuracy                        65838 non-null  float64
#  63  review_scores_cleanliness                     65843 non-null  float64
#  64  review_scores_checkin                         65808 non-null  float64
#  65  review_scores_communication                   65833 non-null  float64
#  66  review_scores_location                        65808 non-null  float64
#  67  review_scores_value                           65806 non-null  float64
#  68  license                                       0 non-null      float64
#  69  instant_bookable                              90852 non-null  object
#  70  calculated_host_listings_count                90852 non-null  int64
#  71  calculated_host_listings_count_entire_homes   90852 non-null  int64
#  72  calculated_host_listings_count_private_rooms  90852 non-null  int64
#  73  calculated_host_listings_count_shared_rooms   90852 non-null  int64
#  74  reviews_per_month                             65869 non-null  float64
# dtypes: float64(24), int64(17), object(34)
# memory usage: 52.0+ MB

# %% [markdown]
# ### 분석에서 사용하지 않을 컬럼 삭제

# %%
# 1차 선별한 컬럼 리스트 
# 1차 선별한 컬럼 27개 + 검증만 하고 삭제하기로 합의한 컬럼 3개('host_has_profile_pic','host_identity_verified', 'has_availability')
# 총 30개 컬럼 선별 

columns_selected = ['id', 'host_id', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'host_total_listings_count', 'host_has_profile_pic', 'host_identity_verified', 'neighbourhood_cleansed', \
    'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'amenities', 'price', 'minimum_nights', 'maximum_nights', 'has_availability', 'number_of_reviews', 'number_of_reviews_l30d', 'review_scores_rating', 'review_scores_accuracy', \
    'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'reviews_per_month']

# 선별한 컬럼만 적용
london_lists = london_lists[columns_selected]

# url도 포함한 df (실제 에어비앤비 사이트 들어가서 확인할 용도)
columns_selected_url = ['id', 'listing_url', 'host_id', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'host_total_listings_count', 'host_has_profile_pic', 'host_identity_verified', 'neighbourhood_cleansed', \
    'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'amenities', 'price', 'minimum_nights', 'maximum_nights', 'has_availability', 'number_of_reviews', 'number_of_reviews_l30d', 'review_scores_rating', 'review_scores_accuracy', \
    'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'reviews_per_month']

london_url = london_lists_raw[columns_selected_url]

# 변수 정리 
london_lists = london_lists.rename(columns={
    'id': '숙소_id',
    'host_id': '호스트_id',
    'host_response_time': '답변_평균시간',
    'host_response_rate': '문의_응답률',
    'host_acceptance_rate': '예약_수락률',
    'host_is_superhost': '슈퍼호스트',
    'host_total_listings_count': '숙소_수',
    'host_has_profile_pic' : '프로필_사진',
    'host_identity_verified' : '호스트_신원',
    'neighbourhood_cleansed': '숙소_지역',
    'room_type': '숙소_유형',
    'accommodates': '수용_인원수',
    'bathrooms': '욕실수',
    'bedrooms': '침실수',
    'beds': '침대수',
    'amenities': '편의시설',
    'price': '숙소_가격',
    'minimum_nights': '최소_숙박일',
    'maximum_nights': '최대_숙박일',
    'has_availability' : '예약_가능여부',
    'number_of_reviews': '리뷰수',
    'number_of_reviews_l30d': '30일_리뷰수',
    'review_scores_rating': '리뷰점수',
    'review_scores_accuracy': '숙소_정확성_리뷰점수',
    'review_scores_cleanliness': '숙소_청결도_리뷰점수',
    'review_scores_checkin': '숙소_체크인_리뷰점수',
    'review_scores_communication': '숙소_소통_리뷰점수',
    'review_scores_location': '숙소_위치_리뷰점수',
    'review_scores_value': '숙소_가격_리뷰점수',
    'reviews_per_month': '평균_리뷰수'
})

# url 포함 df 변수 정리 
london_url = london_url.rename(columns={
    'id': '숙소_id',
    'listing_url' : '숙소_url',
    'host_id': '호스트_id',
    'host_response_time': '답변_평균시간',
    'host_response_rate': '문의_응답률',
    'host_acceptance_rate': '예약_수락률',
    'host_is_superhost': '슈퍼호스트',
    'host_total_listings_count': '숙소_수',
    'host_has_profile_pic' : '프로필_사진',
    'host_identity_verified' : '호스트_신원',
    'neighbourhood_cleansed': '숙소_지역',
    'room_type': '숙소_유형',
    'accommodates': '수용_인원수',
    'bathrooms': '욕실수',
    'bedrooms': '침실수',
    'beds': '침대수',
    'amenities': '편의시설',
    'price': '숙소_가격',
    'minimum_nights': '최소_숙박일',
    'maximum_nights': '최대_숙박일',
    'has_availability' : '예약_가능여부',
    'number_of_reviews': '리뷰수',
    'number_of_reviews_l30d': '30일_리뷰수',
    'review_scores_rating': '리뷰점수',
    'review_scores_accuracy': '숙소_정확성_리뷰점수',
    'review_scores_cleanliness': '숙소_청결도_리뷰점수',
    'review_scores_checkin': '숙소_체크인_리뷰점수',
    'review_scores_communication': '숙소_소통_리뷰점수',
    'review_scores_location': '숙소_위치_리뷰점수',
    'review_scores_value': '숙소_가격_리뷰점수',
    'reviews_per_month': '평균_리뷰수'
})


# 컬럼명 확인
london_lists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90852 entries, 0 to 90851
# Data columns (total 30 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   숙소_id        90852 non-null  int64
#  1   호스트_id       90852 non-null  int64
#  2   답변_평균시간      57797 non-null  object
#  3   문의_응답률       57797 non-null  object
#  4   예약_수락률       65213 non-null  object
#  5   슈퍼호스트        90463 non-null  object
#  6   숙소_수         90847 non-null  float64
#  7   프로필_사진       90847 non-null  object
#  8   호스트_신원       90847 non-null  object
#  9   숙소_지역        90852 non-null  object
#  10  숙소_유형        90852 non-null  object
#  11  수용_인원수       90852 non-null  int64
#  12  욕실수          57894 non-null  float64
#  13  침실수          78118 non-null  float64
#  14  침대수          57837 non-null  float64
#  15  편의시설         90852 non-null  object
#  16  숙소_가격        57885 non-null  object
#  17  최소_숙박일       90852 non-null  int64
#  18  최대_숙박일       90852 non-null  int64
#  19  예약_가능여부      86773 non-null  object
#  20  리뷰수          90852 non-null  int64
#  21  30일_리뷰수      90852 non-null  int64
#  22  리뷰점수         65869 non-null  float64
#  23  숙소_정확성_리뷰점수  65838 non-null  float64
#  24  숙소_청결도_리뷰점수  65843 non-null  float64
#  25  숙소_체크인_리뷰점수  65808 non-null  float64
#  26  숙소_소통_리뷰점수   65833 non-null  float64
#  27  숙소_위치_리뷰점수   65808 non-null  float64
#  28  숙소_가격_리뷰점수   65806 non-null  float64
#  29  평균_리뷰수       65869 non-null  float64
# dtypes: float64(12), int64(7), object(11)
# memory usage: 20.8+ MB

# %% [markdown]
# ### 결측치 처리에 앞서서 리뷰가 0인 컬럼 제거

# %%
# 리뷰수가 0인 컬럼 조건 
condition_review_0 = london_lists['리뷰수'] == 0

# 별도의 DF로 저장
london_lists_review_0 = london_lists[condition_review_0]

# %% [markdown]
# 리뷰가 0인 데이터의 특징 파악

# %%
# 리뷰수가 0인 컬럼의 특징 파악_리뷰데이터 관련

# 개수: 24,983개
print('리뷰가 0개인 런던 내 숙소 개수: ')
print(london_lists_review_0.shape)
print()

# 리뷰가 0개인데 각 리뷰점수가 Null값이 아닌 숙소 개수 

score_type = ['리뷰점수', '숙소_정확성_리뷰점수', '숙소_청결도_리뷰점수', '숙소_체크인_리뷰점수', '숙소_소통_리뷰점수', '숙소_위치_리뷰점수', '숙소_가격_리뷰점수', '평균_리뷰수']

for type in score_type:
    print(f'{type} :')
    print(f'{type}가 null이 아닌 데이터의 개수 >> {london_lists_review_0[type].notnull().sum()}개')
    print()
# Out:
# 리뷰가 0개인 런던 내 숙소 개수:
# (24983, 30)
#
# 리뷰점수 :
# 리뷰점수가 null이 아닌 데이터의 개수 >> 0개
#
# 숙소_정확성_리뷰점수 :
# 숙소_정확성_리뷰점수가 null이 아닌 데이터의 개수 >> 0개
#
# 숙소_청결도_리뷰점수 :
# 숙소_청결도_리뷰점수가 null이 아닌 데이터의 개수 >> 0개
#
# 숙소_체크인_리뷰점수 :
# 숙소_체크인_리뷰점수가 null이 아닌 데이터의 개수 >> 0개
#
# 숙소_소통_리뷰점수 :
# 숙소_소통_리뷰점수가 null이 아닌 데이터의 개수 >> 0개
#
# 숙소_위치_리뷰점수 :
# 숙소_위치_리뷰점수가 null이 아닌 데이터의 개수 >> 0개
#
# 숙소_가격_리뷰점수 :
# 숙소_가격_리뷰점수가 null이 아닌 데이터의 개수 >> 0개
#
# 평균_리뷰수 :
# 평균_리뷰수가 null이 아닌 데이터의 개수 >> 0개

# %%
# # 리뷰수가 0인 컬럼의 특징 파악_슈퍼호스트 관련

print(london_lists_review_0['슈퍼호스트'].unique())
print()
print('리뷰슈가 0개인 숙소 중 호스트가 슈퍼호스트인지 여부: ')
print(london_lists_review_0['슈퍼호스트'].value_counts())
print()
print('리뷰수가 0개인 숙소 데이터 중 슈퍼호스트가 null값인 데이터 개수:')
print(f'{london_lists_review_0["슈퍼호스트"].isnull().sum()}개')
# Out:
# ['f' 't' nan]
#
# 리뷰슈가 0개인 숙소 중 호스트가 슈퍼호스트인지 여부:
# f    23754
# t     1171
# Name: 슈퍼호스트, dtype: int64
#
# 리뷰수가 0개인 숙소 데이터 중 슈퍼호스트가 null값인 데이터 개수:
# 58개

# %% [markdown]
# 리뷰가 0개가 아닌 데이터만 사용

# %%
# 리뷰 개수가 0이 아닌 컬럼 조건 설정
condition_review = london_lists['리뷰수'] != 0

# 리뷰 개수가 0이 아닌 컬럼으로 df 업데이트 
london_lists = london_lists[condition_review]
london_url = london_url[condition_review]

# print(london_lists[:10])
# print()
print(london_lists.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65869 entries, 0 to 90735
# Data columns (total 30 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   숙소_id        65869 non-null  int64
#  1   호스트_id       65869 non-null  int64
#  2   답변_평균시간      45111 non-null  object
#  3   문의_응답률       45111 non-null  object
#  4   예약_수락률       51189 non-null  object
#  5   슈퍼호스트        65538 non-null  object
#  6   숙소_수         65869 non-null  float64
#  7   프로필_사진       65869 non-null  object
#  8   호스트_신원       65869 non-null  object
#  9   숙소_지역        65869 non-null  object
#  10  숙소_유형        65869 non-null  object
#  11  수용_인원수       65869 non-null  int64
#  12  욕실수          43758 non-null  float64
#  13  침실수          58052 non-null  float64
#  14  침대수          43703 non-null  float64
#  15  편의시설         65869 non-null  object
#  16  숙소_가격        43728 non-null  object
#  17  최소_숙박일       65869 non-null  int64
#  18  최대_숙박일       65869 non-null  int64
#  19  예약_가능여부      64536 non-null  object
#  20  리뷰수          65869 non-null  int64
#  21  30일_리뷰수      65869 non-null  int64
#  22  리뷰점수         65869 non-null  float64
#  23  숙소_정확성_리뷰점수  65838 non-null  float64
#  24  숙소_청결도_리뷰점수  65843 non-null  float64
#  25  숙소_체크인_리뷰점수  65808 non-null  float64
#  26  숙소_소통_리뷰점수   65833 non-null  float64
#  27  숙소_위치_리뷰점수   65808 non-null  float64
#  28  숙소_가격_리뷰점수   65806 non-null  float64
#  29  평균_리뷰수       65869 non-null  float64
# dtypes: float64(12), int64(7), object(11)
# memory usage: 15.6+ MB
# None
# /var/folders/_j/yl1g13yd0_s25zcx_fwnjdkm0000gn/T/ipykernel_10047/1749373705.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   london_url = london_url[condition_review]

# %%
# 문의_응답률 / 예약_수략률 >> 타입변경

london_lists['문의_응답률'] = london_lists['문의_응답률'].str.rstrip('%').astype('float')
london_lists['예약_수락률'] = london_lists['예약_수락률'].str.rstrip('%').astype('float')

# 기초 통계 요약
london_lists[['문의_응답률', '예약_수락률']].describe()
# Out:
#              문의_응답률        예약_수락률
# count  45111.000000  51189.000000
# mean      94.720334     85.460333
# std       16.803026     23.021839
# min        0.000000      0.000000
# 25%      100.000000     80.000000
# 50%      100.000000     97.000000
# 75%      100.000000    100.000000
# max      100.000000    100.000000

# %% [markdown]
# 결측치때문에 제대로 된 수치가 나오지 않은 것으로 추정

# %% [markdown]
# # 결측치

# %% [markdown]
# 결측치 처리에 집중해야할 컬럼 선택

# %%
# 컬럼 전체 결측치 확인 

london_lists.isnull().sum()
# 전체 개수 : 65,869개 중
# Out:
# 숙소_id              0
# 호스트_id             0
# 답변_평균시간        20758
# 문의_응답률         20758
# 예약_수락률         14680
# 슈퍼호스트            331
# 숙소_수               0
# 프로필_사진             0
# 호스트_신원             0
# 숙소_지역              0
# 숙소_유형              0
# 수용_인원수             0
# 욕실수            22111
# 침실수             7817
# 침대수            22166
# 편의시설               0
# 숙소_가격          22141
# 최소_숙박일             0
# 최대_숙박일             0
# 예약_가능여부         1333
# 리뷰수                0
# 30일_리뷰수            0
# 리뷰점수               0
# 숙소_정확성_리뷰점수       31
# 숙소_청결도_리뷰점수       26
# 숙소_체크인_리뷰점수       61
# 숙소_소통_리뷰점수        36
# 숙소_위치_리뷰점수        61
# 숙소_가격_리뷰점수        63
# 평균_리뷰수             0
# dtype: int64

# %% [markdown]
# ### 결측치가 천단위 이상인  컬럼

# %% [markdown]
# 1. '답변_평균시간', '문의_응답률', '예약_수락률'
# * 호스트 커뮤니케이션 관련 컬럼 > 고객의 만족도(좋은 숙소?)에 큰 영향을 미치는 요인 중 하나
# 2. '욕실수', '침실수', '침대수'
# *  숙소 가격을 결정하는데 큰 요소가 될 수 있는 카테고리 > 크롤링으로 데이터 값 채워넣기(값이 시간에 영향을 받지 않음)
# 3. '숙소_가격' : 크롤링으로 채워넣기가 힘듬. 시간에 따른 변동성이 큰 값.
# * 숙소 가격에 영향을 미칠 요인 추측 : 위치, 숙소 크기, 숙소 형태(ex. 아파트?)

# %% [markdown]
# ### 결측치가 천단위 이하인 컬럼
#
# 1. 슈퍼호스트
# 2. 예약_가능여부
# 3. '숙소_정확성_리뷰점수', '숙소_청결도_리뷰점수', '숙소_체크인_리뷰점수', '숙소_소통_리뷰점수', '숙소_위치_리뷰점수', '숙소_가격_리뷰점수'

# %% [markdown]
# # 슈퍼호스트

# %% [markdown]
# 슈퍼호스트 기준
# 1. 숙박 10건 이상 호스팅 또는 3건의 예약에 걸쳐 총 100박 이상 호스팅
# 2. 응답률 90% 이상 유지
# 3. 예약 취소율 1% 미만 유지. 단, 정상참작이 가능한 상황에 따른 예약 취소는 제외
# 4. 전체 평점 4.8점 이상 유지(후기 작성 기한인 14일이 지나거나, 그전에라도 게스트와 호스트 양측이 모두 후기를 제출하면 후기는 슈퍼호스트 실적에 계산됩니다).

# %%
# 슈퍼호스트 null 값 : 331개
print(f'슈퍼호스트 null값 개수: {london_lists["슈퍼호스트"].isnull().sum()}개')

# 슈퍼호스트 null값의 비율: 0.5% >> 삭제해도 무방 
print(f'슈퍼호스트 null값의 비율: {round((london_lists["슈퍼호스트"].isnull().sum() / 65869) * 100, 2)}%')
# Out:
# 슈퍼호스트 null값 개수: 331개
# 슈퍼호스트 null값의 비율: 0.5%

# %%
london_lists['슈퍼호스트'].value_counts()
# Out:
# f    52458
# t    13080
# Name: 슈퍼호스트, dtype: int64

# %%
# 슈퍼호스트 null값인 데이터 특징 파악

condition_superhost_null = london_lists['슈퍼호스트'].isnull()
london_lists[condition_superhost_null][['문의_응답률', '예약_수락률', '숙소_수', '리뷰수', '리뷰점수', '평균_리뷰수']].describe()
# Out:
#              숙소_수         리뷰수        리뷰점수      평균_리뷰수
# count  331.000000  331.000000  331.000000  331.000000
# mean    26.957704   35.525680    4.675921    1.490242
# std     28.076271   50.373229    0.320133    1.390061
# min      2.000000    1.000000    3.400000    0.010000
# 25%      5.000000    4.000000    4.500000    0.380000
# 50%     14.000000   14.000000    4.730000    1.050000
# 75%     36.000000   48.500000    4.970000    2.155000
# max    123.000000  342.000000    5.000000    6.860000

# %% [markdown]
# ### 슈퍼호스트가 null값인 데이터 특징?
# 1. 호스트가 여러 숙소를 운영하고 있다. (숙소수 중위수 14개, 미니멈 2개, q1 5개)
# 2. 리뷰수가 적다. (중위수 14개)
# 3. 예약 수략률과 문의 응답률이 모두 좋다 (호스트 단위 집계 항목)

# %% [markdown]
# 실제 데이터를 좀 봐볼까?

# %%
london_url[condition_superhost_null][['숙소_url', '호스트_id', '문의_응답률', '예약_수락률', '숙소_수', '리뷰수', '리뷰점수', '평균_리뷰수']].sort_values(by = ['숙소_수', '리뷰수'], ascending=[False, True])[:30]
# Out:
#                                                  숙소_url     호스트_id 문의_응답률  \
# 78819  https://www.airbnb.com/rooms/1022410255586290392   60524679    98%
# 30653             https://www.airbnb.com/rooms/34884624   60524679    98%
# 12449             https://www.airbnb.com/rooms/14754559   60524679    98%
# 13539             https://www.airbnb.com/rooms/16328145   60524679    98%
# 13538             https://www.airbnb.com/rooms/16327915   60524679    98%
# 11022             https://www.airbnb.com/rooms/13541121   60524679    98%
# 12216             https://www.airbnb.com/rooms/14483249   60524679    98%
# 11762             https://www.airbnb.com/rooms/14092256   60524679    98%
# 10670             https://www.airbnb.com/rooms/13422389   60524679    98%
# 12448             https://www.airbnb.com/rooms/14754229   60524679    98%
# 76555  https://www.airbnb.com/rooms/1003461431060401961  423475816   100%
# 83041  https://www.airbnb.com/rooms/1056571091485913860  423475816   100%
# 78328  https://www.airbnb.com/rooms/1018826274689340194  423475816   100%
# 83723  https://www.airbnb.com/rooms/1063866318964963165  423475816   100%
# 65460   https://www.airbnb.com/rooms/902779906698528795  423475816   100%
# 80991  https://www.airbnb.com/rooms/1039109669085246708   30362264   100%
# 79886  https://www.airbnb.com/rooms/1031895389130313054   30362264   100%
# 80116  https://www.airbnb.com/rooms/1033214904811674573   30362264   100%
# 65225   https://www.airbnb.com/rooms/899332588862870272   30362264   100%
# 65574   https://www.airbnb.com/rooms/903009527880128060   30362264   100%
# 72136   https://www.airbnb.com/rooms/961341371938874112   30362264   100%
# 64862   https://www.airbnb.com/rooms/894555332011787997   30362264   100%
# 65475   https://www.airbnb.com/rooms/902007368557652902   30362264   100%
# 16565             https://www.airbnb.com/rooms/19082942   30362264   100%
# 17849             https://www.airbnb.com/rooms/20165248   30362264   100%
# 72123   https://www.airbnb.com/rooms/962175437451693698  395211098   100%
# 69007   https://www.airbnb.com/rooms/934819695469775226  157295299   100%
# 45957   https://www.airbnb.com/rooms/577989883767859579  157295299   100%
# 40845             https://www.airbnb.com/rooms/49750782  157295299   100%
# 40282             https://www.airbnb.com/rooms/49129431  157295299   100%
#
#       예약_수락률   숙소_수  리뷰수  리뷰점수  평균_리뷰수
# 78819   100%  123.0    4  4.25    1.05
# 30653   100%  123.0    6  4.33    0.10
# 12449   100%  123.0  147  4.41    1.61
# 13539   100%  123.0  154  4.38    1.76
# 13538   100%  123.0  158  4.42    1.79
# 11022   100%  123.0  159  4.48    1.70
# 12216   100%  123.0  162  4.43    1.75
# 11762   100%  123.0  164  4.38    1.79
# 10670   100%  123.0  167  4.45    1.77
# 12448   100%  123.0  191  4.45    2.09
# 76555    86%   85.0    1  5.00    0.28
# 83041    86%   85.0    6  3.83    3.00
# 78328    86%   85.0   10  4.30    2.68
# 83723    86%   85.0   12  4.75    5.54
# 65460    86%   85.0   15  4.60    1.59
# 80991    99%   83.0    3  3.67    0.96
# 79886    99%   83.0    4  4.25    1.18
# 80116    99%   83.0    5  4.60    1.60
# 65225    99%   83.0    8  4.38    0.81
# 65574    99%   83.0   16  4.75    1.65
# 72136    99%   83.0   16  4.56    2.32
# 64862    99%   83.0   22  4.55    2.19
# 65475    99%   83.0   23  4.52    2.35
# 16565    99%   83.0  242  4.72    2.94
# 17849    99%   83.0  247  4.72    3.06
# 72123    98%   80.0    5  4.60    0.91
# 69007   100%   73.0   17  4.35    2.19
# 45957   100%   73.0   72  4.40    2.95
# 40845   100%   73.0   74  4.41    2.22
# 40282   100%   73.0   82  4.54    2.32

# %% [markdown]
# 엥? 호스트가 같은 값이 많네?

# %%
# 호스트가 겹치는 숙소(슈퍼호스트가 null값인) 숫자 세기 

# 조건 설정 
condition_result_host_1 = (london_lists[condition_superhost_null]['호스트_id'].value_counts() == 1)

# True와 False 값의 개수를 각각 세기
true_count = condition_result_host_1.sum()
false_count = (~condition_result_host_1).sum()

# 출력
print(f"겹치지 않은 호스트의 수: {true_count}")
print(f"겹치는 호스트의 수: {false_count}")
# Out:
# 겹치지 않은 호스트의 수: 83
# 겹치는 호스트의 수: 47

# %%
london_lists[condition_superhost_null]['호스트_id'].value_counts()[:30]
# Out:
# 494256171    21
# 239389535    15
# 268416645    14
# 154555136    11
# 4086714      11
# 30362264     10
# 127463633    10
# 329579576    10
# 60524679     10
# 183088797     9
# 157295299     8
# 23966399      7
# 67938882      6
# 456934029     6
# 68502358      5
# 423475816     5
# 509171821     5
# 232786181     5
# 190939015     5
# 107983837     4
# 196192499     4
# 401748044     4
# 35351106      4
# 462011865     3
# 144834468     3
# 97874184      3
# 13792962      3
# 235963197     3
# 8419096       3
# 267646946     3
# Name: 호스트_id, dtype: int64

# %% [markdown]
# 숙소 개수는 미니멈이 2개 였으니까 전체 데이터에서 슈퍼호스트가 null값인 호스트의 다른 숙소가 있나 한 번 확인해보자.

# %% [markdown]
# # 답변_평균시간

# %% [markdown]
# * '답변 평균시간'을 제외하고자 했던 논리가 슈퍼호스트 선정 기준이었던 것으로 기억함
# * 근데 엄연히 답변 평균 시간과 응답률은 다른 속성 컬럼임으로 임의로 전처리를 진행해보기로 결정

# %%
london_lists['답변_평균시간'].unique()
# Out:
# array(['within a few hours', 'within a day', 'within an hour', nan,
#        'a few days or more'], dtype=object)

# %%
london_lists['답변_평균시간'].isnull().sum()
# Out:
# 20758

# %%
london_lists['답변_평균시간'].value_counts()
# Out:
# within an hour        31207
# within a few hours     7548
# within a day           5008
# a few days or more     1348
# Name: 답변_평균시간, dtype: int64

# %% [markdown]
# ### 답변_평균시간이 null인 값들의 슈퍼호스트 여부

# %% [markdown]
# # 문의_응답률

# %%
# 문의_응답률 컬럼 

london_lists['문의_응답률'].isnull().sum()
# Out:
# 20758

# %%
# 문의 응답률이 not null값인 숙소 >> 에어비앤비 사이트에서 샘플 확인

condition_response_notnull = london_lists['문의_응답률'].notnull()
london_lists_raw[condition_response_notnull][['listing_url', 'name', 'host_response_rate']][:30]

# >> 사이트 숙소 상세 설명 페이지 내 문의 응답률 위치 확인
# Out:
# /var/folders/_j/yl1g13yd0_s25zcx_fwnjdkm0000gn/T/ipykernel_10047/2834148228.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   london_lists_raw[condition_response_notnull][['listing_url', 'name', 'host_response_rate']][:30]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# /var/folders/_j/yl1g13yd0_s25zcx_fwnjdkm0000gn/T/ipykernel_10047/2834148228.py in <module>
#       2
#       3 condition_response_notnull = london_lists['문의_응답률'].notnull()
# ----> 4 london_lists_raw[condition_response_notnull][['listing_url', 'name', 'host_response_rate']][:30]
#       5
#       6 # >> 사이트 숙소 상세 설명 페이지 내 문의 응답률 위치 확인
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3494         # Do we have a (boolean) 1d indexer?
#    3495         if com.is_bool_indexer(key):
# -> 3496             return self._getitem_bool_array(key)
#    3497
#    3498         # We are left with two options: a single key, and a collection of keys,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    3547         # check_bool_indexer will throw exception if Series key cannot
#    3548         # be reindexed to match DataFrame rows
# -> 3549         key = check_bool_indexer(self.index, key)
#    3550         indexer = key.nonzero()[0]
#    3551         return self._take_with_is_copy(indexer, axis=0)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in check_bool_indexer(index, key)
#    2386         mask = isna(result._values)
#    2387         if mask.any():
# -> 2388             raise IndexingError(
#    2389                 "Unalignable boolean Series provided as "
#    2390                 "indexer (index of the boolean Series and of "
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %% [markdown]
# 응답률이 나와있는 숙소도 현재 사이트 내 문의 응답률과 다른 경우도 있음
# * https://www.airbnb.com/rooms/170524
# * 66% > 33 %

# %%
# 문의 응답률이 null값인 숙소 >> 에어비앤비 사이트에서 샘플 확인

# 선별한 컬럼의 데이터프레임에서 문의응답률이 null 값인 조건 설정 
condition_response_null = london_lists['문의_응답률'].isnull()  

# raw 데이터프레임에서 문의응답률이 null 값인 조건 설정 
raw_response_null = london_lists_raw['host_response_rate'].isnull()
london_lists_raw[raw_response_null][['listing_url', 'name']]
# Out:
#                                             listing_url  \
# 5                   https://www.airbnb.com/rooms/313710
# 6                   https://www.airbnb.com/rooms/168359
# 8                    https://www.airbnb.com/rooms/24328
# 11                  https://www.airbnb.com/rooms/170702
# 12                   https://www.airbnb.com/rooms/33332
# ...                                                 ...
# 90844  https://www.airbnb.com/rooms/1115272705566417319
# 90845  https://www.airbnb.com/rooms/1115272736222611647
# 90846  https://www.airbnb.com/rooms/1115272737028206976
# 90847  https://www.airbnb.com/rooms/1115272743905612628
# 90848  https://www.airbnb.com/rooms/1115272767893608505
#
#                                                     name
# 5                    Pretty Home Kensal Green NW10 1 bed
# 6          Stunning 2 Bed Apartment in Elephant & Castle
# 8      Battersea live/work artist house, garden communal
# 11                       A Double Room with  River Views
# 12        Beautiful Ensuite Richmond-upon-Thames borough
# ...                                                  ...
# 90844                           Primrose Hill Studio #29
# 90845                           Primrose Hill Studio #28
# 90846                           Primrose Hill Studio #26
# 90847                           Primrose Hill Studio #25
# 90848                           Primrose Hill Studio #27
#
# [33055 rows x 2 columns]

# %% [markdown]
# 문의 응답률이 null값'인 숙소의 경우의 수 (가설)
#
# 1. 숙소 이용이 없어서 문의 또한 없기 때문에
# 2. 실제로 문의 응답을 안하는 경우 (카운팅을 하지 못하기 때문)
#
# <br />
#
# 3. 에어비앤비 호스트 정보에 문의 응답률이 누락된 경우
# 4. 데이터를 가져오면서 누락된 경우 및 기타 오류

# %%
# 문의 응답률이 null 값인 숙소의 리뷰수와 리뷰 점수 조회

london_lists[condition_response_null][['리뷰수', '리뷰점수']]
london_lists[condition_response_null][['리뷰수', '리뷰점수']].sort_values(by='리뷰수', ascending=False)
# Out:
#        리뷰수  리뷰점수
# 6874   711  4.87
# 885    575  4.95
# 1144   559  4.89
# 536    548  4.60
# 967    400  4.63
# ...    ...   ...
# 25321    0   NaN
# 25322    0   NaN
# 25334    0   NaN
# 25340    0   NaN
# 90848    0   NaN
#
# [33055 rows x 2 columns]

# %% [markdown]
# 리뷰가 많은데 문의 응답이 없는 경우가 있네?
# * 이 케이스가 어떤 케이스인지 실제 사이트에서 확인해보자

# %%
london_lists_raw[raw_response_null][['listing_url', 'name']].shape
# Out:
# (33055, 2)

# %%
london_lists_raw[raw_response_null][['listing_url', 'name', 'number_of_reviews', 'review_scores_rating']].sort_values(by='number_of_reviews', ascending=False)[:30]
# Out:
#                                  listing_url  \
# 6874    https://www.airbnb.com/rooms/9046849
# 885      https://www.airbnb.com/rooms/877864
# 1144    https://www.airbnb.com/rooms/1296836
# 536      https://www.airbnb.com/rooms/502190
# 967      https://www.airbnb.com/rooms/756481
# 4030    https://www.airbnb.com/rooms/5878880
# 20       https://www.airbnb.com/rooms/315658
# 1087    https://www.airbnb.com/rooms/1117720
# 8819   https://www.airbnb.com/rooms/11226035
# 13151  https://www.airbnb.com/rooms/15855571
# 8593   https://www.airbnb.com/rooms/10833014
# 317      https://www.airbnb.com/rooms/397504
# 804      https://www.airbnb.com/rooms/715564
# 841      https://www.airbnb.com/rooms/726669
# 9876   https://www.airbnb.com/rooms/12444228
# 825      https://www.airbnb.com/rooms/720633
# 985     https://www.airbnb.com/rooms/1044873
# 840      https://www.airbnb.com/rooms/725370
# 1322    https://www.airbnb.com/rooms/1626486
# 819      https://www.airbnb.com/rooms/717220
# 3560    https://www.airbnb.com/rooms/5041618
# 21757  https://www.airbnb.com/rooms/23367928
# 3276    https://www.airbnb.com/rooms/4772751
# 12087  https://www.airbnb.com/rooms/14521008
# 8993   https://www.airbnb.com/rooms/11419334
# 9372   https://www.airbnb.com/rooms/11966878
# 1093    https://www.airbnb.com/rooms/1185611
# 28981  https://www.airbnb.com/rooms/32440623
# 8546   https://www.airbnb.com/rooms/10706762
# 21652  https://www.airbnb.com/rooms/23335713
#
#                                                     name  number_of_reviews  \
# 6874         Near HEATHROW AIRPORT, London, double room.                711
# 885                   Bright guest room in gay household                575
# 1144         Covent Garden Flat Listed Building, London.                559
# 536     Large Double room private bath near Kilburn tube                548
# 967                     Brand new studio in Victoria 15A                400
# 4030     INDEPENDENT COSY LITTLE HOUSE IN CENTRAL LONDON                397
# 20                    Double Room nr Oval Vauxhall Tubes                389
# 1087                 Central London:  Sunny single room!                369
# 8819    Tranquil comfortable single bedroom/females only                357
# 13151  LHR,free travelzone,UB35BD vPrivate,vClean,Gar...                354
# 8593                  Charming apartment, Central London                350
# 317                                         Casa Chelsea                336
# 804                      Brand new studio in Victoria 8A                332
# 841                     Brand new studio in Victoria 11A                330
# 9876    Room close to Central London - Wi-Fi and TV inc.                329
# 825                   Double studio + patio, Victoria 2A                328
# 985    Penthouse Room with Views over Park, near Station                308
# 840                     Brand new studio in Victoria 12A                306
# 1322   Private bathroom. Lovely area of North London N10                306
# 819                         Double Studio in Victoria 5A                302
# 3560   Pimlico Victoria Double Room Georgian Garden Flat                289
# 21757  Charming Apartment in Central London - Farring...                289
# 3276      Stylish 2 Bedroom Flat Central London *ZONE 1*                288
# 12087       Beautiful, Victorian Room Facing The Garden.                286
# 8993                              CAVENDISH  Apartment+1                285
# 9372   Large single room with a big cosy bed with ens...                281
# 1093                 Central London Zone1 Big Doubleroom                276
# 28981                        Double room in Islington N1                275
# 8546                  Clean and quite room with a garden                273
# 21652      Master bedroom near Heathrow with an en-suite                270
#
#        review_scores_rating
# 6874                   4.87
# 885                    4.95
# 1144                   4.89
# 536                    4.60
# 967                    4.63
# 4030                   4.86
# 20                     4.75
# 1087                   4.75
# 8819                   4.91
# 13151                  4.91
# 8593                   4.70
# 317                    4.96
# 804                    4.70
# 841                    4.68
# 9876                   4.73
# 825                    4.54
# 985                    4.87
# 840                    4.56
# 1322                   4.86
# 819                    4.60
# 3560                   4.88
# 21757                  4.81
# 3276                   4.61
# 12087                  4.68
# 8993                   4.42
# 9372                   4.89
# 1093                   4.71
# 28981                  4.70
# 8546                   4.62
# 21652                  4.64

# %% [markdown]
# 슈퍼호스트가 아닌 경우 문의 응답률이 호스트 정보에 나오질 않나?
# *  확인 필요

# %% [markdown]
# 슈퍼호스트 컬럼 확인

# %%
# 슈퍼호스트 컬럼 null값 확인 
london_lists_raw['host_is_superhost'].isnull().sum()
# Out:
# 389

# %%
# 슈퍼호스트 컬럼 유니크값 확인 
london_lists_raw['host_is_superhost'].unique()
# Out:
# array(['t', 'f', nan], dtype=object)

# %%
# 슈퍼호스트 컬럼 값별 개수 확인
# 슈퍼호스트 값이 t : 14,251
# 슈퍼호스트 값이 f : 76,212

# 30개 컬럼 선별한 데이터프레임(london_lists)의 컨디션
condition_superhost_t = london_lists['슈퍼호스트'] == 't'
condition_superhost_f = london_lists['슈퍼호스트'] == 'f'

# raw 데이터프레임(london_lists_raw)의 컨디션
raw_superhost_t = london_lists_raw['host_is_superhost'] == 't'
raw_superhost_f = london_lists_raw['host_is_superhost'] == 'f'
print('슈퍼호스트인 숙소 ')
print(london_lists_raw[raw_superhost_t].shape)
print()
print('슈퍼호스트가 아닌 숙소')
print(london_lists_raw[raw_superhost_f].shape)
# Out:
# 슈퍼호스트인 숙소
# (14251, 75)
#
# 슈퍼호스트가 아닌 숙소
# (76212, 75)

# %% [markdown]
# * 문의응답률 null 값 개수 : 33,055 개
# * 슈퍼호스트가 아닌 숙소 : 76,212 개
#
# <br />
#
# *  슈퍼호스트가 아닌 경우에도 응답률 수집이 가능하긴 함!

# %% [markdown]
# 리뷰가 많은데 문의응답률이 null값인 숙소의 슈퍼호스트 여부 확인

# %%
london_lists_raw[raw_response_null]['host_is_superhost'].unique()
# Out:
# array(['f', 't', nan], dtype=object)

# %%
# '문의_응답률'이 null인 숙소를 '리뷰수' 내림차순으로 정렬

london_lists_raw[raw_response_null][['listing_url', 'name', 'number_of_reviews', 'review_scores_rating', 'host_is_superhost']].sort_values(by='number_of_reviews', ascending=False)[:50]
# Out:
#                                  listing_url  \
# 6874    https://www.airbnb.com/rooms/9046849
# 885      https://www.airbnb.com/rooms/877864
# 1144    https://www.airbnb.com/rooms/1296836
# 536      https://www.airbnb.com/rooms/502190
# 967      https://www.airbnb.com/rooms/756481
# 4030    https://www.airbnb.com/rooms/5878880
# 20       https://www.airbnb.com/rooms/315658
# 1087    https://www.airbnb.com/rooms/1117720
# 8819   https://www.airbnb.com/rooms/11226035
# 13151  https://www.airbnb.com/rooms/15855571
# 8593   https://www.airbnb.com/rooms/10833014
# 317      https://www.airbnb.com/rooms/397504
# 804      https://www.airbnb.com/rooms/715564
# 841      https://www.airbnb.com/rooms/726669
# 9876   https://www.airbnb.com/rooms/12444228
# 825      https://www.airbnb.com/rooms/720633
# 985     https://www.airbnb.com/rooms/1044873
# 840      https://www.airbnb.com/rooms/725370
# 1322    https://www.airbnb.com/rooms/1626486
# 819      https://www.airbnb.com/rooms/717220
# 3560    https://www.airbnb.com/rooms/5041618
# 21757  https://www.airbnb.com/rooms/23367928
# 3276    https://www.airbnb.com/rooms/4772751
# 12087  https://www.airbnb.com/rooms/14521008
# 8993   https://www.airbnb.com/rooms/11419334
# 9372   https://www.airbnb.com/rooms/11966878
# 1093    https://www.airbnb.com/rooms/1185611
# 28981  https://www.airbnb.com/rooms/32440623
# 8546   https://www.airbnb.com/rooms/10706762
# 21652  https://www.airbnb.com/rooms/23335713
# 199      https://www.airbnb.com/rooms/358360
# 273      https://www.airbnb.com/rooms/381467
# 8505   https://www.airbnb.com/rooms/10546640
# 6364    https://www.airbnb.com/rooms/8127220
# 1999    https://www.airbnb.com/rooms/2841245
# 869      https://www.airbnb.com/rooms/739774
# 5010    https://www.airbnb.com/rooms/6843786
# 844      https://www.airbnb.com/rooms/726950
# 13573  https://www.airbnb.com/rooms/16256750
# 12824  https://www.airbnb.com/rooms/15333989
# 777      https://www.airbnb.com/rooms/710203
# 9999   https://www.airbnb.com/rooms/12613250
# 813      https://www.airbnb.com/rooms/717171
# 6062    https://www.airbnb.com/rooms/7876250
# 16802  https://www.airbnb.com/rooms/19455388
# 3629    https://www.airbnb.com/rooms/5081461
# 871      https://www.airbnb.com/rooms/739825
# 20389  https://www.airbnb.com/rooms/21988961
# 12015  https://www.airbnb.com/rooms/14239782
# 4651    https://www.airbnb.com/rooms/6532498
#
#                                                     name  number_of_reviews  \
# 6874         Near HEATHROW AIRPORT, London, double room.                711
# 885                   Bright guest room in gay household                575
# 1144         Covent Garden Flat Listed Building, London.                559
# 536     Large Double room private bath near Kilburn tube                548
# 967                     Brand new studio in Victoria 15A                400
# 4030     INDEPENDENT COSY LITTLE HOUSE IN CENTRAL LONDON                397
# 20                    Double Room nr Oval Vauxhall Tubes                389
# 1087                 Central London:  Sunny single room!                369
# 8819    Tranquil comfortable single bedroom/females only                357
# 13151  LHR,free travelzone,UB35BD vPrivate,vClean,Gar...                354
# 8593                  Charming apartment, Central London                350
# 317                                         Casa Chelsea                336
# 804                      Brand new studio in Victoria 8A                332
# 841                     Brand new studio in Victoria 11A                330
# 9876    Room close to Central London - Wi-Fi and TV inc.                329
# 825                   Double studio + patio, Victoria 2A                328
# 985    Penthouse Room with Views over Park, near Station                308
# 840                     Brand new studio in Victoria 12A                306
# 1322   Private bathroom. Lovely area of North London N10                306
# 819                         Double Studio in Victoria 5A                302
# 3560   Pimlico Victoria Double Room Georgian Garden Flat                289
# 21757  Charming Apartment in Central London - Farring...                289
# 3276      Stylish 2 Bedroom Flat Central London *ZONE 1*                288
# 12087       Beautiful, Victorian Room Facing The Garden.                286
# 8993                              CAVENDISH  Apartment+1                285
# 9372   Large single room with a big cosy bed with ens...                281
# 1093                 Central London Zone1 Big Doubleroom                276
# 28981                        Double room in Islington N1                275
# 8546                  Clean and quite room with a garden                273
# 21652      Master bedroom near Heathrow with an en-suite                270
# 199                      Room w/ WI-FI in Arty Victorian                266
# 273                      Earls Court-London-2 Bed/2 Bath                265
# 8505                      Cosy Room in Central Apartment                262
# 6364        Sunny room (on left) in renovated 1825 house                260
# 1999                       A single room in a large flat                258
# 869                        Ensuite Studio in Victoria 6A                256
# 5010                   Highbury Garden House - King Room                254
# 844         Studio with private terrace near Victoria 9A                252
# 13573     Flat2(Angie), double room, London, Kings Cross                251
# 12824  Double bedroom, own bath and kitchen in Islington                250
# 777                         Double studio in Victoria 4A                249
# 9999                  Lovely room on right in 1825 house                248
# 813                   Cosy single studio in Victoria 14A                246
# 6062   GuestReady - Self-Contained EnSuite Room w/Bal...                245
# 16802                     Clean, comfortable double room                243
# 3629                 Huge Attic Room, en-suite & terrace                242
# 871                     Brand new studio in Victoria 13A                239
# 20389                       Shoreditch High Street Haven                239
# 12015      Lovely double room 1 stop from London Bridge.                239
# 4651                  Highbury Garden House - Queen Room                238
#
#        review_scores_rating host_is_superhost
# 6874                   4.87                 f
# 885                    4.95                 f
# 1144                   4.89                 f
# 536                    4.60                 f
# 967                    4.63                 f
# 4030                   4.86                 f
# 20                     4.75                 f
# 1087                   4.75                 f
# 8819                   4.91                 f
# 13151                  4.91                 f
# 8593                   4.70                 f
# 317                    4.96                 f
# 804                    4.70                 f
# 841                    4.68                 f
# 9876                   4.73                 t
# 825                    4.54                 f
# 985                    4.87                 f
# 840                    4.56                 f
# 1322                   4.86                 f
# 819                    4.60                 f
# 3560                   4.88                 t
# 21757                  4.81                 f
# 3276                   4.61                 t
# 12087                  4.68                 f
# 8993                   4.42                 f
# 9372                   4.89                 f
# 1093                   4.71                 f
# 28981                  4.70                 f
# 8546                   4.62                 f
# 21652                  4.64                 f
# 199                    4.79                 f
# 273                    4.66                 f
# 8505                   4.71                 f
# 6364                   4.96                 f
# 1999                   4.74                 f
# 869                    4.65                 f
# 5010                   4.84                 f
# 844                    4.62                 f
# 13573                  4.39                 f
# 12824                  4.75                 f
# 777                    4.60                 f
# 9999                   4.94                 f
# 813                    4.71                 f
# 6062                   4.73                 f
# 16802                  4.98                 f
# 3629                   4.96                 f
# 871                    4.68                 f
# 20389                  4.90                 f
# 12015                  4.67                 f
# 4651                   4.85                 f

# %% [markdown]
# * 응답률 null값 중 리뷰가 많은 숙소는 슈퍼호스트가 아니다.'는 가설은 기각.
# * 응답률 null값 중 리뷰가 많은 숙소의 대부분의 경우 슈퍼호스트가 아니다.' 이거는 맞는거 같은데?

# %% [markdown]
# 또 다른 가설: 응답률이 나와있지 않으면서 슈퍼호스트인 경우 >> 다른 숙소에서 슈퍼호스트를 달고 해당 숙소는 오픈한지 얼마되지 않은 것 아닐까 ?
# 1. 리뷰는 숙소 단위로 카운트되는게 맞으므로, 리뷰가 많을 경우엔 해당 가설도 해당되지 않음
# 2. 리뷰가 얼마 없는데 슈퍼호스트인 경우는 해당될 수 있음 >> 이 경우엔 실제 사이트에 들어가서 리뷰가 남겨진 날짜를 확인하면 증명할 수 있을 듯

# %%
# '문의_응답률'이 null값이고 '슈퍼호스트'가 t/f인 조건 생성

raw_response_null_superhost_t = raw_response_null & (london_lists_raw['host_is_superhost'] == 't')
raw_response_null_superhost_f = raw_response_null & (london_lists_raw['host_is_superhost'] == 'f')

raw_response_null_superhost_t
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 90847    False
# 90848    False
# 90849    False
# 90850    False
# 90851    False
# Length: 90852, dtype: bool

# %%
# '문의_응답률'이 null값이고 '슈퍼호스트'가 t인 숙소 조회 : 총 907개 

london_lists_raw[raw_response_null_superhost_t][['listing_url', 'name', 'number_of_reviews', 'review_scores_rating']].sort_values(by='number_of_reviews', ascending=False)
# Out:
#                                             listing_url  \
# 9876              https://www.airbnb.com/rooms/12444228
# 3560               https://www.airbnb.com/rooms/5041618
# 3276               https://www.airbnb.com/rooms/4772751
# 29452             https://www.airbnb.com/rooms/33040646
# 5162               https://www.airbnb.com/rooms/7257296
# ...                                                 ...
# 34712             https://www.airbnb.com/rooms/39941435
# 60239   https://www.airbnb.com/rooms/838154978747603826
# 71150   https://www.airbnb.com/rooms/953343244946347684
# 63871   https://www.airbnb.com/rooms/884863856530629176
# 90717  https://www.airbnb.com/rooms/1114582876470375854
#
#                                                     name  number_of_reviews  \
# 9876    Room close to Central London - Wi-Fi and TV inc.                329
# 3560   Pimlico Victoria Double Room Georgian Garden Flat                289
# 3276      Stylish 2 Bedroom Flat Central London *ZONE 1*                288
# 29452                Cosy room in the heart of the city!                219
# 5162   VERY SAFE area for female travellers/Flexi wor...                209
# ...                                                  ...                ...
# 34712                  Parkview Flat of Real Tranquility                  0
# 60239                              Mezzanine Double Room                  0
# 71150                   King bedroom+private shower room                  0
# 63871                        Entire flat in Notting Hill                  0
# 90717                          Ilford 3-Bed Garden House                  0
#
#        review_scores_rating
# 9876                   4.73
# 3560                   4.88
# 3276                   4.61
# 29452                  4.80
# 5162                   4.96
# ...                     ...
# 34712                   NaN
# 60239                   NaN
# 71150                   NaN
# 63871                   NaN
# 90717                   NaN
#
# [907 rows x 4 columns]

# %%
# '문의_응답률'이 null값이고 '슈퍼호스트'이면서 리뷰가 0개인 숙소 개수 : 37개 

london_lists_raw[raw_response_null_superhost_t & (london_lists_raw['number_of_reviews'] == 0)][['listing_url', 'name', 'number_of_reviews', 'review_scores_rating']].shape
# Out:
# (37, 4)

# %% [markdown]
# '문의_응답률'이 null값이고 '슈퍼호스트'이면서 리뷰가 0개인 숙소 개수 : 37개
#
# --> 37개의 숙소는 슈퍼호스트가 새로 오픈한 숙소가 맞을듯

# %%
london_lists_raw[raw_response_null_superhost_t & (london_lists_raw['number_of_reviews'] == 0)][['listing_url', 'name', 'number_of_reviews', 'review_scores_rating', 'host_is_superhost', 'host_response_rate']]
# Out:
#                                             listing_url  \
# 11604             https://www.airbnb.com/rooms/13922077
# 14098             https://www.airbnb.com/rooms/16772532
# 23837             https://www.airbnb.com/rooms/25768390
# 34712             https://www.airbnb.com/rooms/39941435
# 37028             https://www.airbnb.com/rooms/42733043
# 37098             https://www.airbnb.com/rooms/42849943
# 41621             https://www.airbnb.com/rooms/50633813
# 43196             https://www.airbnb.com/rooms/52646658
# 45441   https://www.airbnb.com/rooms/557769923114262393
# 47925   https://www.airbnb.com/rooms/633402445806743860
# 48399   https://www.airbnb.com/rooms/642748803982079952
# 49623   https://www.airbnb.com/rooms/661066286062236557
# 49871   https://www.airbnb.com/rooms/666013846077572084
# 51489   https://www.airbnb.com/rooms/691291208015701662
# 54803   https://www.airbnb.com/rooms/756220250238217147
# 56467   https://www.airbnb.com/rooms/780792831841657873
# 58320   https://www.airbnb.com/rooms/816516085970776742
# 58728   https://www.airbnb.com/rooms/821086864660089631
# 60239   https://www.airbnb.com/rooms/838154978747603826
# 60243   https://www.airbnb.com/rooms/838161851268552646
# 63871   https://www.airbnb.com/rooms/884863856530629176
# 65093   https://www.airbnb.com/rooms/898245019101277593
# 65490   https://www.airbnb.com/rooms/902831034847813543
# 66347   https://www.airbnb.com/rooms/910854828468444116
# 68340   https://www.airbnb.com/rooms/929590113453182788
# 71150   https://www.airbnb.com/rooms/953343244946347684
# 72031   https://www.airbnb.com/rooms/959968164600589433
# 74402   https://www.airbnb.com/rooms/983266626261579749
# 75274   https://www.airbnb.com/rooms/991014831820758089
# 78483  https://www.airbnb.com/rooms/1019252518946558544
# 81058  https://www.airbnb.com/rooms/1039827210985750539
# 83664  https://www.airbnb.com/rooms/1062956410176356460
# 89188  https://www.airbnb.com/rooms/1105111144156949144
# 90164  https://www.airbnb.com/rooms/1110644693526479364
# 90678  https://www.airbnb.com/rooms/1113264792320739207
# 90712  https://www.airbnb.com/rooms/1114574886555748426
# 90717  https://www.airbnb.com/rooms/1114582876470375854
#
#                                                    name  number_of_reviews  \
# 11604       Beautiful large room Highbury and Islington                  0
# 14098                      North Acton two bed two bath                  0
# 23837                      Perfect for Wimbledon Tennis                  0
# 34712                 Parkview Flat of Real Tranquility                  0
# 37028  Spacious room females ONLY double bed London E18                  0
# 37098            Stylish flat overlooking Hackney Downs                  0
# 41621       Vacant Professional housing in West Drayton                  0
# 43196                              The Rokxy King Suite                  0
# 45441                         Family Ensuite@SkylarkB&B                  0
# 47925                             Islington Family Home                  0
# 48399              Spacious family home opposite a park                  0
# 49623   Riverside apartment minutes from Elizabeth line                  0
# 49871                              Cosy 2 bed apartment                  0
# 51489                    Self contained Studio flat NW2                  0
# 54803    Double room in Ground Floor Duplex with Garden                  0
# 56467                   Stunning room near Tower Bridge                  0
# 58320                     The Hygge Suite -at the Rokxy                  0
# 58728                  lovely bedroom near Notting hill                  0
# 60239                             Mezzanine Double Room                  0
# 60243                 Mezzanine Studio - Annex Building                  0
# 63871                       Entire flat in Notting Hill                  0
# 65093                 St James Park 2bed2bath apartment                  0
# 65490                  Luxury o2 family sized apartment                  0
# 66347                    Six behind the pink front door                  0
# 68340                      Two bedroom flat in Haringey                  0
# 71150                  King bedroom+private shower room                  0
# 72031                        Luxury Urban Cabin retreat                  0
# 74402                    Prime 2BR, Whitechapel Central                  0
# 75274    Deluxe room close to northen+jubilee line Lo@k                  0
# 78483                                Lakeside Apartment                  0
# 81058                                Merchant Residence                  0
# 83664         Weekend in London - Tranquil Swiss Chalet                  0
# 89188  Newly Renovated Shoreditch's Flat with Park View                  0
# 90164                   Stylish Central London 2BR Flat                  0
# 90678                        Beautiful & spacious Rooms                  0
# 90712                    Ground Floor Apartment Romford                  0
# 90717                         Ilford 3-Bed Garden House                  0
#
#        review_scores_rating host_is_superhost host_response_rate
# 11604                   NaN                 t                NaN
# 14098                   NaN                 t                NaN
# 23837                   NaN                 t                NaN
# 34712                   NaN                 t                NaN
# 37028                   NaN                 t                NaN
# 37098                   NaN                 t                NaN
# 41621                   NaN                 t                NaN
# 43196                   NaN                 t                NaN
# 45441                   NaN                 t                NaN
# 47925                   NaN                 t                NaN
# 48399                   NaN                 t                NaN
# 49623                   NaN                 t                NaN
# 49871                   NaN                 t                NaN
# 51489                   NaN                 t                NaN
# 54803                   NaN                 t                NaN
# 56467                   NaN                 t                NaN
# 58320                   NaN                 t                NaN
# 58728                   NaN                 t                NaN
# 60239                   NaN                 t                NaN
# 60243                   NaN                 t                NaN
# 63871                   NaN                 t                NaN
# 65093                   NaN                 t                NaN
# 65490                   NaN                 t                NaN
# 66347                   NaN                 t                NaN
# 68340                   NaN                 t                NaN
# 71150                   NaN                 t                NaN
# 72031                   NaN                 t                NaN
# 74402                   NaN                 t                NaN
# 75274                   NaN                 t                NaN
# 78483                   NaN                 t                NaN
# 81058                   NaN                 t                NaN
# 83664                   NaN                 t                NaN
# 89188                   NaN                 t                NaN
# 90164                   NaN                 t                NaN
# 90678                   NaN                 t                NaN
# 90712                   NaN                 t                NaN
# 90717                   NaN                 t                NaN

# %% [markdown]
# * 1번째 숙소 : 슈퍼호스트가 아닌데 슈퍼호스트라고 나와있고..
# * 2번째 숙소 : 슈퍼호스트는 맞는데 문의_응답률이 나와있고...
# * 3번째 숙소 : 슈퍼호스트는 아닌데 문의_응답률이 나와있고...
# * 4번째 숙소 : 슈퍼호스트는 맞는데 문의_응답률이 나와있고...
# * 5번째 숙소 : 이 숙소는 링크 진입 자체가 안되네??

# %% [markdown]
# * 우선 응답률 null 값을 처리하는 방법은 투 트랙으로 가는 것이 좋을 듯.
#     1. 리뷰 수가 많은 숙소의 경우 평균 또는 중위수로 처리
#     2. 리뷰 수가 없는 숙소의 경우는 삭제하는 것이 맞지 않을까?

# %% [markdown]
# 근데 리뷰가 없는 애들은 분석할게 없으니까 먼저 정리하는게 맞지 않을까?

# %% [markdown]
# 우선은 중위수랑 평균 먼저 봐보자.

# %%
# 문의 응답률 >> 타입 변경 >> float

london_lists['문의_응답률'] = london_lists['문의_응답률'].str.rstrip('%').astype('float')
london_lists['문의_응답률'].head()
# Out:
# 0    100.0
# 1     86.0
# 2    100.0
# 3    100.0
# 4    100.0
# Name: 문의_응답률, dtype: float64

# %%
london_lists['문의_응답률'].describe()
# Out:
# count    57797.000000
# mean        91.930360
# std         21.931639
# min          0.000000
# 25%         98.000000
# 50%        100.000000
# 75%        100.000000
# max        100.000000
# Name: 문의_응답률, dtype: float64

# %% [markdown]
# 응답률 > 호스트 단위로 측정됨 (에어비앤비 CS 문의)

# %% [markdown]
# 슈퍼호스트인데 문의 응답률이 없는 경우는 무엇인가? (에어비앤비 CS 팀에서 답변은 어렵다고 함)

# %% [markdown]
# 슈퍼호스트  > 호스트 아이디로 묶어서 숙소 별로 일치하는지도 확인해야
