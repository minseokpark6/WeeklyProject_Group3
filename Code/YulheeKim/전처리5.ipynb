# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
path = "D:/에어비앤비/파리/listings.csv"
df = pd.read_csv(path)

# %%
print(df.shape)
df.head()
# Out:
# (84397, 75)
#        id                          listing_url       scrape_id last_scraped  \
# 0    3109    https://www.airbnb.com/rooms/3109  20240316023852   2024-03-19
# 1  165409  https://www.airbnb.com/rooms/165409  20240316023852   2024-03-19
# 2    5396    https://www.airbnb.com/rooms/5396  20240316023852   2024-03-18
# 3  166370  https://www.airbnb.com/rooms/166370  20240316023852   2024-03-16
# 4   39948   https://www.airbnb.com/rooms/39948  20240316023852   2024-03-19
#
#             source                                          name  \
# 0      city scrape                                  zen and calm
# 1      city scrape               studio charme Haut Marais PARIS
# 2      city scrape  Your perfect Paris studio on Île Saint-Louis
# 3      city scrape             Big appartment with view 4 people
# 4  previous scrape        COSY INDEPENDENT ROOM IN CENTRAL PARIS
#
#                                          description  \
# 0  Lovely Appartment with one bedroom with a Quee...
# 1            You'll love this typical parisian flat.
# 2  NEW SOFA-BED SINCE JUNE 2023, Please disregard...
# 3  2 Bedrooms apartment for up to 4 people, with ...
# 4  Large newly-renovated guest room in central Pa...
#
#                                neighborhood_overview  \
# 0  Good restaurants<br />very close the Montparna...
# 1                                                NaN
# 2  You are within walking distance to the Louvre,...
# 3  The avenue is located nearby the animated dist...
# 4  Located in the heart of Paris, The Montorgueil...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...     3631  ...
# 1  https://a0.muscache.com/pictures/miso/Hosting-...   788732  ...
# 2  https://a0.muscache.com/pictures/52413/f9bf76f...     7903  ...
# 3  https://a0.muscache.com/pictures/74224563/6c9e...   793032  ...
# 4  https://a0.muscache.com/pictures/f898fb0b-e72e...   171483  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        5.00                   5.00                5.00
# 1                        4.89                   4.95                4.74
# 2                        4.84                   4.96                4.58
# 3                        4.79                   4.65                4.48
# 4                        4.97                   4.94                4.82
#
#          license instant_bookable calculated_host_listings_count  \
# 0  7511409139079                f                              1
# 1  7510309597559                f                              1
# 2  7510402838018                f                              2
# 3  7511007974397                f                              1
# 4  7510200734360                f                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           1
# 2                                           1
# 3                                           1
# 4                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            1
# 3                                            0
# 4                                            1
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.05
# 1                                           0              0.69
# 2                                           0              2.19
# 3                                           0              0.51
# 4                                           0              0.99
#
# [5 rows x 75 columns]

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
columns_to_drop = ['scrape_id','last_scraped','source','name','neighborhood_overview','picture_url','host_url','host_name','host_since','host_location','host_about','host_thumbnail_url','host_picture_url','host_neighbourhood','host_listings_count','host_verifications','neighbourhood','neighbourhood_group_cleansed','property_type','bathrooms_text','minimum_minimum_nights','maximum_minimum_nights','minimum_maximum_nights','maximum_maximum_nights','minimum_nights_avg_ntm','maximum_nights_avg_ntm','availability_60','availability_90','availability_365','calendar_last_scraped','number_of_reviews_ltm','first_review','last_review','license','instant_bookable','calculated_host_listings_count','calculated_host_listings_count_entire_homes','calculated_host_listings_count_private_rooms','calculated_host_listings_count_shared_rooms']
df.drop(columns=columns_to_drop, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84397 entries, 0 to 84396
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           84397 non-null  int64
#  1   listing_url                  84397 non-null  object
#  2   description                  80894 non-null  object
#  3   host_id                      84397 non-null  int64
#  4   host_response_time           48310 non-null  object
#  5   host_response_rate           48310 non-null  object
#  6   host_acceptance_rate         56521 non-null  object
#  7   host_is_superhost            84306 non-null  object
#  8   host_total_listings_count    84390 non-null  float64
#  9   host_has_profile_pic         84390 non-null  object
#  10  host_identity_verified       84390 non-null  object
#  11  neighbourhood_cleansed       84397 non-null  object
#  12  latitude                     84397 non-null  float64
#  13  longitude                    84397 non-null  float64
#  14  room_type                    84397 non-null  object
#  15  accommodates                 84397 non-null  int64
#  16  bathrooms                    60959 non-null  float64
#  17  bedrooms                     77480 non-null  float64
#  18  beds                         60828 non-null  float64
#  19  amenities                    84397 non-null  object
#  20  price                        60917 non-null  object
#  21  minimum_nights               84397 non-null  int64
#  22  maximum_nights               84397 non-null  int64
#  23  calendar_updated             0 non-null      float64
#  24  has_availability             79888 non-null  object
#  25  availability_30              84397 non-null  int64
#  26  number_of_reviews            84397 non-null  int64
#  27  number_of_reviews_l30d       84397 non-null  int64
#  28  review_scores_rating         58827 non-null  float64
#  29  review_scores_accuracy       58793 non-null  float64
#  30  review_scores_cleanliness    58797 non-null  float64
#  31  review_scores_checkin        58784 non-null  float64
#  32  review_scores_communication  58795 non-null  float64
#  33  review_scores_location       58787 non-null  float64
#  34  review_scores_value          58782 non-null  float64
#  35  reviews_per_month            58822 non-null  float64
# dtypes: float64(15), int64(8), object(13)
# memory usage: 23.2+ MB

# %%
print(df.isnull().sum())
# Out:
# id                                 0
# listing_url                        0
# description                     3503
# host_id                            0
# host_response_time             36087
# host_response_rate             36087
# host_acceptance_rate           27876
# host_is_superhost                 91
# host_total_listings_count          7
# host_has_profile_pic               7
# host_identity_verified             7
# neighbourhood_cleansed             0
# latitude                           0
# longitude                          0
# room_type                          0
# accommodates                       0
# bathrooms                      23438
# bedrooms                        6917
# beds                           23569
# amenities                          0
# price                          23480
# minimum_nights                     0
# maximum_nights                     0
# calendar_updated               84397
# has_availability                4509
# availability_30                    0
# number_of_reviews                  0
# number_of_reviews_l30d             0
# review_scores_rating           25570
# review_scores_accuracy         25604
# review_scores_cleanliness      25600
# review_scores_checkin          25613
# review_scores_communication    25602
# review_scores_location         25610
# review_scores_value            25615
# reviews_per_month              25575
# dtype: int64

# %%
df['description'] = df['description'].fillna(' ')

# %%
df = df[~df['room_type'].isin(['Shared room', 'Hotel room'])]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83128 entries, 0 to 84396
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           83128 non-null  int64
#  1   listing_url                  83128 non-null  object
#  2   description                  83128 non-null  object
#  3   host_id                      83128 non-null  int64
#  4   host_response_time           47520 non-null  object
#  5   host_response_rate           47520 non-null  object
#  6   host_acceptance_rate         55578 non-null  object
#  7   host_is_superhost            83037 non-null  object
#  8   host_total_listings_count    83121 non-null  float64
#  9   host_has_profile_pic         83121 non-null  object
#  10  host_identity_verified       83121 non-null  object
#  11  neighbourhood_cleansed       83128 non-null  object
#  12  latitude                     83128 non-null  float64
#  13  longitude                    83128 non-null  float64
#  14  room_type                    83128 non-null  object
#  15  accommodates                 83128 non-null  int64
#  16  bathrooms                    60133 non-null  float64
#  17  bedrooms                     76402 non-null  float64
#  18  beds                         60083 non-null  float64
#  19  amenities                    83128 non-null  object
#  20  price                        60092 non-null  object
#  21  minimum_nights               83128 non-null  int64
#  22  maximum_nights               83128 non-null  int64
#  23  calendar_updated             0 non-null      float64
#  24  has_availability             78734 non-null  object
#  25  availability_30              83128 non-null  int64
#  26  number_of_reviews            83128 non-null  int64
#  27  number_of_reviews_l30d       83128 non-null  int64
#  28  review_scores_rating         57916 non-null  float64
#  29  review_scores_accuracy       57882 non-null  float64
#  30  review_scores_cleanliness    57886 non-null  float64
#  31  review_scores_checkin        57873 non-null  float64
#  32  review_scores_communication  57884 non-null  float64
#  33  review_scores_location       57876 non-null  float64
#  34  review_scores_value          57871 non-null  float64
#  35  reviews_per_month            57911 non-null  float64
# dtypes: float64(15), int64(8), object(13)
# memory usage: 23.5+ MB

# %%
df['host_response_time'] = df['host_response_time'].fillna('No response')
df['host_is_superhost'] = df['host_is_superhost'].fillna('f')
df['host_has_profile_pic'] = df['host_has_profile_pic'].fillna('f')
df['host_identity_verified'] = df['host_identity_verified'].fillna('f')

# 비율형 데이터는 0으로 대체하거나 비율 계산에 사용
df['host_response_rate'] = df['host_response_rate'].str.rstrip('%').astype('float') / 100.0
df['host_response_rate'] = df['host_response_rate'].fillna(0)

df['host_acceptance_rate'] = df['host_acceptance_rate'].str.rstrip('%').astype('float') / 100.0
df['host_acceptance_rate'] = df['host_acceptance_rate'].fillna(0)

# 리뷰 관련 컬럼 결측치는 0으로 대체
review_columns = ['review_scores_value', 'reviews_per_month']
for column in review_columns:
    df[column] = df[column].fillna(0)
# Out:
# C:\Users\evol0\AppData\Local\Temp\ipykernel_29668\658535595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['host_response_time'] = df['host_response_time'].fillna('No response')
# C:\Users\evol0\AppData\Local\Temp\ipykernel_29668\658535595.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['host_is_superhost'] = df['host_is_superhost'].fillna('f')
# C:\Users\evol0\AppData\Local\Temp\ipykernel_29668\658535595.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['host_has_profile_pic'] = df['host_has_profile_pic'].fillna('f')
# C:\Users\evol0\AppData\Local\Temp\ipykernel_29668\658535595.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['host_identity_verified'] = df['host_identity_verified'].fillna('f')
# C:\Users\evol0\AppData\Local\Temp\ipykernel_29668\658535595.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['host_response_rate'] = df['host_response_rate'].str.rstrip('%').astype('float') / 100.0
# C:\Users\evol0\AppData\Local\Temp\ipykernel_29668\658535595.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['host_response_rate'] = df['host_response_rate'].fillna(0)
# C:\Users\evol0\AppData\Local\Temp\ipykernel_29668\658535595.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['host_acceptance_rate'] = df['host_acceptance_rate'].str.rstrip('%').astype('float') / 100.0
# C:\Users\evol0\AppData\Local\Temp\ipykernel_29668\658535595.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['host_acceptance_rate'] = df['host_acceptance_rate'].fillna(0)
# C:\Users\evol0\AppData\Local\Temp\ipykernel_29668\658535595.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].fillna(0)
