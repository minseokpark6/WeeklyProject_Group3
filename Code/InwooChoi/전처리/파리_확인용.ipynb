# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
from matplotlib import font_manager, rc
# %matplotlib inline

# 글꼴 경로 지정
font_path = "c:/Windows/Fonts/malgun.ttf"  # 윈도우에 설치된 맑은 고딕 폰트 경로

# 폰트 이름 얻어오기
font_name = font_manager.FontProperties(fname=font_path).get_name()

# matplotlib의 rc(run command) 기능을 이용하여 글꼴 설정
mpl.rc('font', family=font_name)

# 유니코드에서  음수 부호 설정
mpl.rc('axes', unicode_minus=False)

path='../../../../../datasets/paris_listings.csv'
raw = pd.read_csv(path)
df = raw.copy()

df = df[['id', 'host_id','host_is_superhost',
        'host_total_listings_count','neighbourhood_cleansed','room_type','accommodates','bathrooms','bedrooms',
        'beds','amenities','price','minimum_nights','maximum_nights','number_of_reviews', 'number_of_reviews_l30d', 'review_scores_rating', 'review_scores_accuracy', 
        'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 
        'review_scores_location', 'review_scores_value', 'reviews_per_month','listing_url','property_type','number_of_reviews_ltm','has_availability','last_review']]

df = df.rename(columns= {
    'id': '숙소_id',
    'host_id': '호스트_id',
    'host_is_superhost': '슈퍼호스트',
    'host_total_listings_count': '숙소_수',
    'neighbourhood_cleansed': '숙소_지역',
    'room_type': '숙소_유형',
    'accommodates': '수용_인원수',
    'bathrooms': '욕실수',
    'bedrooms': '침실수',
    'beds': '침대수',
    'amenities': '편의시설',
    'price': '숙소_가격',
    'minimum_nights': '최소_숙박일',
    'maximum_nights': '최대_숙박일',
    'number_of_reviews': '리뷰수',
    'number_of_reviews_l30d': '30일_리뷰수',
    'review_scores_rating': '리뷰점수',
    'review_scores_accuracy': '숙소_정확성_리뷰점수',
    'review_scores_cleanliness': '숙소_청결도_리뷰점수',
    'review_scores_checkin': '숙소_체크인_리뷰점수',
    'review_scores_communication': '숙소_소통_리뷰점수',
    'review_scores_location': '숙소_위치_리뷰점수',
    'review_scores_value': '숙소_가격_리뷰점수',
    'reviews_per_month': '평균_리뷰수',
    'listing_url':'url',
    'property_type':'숙소_특징',
    'number_of_reviews_ltm':'12개월_리뷰수',
    'has_availability':'예약가능여부',
    'last_review':'마지막_리뷰'
})

print(len(df[df['리뷰수']==0]))
# 슈퍼호스트, 리뷰수 결측치 제거
print(f"처음 df : {len(df)}")
df = df[~df['슈퍼호스트'].isnull()]
print(f"슈퍼호스트 제거 : {len(df)}")
df = df[df['리뷰수']>2]
print(f"리뷰수 제거 : {len(df)}")

# 숙소가격 null값 제거
df= df[~df['숙소_가격'].isnull()]

#가격 앞 통화기호 제거
df['숙소_가격'] = df['숙소_가격'].replace('[\$,]', '', regex=True).astype(float)

# 유형 제거 
df = df[(df['숙소_유형']=='Entire home/apt') | (df['숙소_유형']=='Private room')]
print(f"숙소_유형 제거 : {len(df)}")

# 12개월 리뷰수 0 개 제거
df = df[df['12개월_리뷰수']!=0]
print(f"12개월_리뷰수 0개 제거 : {len(df)}")

# 욕실수, 침실수, 침대수 null값 제거
df = df.dropna(subset=['욕실수', '침실수', '침대수'])
print(f"욕실수, 침실수, 침대수 제거 후 : {len(df)}")

# 리뷰  null값 제거
df = df.dropna(subset=['숙소_정확성_리뷰점수','숙소_청결도_리뷰점수','숙소_체크인_리뷰점수','숙소_소통_리뷰점수','숙소_위치_리뷰점수','숙소_가격_리뷰점수'])
print(f"리뷰 결측치 제거 후 : {len(df)}")

# 예약 가능여부 f 버리기
df = df.dropna(subset='예약가능여부')
print(f"예약가능여부 : {len(df)}")

df_guest_prefer= df[(df['리뷰점수'] >= 4.9) & (df['리뷰수'] >= 5) & (df['슈퍼호스트'] == 't')]
df_non_guest_prefer = df[(df['슈퍼호스트'] == 'f') & (df['리뷰수'] >= 5)].sort_values('리뷰점수', ascending=True).head(4716)
# Out:
# 25576
# 처음 df : 84397
# 슈퍼호스트 제거 : 84306
# 리뷰수 제거 : 47841
# 숙소_유형 제거 : 34280
# 12개월_리뷰수 0개 제거 : 31052
# 욕실수, 침실수, 침대수 제거 후 : 30997
# 리뷰 결측치 제거 후 : 30997
# 예약가능여부 : 30990

# %% [markdown]
# # 게스트 선호,비선호 비교

# %%
df['편의시설'].unique()
# Out:
# array(['["Lockbox", "Wifi", "Kitchen", "Refrigerator", "Hangers", "Coffee maker", "Host greets you", "Hot water", "Iron", "Hair dryer", "Paid parking garage on premises \\u2013 1 space", "Shampoo", "Smoke alarm", "Essentials", "Self check-in", "Bed linens", "TV", "Dishes and silverware", "Oven", "Heating", "Paid street parking off premises", "Microwave", "Cooking basics"]',
#        '["Cooking basics", "Long term stays allowed", "Wifi", "Dedicated workspace", "TV with standard cable", "Hangers", "Bed linens", "Heating", "Iron", "Fire extinguisher", "Body soap", "Shampoo", "Hair dryer", "Host greets you", "Kitchen", "Hot water", "Coffee maker: espresso machine, pour-over coffee", "Coffee", "Extra pillows and blankets", "Stove", "Hot water kettle", "Cleaning products", "Essentials", "Wine glasses", "Smoke alarm", "Baking sheet", "Books and reading material", "First aid kit", "Drying rack for clothing", "Portable fans", "Shower gel", "Refrigerator", "Dishes and silverware", "Toaster", "Oven", "Washer", "Clothing storage: closet"]',
#        '["Shampoo", "Kitchen", "Washer", "Cooking basics", "Elevator", "Coffee maker", "Refrigerator", "Iron", "Indoor fireplace", "Paid parking off premises", "Dishes and silverware", "Luggage dropoff allowed", "Hair dryer", "Oven", "Microwave", "TV with standard cable", "Hangers", "Wifi", "Lockbox", "Dishwasher", "Heating", "Smoke alarm", "Hot water", "Self check-in", "Game console", "Essentials"]',
#        ...,
#        '["Cooking basics", "Wifi", "Hangers", "Bed linens", "Stainless steel oven", "Dishwasher", "Iron", "Hair dryer", "Kitchen", "Blender", "Hot water", "Wine glasses", "Essentials", "Smoke alarm", "Baking sheet", "Coffee maker: espresso machine", "Drying rack for clothing", "Radiant heating", "Refrigerator", "Dishes and silverware", "Toaster", "Clothing storage: walk-in closet, closet, wardrobe, and dresser", "Washer", "TV", "Dining table", "Microwave", "Free dryer", "Freezer"]',
#        '["Cooking basics", "Pets allowed", "Hangers", "Iron", "Smoking allowed", "Fire extinguisher", "Paid parking on premises", "Coffee maker", "Shampoo", "Hair dryer", "Kitchen", "Hot water", "Coffee", "Extra pillows and blankets", "Wine glasses", "Cleaning products", "Essentials", "Smoke alarm", "Carbon monoxide alarm", "First aid kit", "Shower gel", "Refrigerator", "Dishes and silverware", "Toaster", "Oven", "Washer", "TV", "Dining table", "Microwave"]',
#        '["Cooking basics", "Heating", "Bed linens", "Dishwasher", "Fire extinguisher", "Paid parking on premises", "Coffee maker", "Clothing storage", "Courtyard view", "Hair dryer", "Host greets you", "Kitchen", "Backyard", "Bathtub", "Hot water", "Hot water kettle", "Stove", "Smoke alarm", "Baking sheet", "Rice maker", "Carbon monoxide alarm", "Drying rack for clothing", "Room-darkening shades", "Refrigerator", "Dishes and silverware", "Toaster", "Oven", "Washer", "Microwave", "Freezer"]'],
#       dtype=object)

# %%
# 모든 편의시설을 파싱하여 유니크한 편의시설 세트 생성
amenities_set = set()
df['amenities'].apply(lambda x: amenities_set.update(eval(x)))

# 각 편의시설에 대해 이진 특성 열을 데이터프레임에 추가
for amenity in amenities_set:
    df[amenity] = df['amenities'].apply(lambda x: amenity in eval(x))

# 'amenities' 열 삭제 (옵션)
df.drop('amenities', axis=1, inplace=True)

print(df)
# Out:
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# ...
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2642709407.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[amenity] = df['편의시설'].apply(lambda x: amenity in eval(x))
#                      숙소_id     호스트_id 슈퍼호스트  숙소_수              숙소_지역  \
# 1                   165409     788732     t   1.0             Temple
# 2                     5396       7903     f   3.0     Hôtel-de-Ville
# 3                   166370     793032     f   3.0           Entrepôt
# 6                     7397       2626     t   9.0     Hôtel-de-Ville
# 8                    41106     177387     t   2.0     Hôtel-de-Ville
# ...                    ...        ...   ...   ...                ...
# 82649  1103696635979533455  564997552     f   1.0  Buttes-Montmartre
# 82975  1104437899838519130   13118197     f   2.0  Buttes-Montmartre
# 83073  1105169305670543918   13262987     f   2.0  Buttes-Montmartre
# 83158  1105941359456285384  344916015     f  27.0       Observatoire
# 83393  1107148961327481954   36120497     f   1.0            Reuilly
#
#                  숙소_유형  수용_인원수  욕실수  침실수  침대수  ...  Proline  refrigerator  \
# 1      Entire home/apt       2  1.0  0.0  1.0  ...                  False
# 2      Entire home/apt       2  1.0  0.0  1.0  ...                  False
# 3      Entire home/apt       4  1.0  1.0  1.0  ...                  False
# 6      Entire home/apt       4  1.0  2.0  2.0  ...                  False
# 8      Entire home/apt       4  1.0  1.0  2.0  ...                  False
# ...                ...     ...  ...  ...  ...  ...                    ...
# 82649     Private room       2  1.0  1.0  1.0  ...                  False
# 82975  Entire home/apt       2  1.0  1.0  0.0  ...                  False
# 83073  Entire home/apt       4  1.0  2.0  2.0  ...                  False
# 83158  Entire home/apt       6  1.0  2.0  3.0  ...                  False
# 83393  Entire home/apt       5  1.0  1.0  3.0  ...                  False
#
#        H/K sound system with Bluetooth and aux  Naturel bio body soap  \
# 1                                        False                  False
# 2                                        False                  False
# 3                                        False                  False
# 6                                        False                  False
# 8                                        False                  False
# ...                                        ...                    ...
# 82649                                    False                  False
# 82975                                    False                  False
# 83073                                    False                  False
# 83158                                    False                  False
# 83393                                    False                  False
#
#        Fast wifi – 681 Mbps  \
# 1                     False
# 2                     False
# 3                     False
# 6                     False
# 8                     False
# ...                     ...
# 82649                 False
# 82975                 False
# 83073                 False
# 83158                 False
# 83393                 False
#
#        65" HDTV with Amazon Prime Video, Apple TV, Netflix, standard cable  \
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 6                                                  False
# 8                                                  False
# ...                                                  ...
# 82649                                              False
# 82975                                              False
# 83073                                              False
# 83158                                              False
# 83393                                              False
#
#        ROSIERES stainless steel single oven  BION shampoo  \
# 1                                     False         False
# 2                                     False         False
# 3                                     False         False
# 6                                     False         False
# 8                                     False         False
# ...                                     ...           ...
# 82649                                 False         False
# 82975                                 False         False
# 83073                                 False         False
# 83158                                 False         False
# 83393                                 False         False
#
#        42" HDTV with Amazon Prime Video, Chromecast, Fire TV, Netflix, standard cable  \
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 6                                                  False
# 8                                                  False
# ...                                                  ...
# 82649                                              False
# 82975                                              False
# 83073                                              False
# 83158                                              False
# 83393                                              False
#
#        55" HDTV with Amazon Prime Video, Chromecast, Netflix, Disney+, Apple TV  \
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 6                                                  False
# 8                                                  False
# ...                                                  ...
# 82649                                              False
# 82975                                              False
# 83073                                              False
# 83158                                              False
# 83393                                              False
#
#        42" HDTV with Netflix, standard cable
# 1                                      False
# 2                                      False
# 3                                      False
# 6                                      False
# 8                                      False
# ...                                      ...
# 82649                                  False
# 82975                                  False
# 83073                                  False
# 83158                                  False
# 83393                                  False
#
# [30990 rows x 6639 columns]

# %%
df.head()
# Out:
#     숙소_id  호스트_id 슈퍼호스트  숙소_수           숙소_지역            숙소_유형  수용_인원수  욕실수  \
# 1  165409  788732     t   1.0          Temple  Entire home/apt       2  1.0
# 2    5396    7903     f   3.0  Hôtel-de-Ville  Entire home/apt       2  1.0
# 3  166370  793032     f   3.0        Entrepôt  Entire home/apt       4  1.0
# 6    7397    2626     t   9.0  Hôtel-de-Ville  Entire home/apt       4  1.0
# 8   41106  177387     t   2.0  Hôtel-de-Ville  Entire home/apt       4  1.0
#
#    침실수  침대수  ...  Proline  refrigerator  \
# 1  0.0  1.0  ...                  False
# 2  0.0  1.0  ...                  False
# 3  1.0  1.0  ...                  False
# 6  2.0  2.0  ...                  False
# 8  1.0  2.0  ...                  False
#
#    H/K sound system with Bluetooth and aux  Naturel bio body soap  \
# 1                                    False                  False
# 2                                    False                  False
# 3                                    False                  False
# 6                                    False                  False
# 8                                    False                  False
#
#    Fast wifi – 681 Mbps  \
# 1                 False
# 2                 False
# 3                 False
# 6                 False
# 8                 False
#
#    65" HDTV with Amazon Prime Video, Apple TV, Netflix, standard cable  \
# 1                                              False
# 2                                              False
# 3                                              False
# 6                                              False
# 8                                              False
#
#    ROSIERES stainless steel single oven  BION shampoo  \
# 1                                 False         False
# 2                                 False         False
# 3                                 False         False
# 6                                 False         False
# 8                                 False         False
#
#    42" HDTV with Amazon Prime Video, Chromecast, Fire TV, Netflix, standard cable  \
# 1                                              False
# 2                                              False
# 3                                              False
# 6                                              False
# 8                                              False
#
#    55" HDTV with Amazon Prime Video, Chromecast, Netflix, Disney+, Apple TV  \
# 1                                              False
# 2                                              False
# 3                                              False
# 6                                              False
# 8                                              False
#
#    42" HDTV with Netflix, standard cable
# 1                                  False
# 2                                  False
# 3                                  False
# 6                                  False
# 8                                  False
#
# [5 rows x 6639 columns]

# %%
df_guest_prefer= df[(df['리뷰점수'] >= 4.9) & (df['리뷰수'] >= 5) & (df['슈퍼호스트'] == 't')]
df_non_guest_prefer = df[(df['슈퍼호스트'] == 'f') & (df['리뷰수'] >= 5)].sort_values('리뷰점수', ascending=True).head(4716)

# %%
#df_guest_prefer.to_csv('../../../../../datasets/paris_prefer.csv',index=False)
#df_non_guest_prefer.to_csv('../../../../../datasets/paris_non_prefer.csv',index=False)

# %%
df_guest_prefer = pd.read_csv('../../../../../datasets/paris_prefer.csv')
df_non_guest_prefer = pd.read_csv('../../../../../datasets/paris_non_prefer.csv')

# %%
# 모든 열 이름을 소문자로 변환하여 'tv'를 포함하는 모든 편의시설 찾기
tv_columns = [col for col in df.columns if 'tv' in col.lower()]

# 하나의 'TV' 열 생성
df['TV'] = df[tv_columns].any(axis=1)

# 기존의 TV 관련 열 삭제
df.drop(columns=tv_columns, inplace=True)

print(df)
# Out:
#                      숙소_id     호스트_id 슈퍼호스트  숙소_수              숙소_지역  \
# 1                   165409     788732     t   1.0             Temple
# 2                     5396       7903     f   3.0     Hôtel-de-Ville
# 3                   166370     793032     f   3.0           Entrepôt
# 6                     7397       2626     t   9.0     Hôtel-de-Ville
# 8                    41106     177387     t   2.0     Hôtel-de-Ville
# ...                    ...        ...   ...   ...                ...
# 82649  1103696635979533455  564997552     f   1.0  Buttes-Montmartre
# 82975  1104437899838519130   13118197     f   2.0  Buttes-Montmartre
# 83073  1105169305670543918   13262987     f   2.0  Buttes-Montmartre
# 83158  1105941359456285384  344916015     f  27.0       Observatoire
# 83393  1107148961327481954   36120497     f   1.0            Reuilly
#
#                  숙소_유형  수용_인원수  욕실수  침실수  침대수  ...  \
# 1      Entire home/apt       2  1.0  0.0  1.0  ...
# 2      Entire home/apt       2  1.0  0.0  1.0  ...
# 3      Entire home/apt       4  1.0  1.0  1.0  ...
# 6      Entire home/apt       4  1.0  2.0  2.0  ...
# 8      Entire home/apt       4  1.0  1.0  2.0  ...
# ...                ...     ...  ...  ...  ...  ...
# 82649     Private room       2  1.0  1.0  1.0  ...
# 82975  Entire home/apt       2  1.0  1.0  0.0  ...
# 83073  Entire home/apt       4  1.0  2.0  2.0  ...
# 83158  Entire home/apt       6  1.0  2.0  3.0  ...
# 83393  Entire home/apt       5  1.0  1.0  3.0  ...
#
#        MKL GREEN NATURE body soap  Scholtès stainless steel induction stove  \
# 1                           False                                     False
# 2                           False                                     False
# 3                           False                                     False
# 6                           False                                     False
# 8                           False                                     False
# ...                           ...                                       ...
# 82649                       False                                     False
# 82975                       False                                     False
# 83073                       False                                     False
# 83158                       False                                     False
# 83393                       False                                     False
#
#        Organic body soap  Savon français  body soap  Proline  refrigerator  \
# 1                  False                      False                  False
# 2                  False                      False                  False
# 3                  False                      False                  False
# 6                  False                      False                  False
# 8                  False                      False                  False
# ...                  ...                        ...                    ...
# 82649              False                      False                  False
# 82975              False                      False                  False
# 83073              False                      False                  False
# 83158              False                      False                  False
# 83393              False                      False                  False
#
#        H/K sound system with Bluetooth and aux  Naturel bio body soap  \
# 1                                        False                  False
# 2                                        False                  False
# 3                                        False                  False
# 6                                        False                  False
# 8                                        False                  False
# ...                                        ...                    ...
# 82649                                    False                  False
# 82975                                    False                  False
# 83073                                    False                  False
# 83158                                    False                  False
# 83393                                    False                  False
#
#        ROSIERES stainless steel single oven  BION shampoo   Wifi
# 1                                     False         False  False
# 2                                     False         False  False
# 3                                     False         False  False
# 6                                     False         False  False
# 8                                     False         False  False
# ...                                     ...           ...    ...
# 82649                                 False         False  False
# 82975                                 False         False  False
# 83073                                 False         False  False
# 83158                                 False         False  False
# 83393                                 False         False  False
#
# [30990 rows x 4176 columns]

# %%
# 모든 열 이름을 소문자로 변환하여 'tv'를 포함하는 모든 편의시설 찾기
wifi_columns = [col for col in df.columns if 'wifi' in col.lower()]

# 하나의 'TV' 열 생성
df['Wifi'] = df[wifi_columns].any(axis=1)

# 기존의 TV 관련 열 삭제
df.drop(columns=wifi_columns, inplace=True)

print(df)
# Out:
#                      숙소_id     호스트_id 슈퍼호스트  숙소_수              숙소_지역  \
# 1                   165409     788732     t   1.0             Temple
# 2                     5396       7903     f   3.0     Hôtel-de-Ville
# 3                   166370     793032     f   3.0           Entrepôt
# 6                     7397       2626     t   9.0     Hôtel-de-Ville
# 8                    41106     177387     t   2.0     Hôtel-de-Ville
# ...                    ...        ...   ...   ...                ...
# 82649  1103696635979533455  564997552     f   1.0  Buttes-Montmartre
# 82975  1104437899838519130   13118197     f   2.0  Buttes-Montmartre
# 83073  1105169305670543918   13262987     f   2.0  Buttes-Montmartre
# 83158  1105941359456285384  344916015     f  27.0       Observatoire
# 83393  1107148961327481954   36120497     f   1.0            Reuilly
#
#                  숙소_유형  수용_인원수  욕실수  침실수  침대수  ...  \
# 1      Entire home/apt       2  1.0  0.0  1.0  ...
# 2      Entire home/apt       2  1.0  0.0  1.0  ...
# 3      Entire home/apt       4  1.0  1.0  1.0  ...
# 6      Entire home/apt       4  1.0  2.0  2.0  ...
# 8      Entire home/apt       4  1.0  1.0  2.0  ...
# ...                ...     ...  ...  ...  ...  ...
# 82649     Private room       2  1.0  1.0  1.0  ...
# 82975  Entire home/apt       2  1.0  1.0  0.0  ...
# 83073  Entire home/apt       4  1.0  2.0  2.0  ...
# 83158  Entire home/apt       6  1.0  2.0  3.0  ...
# 83393  Entire home/apt       5  1.0  1.0  3.0  ...
#
#        Rosière stainless steel induction stove  MKL GREEN NATURE body soap  \
# 1                                        False                       False
# 2                                        False                       False
# 3                                        False                       False
# 6                                        False                       False
# 8                                        False                       False
# ...                                        ...                         ...
# 82649                                    False                       False
# 82975                                    False                       False
# 83073                                    False                       False
# 83158                                    False                       False
# 83393                                    False                       False
#
#        Scholtès stainless steel induction stove  Organic body soap  \
# 1                                         False              False
# 2                                         False              False
# 3                                         False              False
# 6                                         False              False
# 8                                         False              False
# ...                                         ...                ...
# 82649                                     False              False
# 82975                                     False              False
# 83073                                     False              False
# 83158                                     False              False
# 83393                                     False              False
#
#        Savon français  body soap  Proline  refrigerator  \
# 1                          False                  False
# 2                          False                  False
# 3                          False                  False
# 6                          False                  False
# 8                          False                  False
# ...                          ...                    ...
# 82649                      False                  False
# 82975                      False                  False
# 83073                      False                  False
# 83158                      False                  False
# 83393                      False                  False
#
#        H/K sound system with Bluetooth and aux  Naturel bio body soap  \
# 1                                        False                  False
# 2                                        False                  False
# 3                                        False                  False
# 6                                        False                  False
# 8                                        False                  False
# ...                                        ...                    ...
# 82649                                    False                  False
# 82975                                    False                  False
# 83073                                    False                  False
# 83158                                    False                  False
# 83393                                    False                  False
#
#        ROSIERES stainless steel single oven  BION shampoo
# 1                                     False         False
# 2                                     False         False
# 3                                     False         False
# 6                                     False         False
# 8                                     False         False
# ...                                     ...           ...
# 82649                                 False         False
# 82975                                 False         False
# 83073                                 False         False
# 83158                                 False         False
# 83393                                 False         False
#
# [30990 rows x 4175 columns]

# %%
df.columns
# Out:
# Index(['숙소_id', '호스트_id', '슈퍼호스트', '숙소_수', '숙소_지역', '숙소_유형', '수용_인원수', '욕실수',
#        '침실수', '침대수',
#        ...
#        'Rosière stainless steel induction stove', 'MKL GREEN NATURE body soap',
#        'Scholtès stainless steel induction stove', 'Organic body soap',
#        'Savon français  body soap', 'Proline  refrigerator',
#        'H/K sound system with Bluetooth and aux', 'Naturel bio body soap',
#        'ROSIERES stainless steel single oven', 'BION shampoo'],
#       dtype='object', length=4175)

# %%
len(df[df['Wifi']==True])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ciw96\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Wifi'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 len(df[df['Wifi']==True])
#
# File c:\Users\ciw96\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\ciw96\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Wifi'

# %%
body_columns = [col for col in df.columns if 'body soap' in col.lower()]

# 하나의 'TV' 열 생성
df['body_soup'] = df[body_columns].any(axis=1)

# 기존의 TV 관련 열 삭제
df.drop(columns=body_columns, inplace=True)

print(df)
# Out:
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\4166941544.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['body_soup'] = df[body_columns].any(axis=1)
#                      숙소_id     호스트_id 슈퍼호스트  숙소_수              숙소_지역  \
# 1                   165409     788732     t   1.0             Temple
# 2                     5396       7903     f   3.0     Hôtel-de-Ville
# 3                   166370     793032     f   3.0           Entrepôt
# 6                     7397       2626     t   9.0     Hôtel-de-Ville
# 8                    41106     177387     t   2.0     Hôtel-de-Ville
# ...                    ...        ...   ...   ...                ...
# 82649  1103696635979533455  564997552     f   1.0  Buttes-Montmartre
# 82975  1104437899838519130   13118197     f   2.0  Buttes-Montmartre
# 83073  1105169305670543918   13262987     f   2.0  Buttes-Montmartre
# 83158  1105941359456285384  344916015     f  27.0       Observatoire
# 83393  1107148961327481954   36120497     f   1.0            Reuilly
#
#                  숙소_유형  수용_인원수  욕실수  침실수  침대수  ...  IKEA induction stove  \
# 1      Entire home/apt       2  1.0  0.0  1.0  ...                 False
# 2      Entire home/apt       2  1.0  0.0  1.0  ...                 False
# 3      Entire home/apt       4  1.0  1.0  1.0  ...                 False
# 6      Entire home/apt       4  1.0  2.0  2.0  ...                 False
# 8      Entire home/apt       4  1.0  1.0  2.0  ...                 False
# ...                ...     ...  ...  ...  ...  ...                   ...
# 82649     Private room       2  1.0  1.0  1.0  ...                 False
# 82975  Entire home/apt       2  1.0  1.0  0.0  ...                 False
# 83073  Entire home/apt       4  1.0  2.0  2.0  ...                 False
# 83158  Entire home/apt       6  1.0  2.0  3.0  ...                 False
# 83393  Entire home/apt       5  1.0  1.0  3.0  ...                 False
#
#        Sumsumg  sound system with Bluetooth and aux  All kind conditioner  \
# 1                                             False                 False
# 2                                             False                 False
# 3                                             False                 False
# 6                                             False                 False
# 8                                             False                 False
# ...                                             ...                   ...
# 82649                                         False                 False
# 82975                                         False                 False
# 83073                                         False                 False
# 83158                                         False                 False
# 83393                                         False                 False
#
#        Rosière stainless steel induction stove  \
# 1                                        False
# 2                                        False
# 3                                        False
# 6                                        False
# 8                                        False
# ...                                        ...
# 82649                                    False
# 82975                                    False
# 83073                                    False
# 83158                                    False
# 83393                                    False
#
#        Scholtès stainless steel induction stove  Proline  refrigerator  \
# 1                                         False                  False
# 2                                         False                  False
# 3                                         False                  False
# 6                                         False                  False
# 8                                         False                  False
# ...                                         ...                    ...
# 82649                                     False                  False
# 82975                                     False                  False
# 83073                                     False                  False
# 83158                                     False                  False
# 83393                                     False                  False
#
#        H/K sound system with Bluetooth and aux  \
# 1                                        False
# 2                                        False
# 3                                        False
# 6                                        False
# 8                                        False
# ...                                        ...
# 82649                                    False
# 82975                                    False
# 83073                                    False
# 83158                                    False
# 83393                                    False
#
#        ROSIERES stainless steel single oven  BION shampoo  body_soup
# 1                                     False         False      False
# 2                                     False         False       True
# 3                                     False         False      False
# 6                                     False         False      False
# 8                                     False         False       True
# ...                                     ...           ...        ...
# 82649                                 False         False       True
# 82975                                 False         False       True
# 83073                                 False         False      False
# 83158                                 False         False      False
# 83393                                 False         False      False
#
# [30990 rows x 3373 columns]

# %%
shampoo_columns = [col for col in df.columns if 'shampoo' in col.lower()]
# 하나의 'TV' 열 생성
df['shampoo'] = df[shampoo_columns].any(axis=1)

# 기존의 TV 관련 열 삭제
df.drop(columns=shampoo_columns, inplace=True)

print(df)
# Out:
#                      숙소_id     호스트_id 슈퍼호스트  숙소_수              숙소_지역  \
# 1                   165409     788732     t   1.0             Temple
# 2                     5396       7903     f   3.0     Hôtel-de-Ville
# 3                   166370     793032     f   3.0           Entrepôt
# 6                     7397       2626     t   9.0     Hôtel-de-Ville
# 8                    41106     177387     t   2.0     Hôtel-de-Ville
# ...                    ...        ...   ...   ...                ...
# 82649  1103696635979533455  564997552     f   1.0  Buttes-Montmartre
# 82975  1104437899838519130   13118197     f   2.0  Buttes-Montmartre
# 83073  1105169305670543918   13262987     f   2.0  Buttes-Montmartre
# 83158  1105941359456285384  344916015     f  27.0       Observatoire
# 83393  1107148961327481954   36120497     f   1.0            Reuilly
#
#                  숙소_유형  수용_인원수  욕실수  침실수  침대수  ...  IKEA induction stove  \
# 1      Entire home/apt       2  1.0  0.0  1.0  ...                 False
# 2      Entire home/apt       2  1.0  0.0  1.0  ...                 False
# 3      Entire home/apt       4  1.0  1.0  1.0  ...                 False
# 6      Entire home/apt       4  1.0  2.0  2.0  ...                 False
# 8      Entire home/apt       4  1.0  1.0  2.0  ...                 False
# ...                ...     ...  ...  ...  ...  ...                   ...
# 82649     Private room       2  1.0  1.0  1.0  ...                 False
# 82975  Entire home/apt       2  1.0  1.0  0.0  ...                 False
# 83073  Entire home/apt       4  1.0  2.0  2.0  ...                 False
# 83158  Entire home/apt       6  1.0  2.0  3.0  ...                 False
# 83393  Entire home/apt       5  1.0  1.0  3.0  ...                 False
#
#        Sumsumg  sound system with Bluetooth and aux  All kind conditioner  \
# 1                                             False                 False
# 2                                             False                 False
# 3                                             False                 False
# 6                                             False                 False
# 8                                             False                 False
# ...                                             ...                   ...
# 82649                                         False                 False
# 82975                                         False                 False
# 83073                                         False                 False
# 83158                                         False                 False
# 83393                                         False                 False
#
#        Rosière stainless steel induction stove  \
# 1                                        False
# 2                                        False
# 3                                        False
# 6                                        False
# 8                                        False
# ...                                        ...
# 82649                                    False
# 82975                                    False
# 83073                                    False
# 83158                                    False
# 83393                                    False
#
#        Scholtès stainless steel induction stove  Proline  refrigerator  \
# 1                                         False                  False
# 2                                         False                  False
# 3                                         False                  False
# 6                                         False                  False
# 8                                         False                  False
# ...                                         ...                    ...
# 82649                                     False                  False
# 82975                                     False                  False
# 83073                                     False                  False
# 83158                                     False                  False
# 83393                                     False                  False
#
#        H/K sound system with Bluetooth and aux  \
# 1                                        False
# 2                                        False
# 3                                        False
# 6                                        False
# 8                                        False
# ...                                        ...
# 82649                                    False
# 82975                                    False
# 83073                                    False
# 83158                                    False
# 83393                                    False
#
#        ROSIERES stainless steel single oven  body_soup  shampoo
# 1                                     False      False     True
# 2                                     False       True     True
# 3                                     False      False     True
# 6                                     False      False     True
# 8                                     False       True     True
# ...                                     ...        ...      ...
# 82649                                 False       True    False
# 82975                                 False       True    False
# 83073                                 False      False    False
# 83158                                 False      False     True
# 83393                                 False      False    False
#
# [30990 rows x 2770 columns]
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2161529706.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['shampoo'] = df[shampoo_columns].any(axis=1)

# %%
df
# Out:
#                      숙소_id     호스트_id 슈퍼호스트  숙소_수              숙소_지역  \
# 1                   165409     788732     t   1.0             Temple
# 2                     5396       7903     f   3.0     Hôtel-de-Ville
# 3                   166370     793032     f   3.0           Entrepôt
# 6                     7397       2626     t   9.0     Hôtel-de-Ville
# 8                    41106     177387     t   2.0     Hôtel-de-Ville
# ...                    ...        ...   ...   ...                ...
# 82649  1103696635979533455  564997552     f   1.0  Buttes-Montmartre
# 82975  1104437899838519130   13118197     f   2.0  Buttes-Montmartre
# 83073  1105169305670543918   13262987     f   2.0  Buttes-Montmartre
# 83158  1105941359456285384  344916015     f  27.0       Observatoire
# 83393  1107148961327481954   36120497     f   1.0            Reuilly
#
#                  숙소_유형  수용_인원수  욕실수  침실수  침대수  ...  IKEA induction stove  \
# 1      Entire home/apt       2  1.0  0.0  1.0  ...                 False
# 2      Entire home/apt       2  1.0  0.0  1.0  ...                 False
# 3      Entire home/apt       4  1.0  1.0  1.0  ...                 False
# 6      Entire home/apt       4  1.0  2.0  2.0  ...                 False
# 8      Entire home/apt       4  1.0  1.0  2.0  ...                 False
# ...                ...     ...  ...  ...  ...  ...                   ...
# 82649     Private room       2  1.0  1.0  1.0  ...                 False
# 82975  Entire home/apt       2  1.0  1.0  0.0  ...                 False
# 83073  Entire home/apt       4  1.0  2.0  2.0  ...                 False
# 83158  Entire home/apt       6  1.0  2.0  3.0  ...                 False
# 83393  Entire home/apt       5  1.0  1.0  3.0  ...                 False
#
#        Sumsumg  sound system with Bluetooth and aux  All kind conditioner  \
# 1                                             False                 False
# 2                                             False                 False
# 3                                             False                 False
# 6                                             False                 False
# 8                                             False                 False
# ...                                             ...                   ...
# 82649                                         False                 False
# 82975                                         False                 False
# 83073                                         False                 False
# 83158                                         False                 False
# 83393                                         False                 False
#
#        Rosière stainless steel induction stove  \
# 1                                        False
# 2                                        False
# 3                                        False
# 6                                        False
# 8                                        False
# ...                                        ...
# 82649                                    False
# 82975                                    False
# 83073                                    False
# 83158                                    False
# 83393                                    False
#
#        Scholtès stainless steel induction stove  Proline  refrigerator  \
# 1                                         False                  False
# 2                                         False                  False
# 3                                         False                  False
# 6                                         False                  False
# 8                                         False                  False
# ...                                         ...                    ...
# 82649                                     False                  False
# 82975                                     False                  False
# 83073                                     False                  False
# 83158                                     False                  False
# 83393                                     False                  False
#
#        H/K sound system with Bluetooth and aux  \
# 1                                        False
# 2                                        False
# 3                                        False
# 6                                        False
# 8                                        False
# ...                                        ...
# 82649                                    False
# 82975                                    False
# 83073                                    False
# 83158                                    False
# 83393                                    False
#
#        ROSIERES stainless steel single oven  body_soup  shampoo
# 1                                     False      False     True
# 2                                     False       True     True
# 3                                     False      False     True
# 6                                     False      False     True
# 8                                     False       True     True
# ...                                     ...        ...      ...
# 82649                                 False       True    False
# 82975                                 False       True    False
# 83073                                 False      False    False
# 83158                                 False      False     True
# 83393                                 False      False    False
#
# [30990 rows x 2770 columns]

# %%
oven_columns = [col for col in df.columns if 'oven' in col.lower()]

print(len(oven_columns))

df['oven'] = df[oven_columns].any(axis=1)

# 기존의 TV 관련 열 삭제
df.drop(columns=oven_columns, inplace=True)

df
# Out:
# 1
#                      숙소_id     호스트_id 슈퍼호스트  숙소_수              숙소_지역  \
# 1                   165409     788732     t   1.0             Temple
# 2                     5396       7903     f   3.0     Hôtel-de-Ville
# 3                   166370     793032     f   3.0           Entrepôt
# 6                     7397       2626     t   9.0     Hôtel-de-Ville
# 8                    41106     177387     t   2.0     Hôtel-de-Ville
# ...                    ...        ...   ...   ...                ...
# 82649  1103696635979533455  564997552     f   1.0  Buttes-Montmartre
# 82975  1104437899838519130   13118197     f   2.0  Buttes-Montmartre
# 83073  1105169305670543918   13262987     f   2.0  Buttes-Montmartre
# 83158  1105941359456285384  344916015     f  27.0       Observatoire
# 83393  1107148961327481954   36120497     f   1.0            Reuilly
#
#                  숙소_유형  수용_인원수  욕실수  침실수  침대수  ...  \
# 1      Entire home/apt       2  1.0  0.0  1.0  ...
# 2      Entire home/apt       2  1.0  0.0  1.0  ...
# 3      Entire home/apt       4  1.0  1.0  1.0  ...
# 6      Entire home/apt       4  1.0  2.0  2.0  ...
# 8      Entire home/apt       4  1.0  1.0  2.0  ...
# ...                ...     ...  ...  ...  ...  ...
# 82649     Private room       2  1.0  1.0  1.0  ...
# 82975  Entire home/apt       2  1.0  1.0  0.0  ...
# 83073  Entire home/apt       4  1.0  2.0  2.0  ...
# 83158  Entire home/apt       6  1.0  2.0  3.0  ...
# 83393  Entire home/apt       5  1.0  1.0  3.0  ...
#
#        Google speaker sound system  IKEA induction stove  \
# 1                            False                 False
# 2                            False                 False
# 3                            False                 False
# 6                            False                 False
# 8                            False                 False
# ...                            ...                   ...
# 82649                        False                 False
# 82975                        False                 False
# 83073                        False                 False
# 83158                        False                 False
# 83393                        False                 False
#
#        Sumsumg  sound system with Bluetooth and aux  All kind conditioner  \
# 1                                             False                 False
# 2                                             False                 False
# 3                                             False                 False
# 6                                             False                 False
# 8                                             False                 False
# ...                                             ...                   ...
# 82649                                         False                 False
# 82975                                         False                 False
# 83073                                         False                 False
# 83158                                         False                 False
# 83393                                         False                 False
#
#        Rosière stainless steel induction stove  \
# 1                                        False
# 2                                        False
# 3                                        False
# 6                                        False
# 8                                        False
# ...                                        ...
# 82649                                    False
# 82975                                    False
# 83073                                    False
# 83158                                    False
# 83393                                    False
#
#        Scholtès stainless steel induction stove  Proline  refrigerator  \
# 1                                         False                  False
# 2                                         False                  False
# 3                                         False                  False
# 6                                         False                  False
# 8                                         False                  False
# ...                                         ...                    ...
# 82649                                     False                  False
# 82975                                     False                  False
# 83073                                     False                  False
# 83158                                     False                  False
# 83393                                     False                  False
#
#        H/K sound system with Bluetooth and aux  body_soup  shampoo
# 1                                        False      False     True
# 2                                        False       True     True
# 3                                        False      False     True
# 6                                        False      False     True
# 8                                        False       True     True
# ...                                        ...        ...      ...
# 82649                                    False       True    False
# 82975                                    False       True    False
# 83073                                    False      False    False
# 83158                                    False      False     True
# 83393                                    False      False    False
#
# [30990 rows x 2202 columns]

# %%
stove_columns = [col for col in df.columns if 'stove' in col.lower()]

print(len(stove_columns))

df['stove'] = df[stove_columns].any(axis=1)

# 기존의 TV 관련 열 삭제
df.drop(columns=stove_columns, inplace=True)

df
# Out:
# 326
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\133522718.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['stove'] = df[stove_columns].any(axis=1)
#                      숙소_id     호스트_id 슈퍼호스트  숙소_수              숙소_지역  \
# 1                   165409     788732     t   1.0             Temple
# 2                     5396       7903     f   3.0     Hôtel-de-Ville
# 3                   166370     793032     f   3.0           Entrepôt
# 6                     7397       2626     t   9.0     Hôtel-de-Ville
# 8                    41106     177387     t   2.0     Hôtel-de-Ville
# ...                    ...        ...   ...   ...                ...
# 82649  1103696635979533455  564997552     f   1.0  Buttes-Montmartre
# 82975  1104437899838519130   13118197     f   2.0  Buttes-Montmartre
# 83073  1105169305670543918   13262987     f   2.0  Buttes-Montmartre
# 83158  1105941359456285384  344916015     f  27.0       Observatoire
# 83393  1107148961327481954   36120497     f   1.0            Reuilly
#
#                  숙소_유형  수용_인원수  욕실수  침실수  침대수  ...  \
# 1      Entire home/apt       2  1.0  0.0  1.0  ...
# 2      Entire home/apt       2  1.0  0.0  1.0  ...
# 3      Entire home/apt       4  1.0  1.0  1.0  ...
# 6      Entire home/apt       4  1.0  2.0  2.0  ...
# 8      Entire home/apt       4  1.0  1.0  2.0  ...
# ...                ...     ...  ...  ...  ...  ...
# 82649     Private room       2  1.0  1.0  1.0  ...
# 82975  Entire home/apt       2  1.0  1.0  0.0  ...
# 83073  Entire home/apt       4  1.0  2.0  2.0  ...
# 83158  Entire home/apt       6  1.0  2.0  3.0  ...
# 83393  Entire home/apt       5  1.0  1.0  3.0  ...
#
#        Urban Ears Bluetooth sound system  \
# 1                                  False
# 2                                  False
# 3                                  False
# 6                                  False
# 8                                  False
# ...                                  ...
# 82649                              False
# 82975                              False
# 83073                              False
# 83158                              False
# 83393                              False
#
#        Paid parking garage on premises – 1 space  Google speaker sound system  \
# 1                                           True                        False
# 2                                          False                        False
# 3                                          False                        False
# 6                                          False                        False
# 8                                          False                        False
# ...                                          ...                          ...
# 82649                                      False                        False
# 82975                                      False                        False
# 83073                                      False                        False
# 83158                                      False                        False
# 83393                                      False                        False
#
#        Sumsumg  sound system with Bluetooth and aux  All kind conditioner  \
# 1                                             False                 False
# 2                                             False                 False
# 3                                             False                 False
# 6                                             False                 False
# 8                                             False                 False
# ...                                             ...                   ...
# 82649                                         False                 False
# 82975                                         False                 False
# 83073                                         False                 False
# 83158                                         False                 False
# 83393                                         False                 False
#
#        Proline  refrigerator  H/K sound system with Bluetooth and aux  \
# 1                      False                                    False
# 2                      False                                    False
# 3                      False                                    False
# 6                      False                                    False
# 8                      False                                    False
# ...                      ...                                      ...
# 82649                  False                                    False
# 82975                  False                                    False
# 83073                  False                                    False
# 83158                  False                                    False
# 83393                  False                                    False
#
#        body_soup  shampoo  stove
# 1          False     True  False
# 2           True     True   True
# 3          False     True  False
# 6          False     True   True
# 8           True     True   True
# ...          ...      ...    ...
# 82649       True    False  False
# 82975       True    False   True
# 83073      False    False  False
# 83158      False     True  False
# 83393      False    False   True
#
# [30990 rows x 1877 columns]

# %%
refrigerator_columns = [col for col in df.columns if 'refrigerator' in col.lower()]

print(len(refrigerator_columns))

df['refrigerator'] = df[refrigerator_columns].any(axis=1)

# 기존의 TV 관련 열 삭제
df.drop(columns=refrigerator_columns, inplace=True)

df
# Out:
# 342
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\878620967.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['refrigerator'] = df[refrigerator_columns].any(axis=1)
#                      숙소_id     호스트_id 슈퍼호스트  숙소_수              숙소_지역  \
# 1                   165409     788732     t   1.0             Temple
# 2                     5396       7903     f   3.0     Hôtel-de-Ville
# 3                   166370     793032     f   3.0           Entrepôt
# 6                     7397       2626     t   9.0     Hôtel-de-Ville
# 8                    41106     177387     t   2.0     Hôtel-de-Ville
# ...                    ...        ...   ...   ...                ...
# 82649  1103696635979533455  564997552     f   1.0  Buttes-Montmartre
# 82975  1104437899838519130   13118197     f   2.0  Buttes-Montmartre
# 83073  1105169305670543918   13262987     f   2.0  Buttes-Montmartre
# 83158  1105941359456285384  344916015     f  27.0       Observatoire
# 83393  1107148961327481954   36120497     f   1.0            Reuilly
#
#                  숙소_유형  수용_인원수  욕실수  침실수  침대수  ...  \
# 1      Entire home/apt       2  1.0  0.0  1.0  ...
# 2      Entire home/apt       2  1.0  0.0  1.0  ...
# 3      Entire home/apt       4  1.0  1.0  1.0  ...
# 6      Entire home/apt       4  1.0  2.0  2.0  ...
# 8      Entire home/apt       4  1.0  1.0  2.0  ...
# ...                ...     ...  ...  ...  ...  ...
# 82649     Private room       2  1.0  1.0  1.0  ...
# 82975  Entire home/apt       2  1.0  1.0  0.0  ...
# 83073  Entire home/apt       4  1.0  2.0  2.0  ...
# 83158  Entire home/apt       6  1.0  2.0  3.0  ...
# 83393  Entire home/apt       5  1.0  1.0  3.0  ...
#
#        Urban Ears Bluetooth sound system  \
# 1                                  False
# 2                                  False
# 3                                  False
# 6                                  False
# 8                                  False
# ...                                  ...
# 82649                              False
# 82975                              False
# 83073                              False
# 83158                              False
# 83393                              False
#
#        Paid parking garage on premises – 1 space  Google speaker sound system  \
# 1                                           True                        False
# 2                                          False                        False
# 3                                          False                        False
# 6                                          False                        False
# 8                                          False                        False
# ...                                          ...                          ...
# 82649                                      False                        False
# 82975                                      False                        False
# 83073                                      False                        False
# 83158                                      False                        False
# 83393                                      False                        False
#
#        Sumsumg  sound system with Bluetooth and aux  All kind conditioner  \
# 1                                             False                 False
# 2                                             False                 False
# 3                                             False                 False
# 6                                             False                 False
# 8                                             False                 False
# ...                                             ...                   ...
# 82649                                         False                 False
# 82975                                         False                 False
# 83073                                         False                 False
# 83158                                         False                 False
# 83393                                         False                 False
#
#        H/K sound system with Bluetooth and aux  body_soup  shampoo  stove  \
# 1                                        False      False     True  False
# 2                                        False       True     True   True
# 3                                        False      False     True  False
# 6                                        False      False     True   True
# 8                                        False       True     True   True
# ...                                        ...        ...      ...    ...
# 82649                                    False       True    False  False
# 82975                                    False       True    False   True
# 83073                                    False      False    False  False
# 83158                                    False      False     True  False
# 83393                                    False      False    False   True
#
#        refrigerator
# 1              True
# 2              True
# 3              True
# 6              True
# 8              True
# ...             ...
# 82649         False
# 82975          True
# 83073          True
# 83158          True
# 83393          True
#
# [30990 rows x 1536 columns]

# %%
sound_columns = [col for col in df.columns if 'sound' in col.lower()]

print(len(sound_columns))

df['sound'] = df[sound_columns].any(axis=1)

# 기존의 TV 관련 열 삭제
df.drop(columns=sound_columns, inplace=True)

df
# Out:
# 670
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2949588817.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['sound'] = df[sound_columns].any(axis=1)
#                      숙소_id     호스트_id 슈퍼호스트  숙소_수              숙소_지역  \
# 1                   165409     788732     t   1.0             Temple
# 2                     5396       7903     f   3.0     Hôtel-de-Ville
# 3                   166370     793032     f   3.0           Entrepôt
# 6                     7397       2626     t   9.0     Hôtel-de-Ville
# 8                    41106     177387     t   2.0     Hôtel-de-Ville
# ...                    ...        ...   ...   ...                ...
# 82649  1103696635979533455  564997552     f   1.0  Buttes-Montmartre
# 82975  1104437899838519130   13118197     f   2.0  Buttes-Montmartre
# 83073  1105169305670543918   13262987     f   2.0  Buttes-Montmartre
# 83158  1105941359456285384  344916015     f  27.0       Observatoire
# 83393  1107148961327481954   36120497     f   1.0            Reuilly
#
#                  숙소_유형  수용_인원수  욕실수  침실수  침대수  ...  \
# 1      Entire home/apt       2  1.0  0.0  1.0  ...
# 2      Entire home/apt       2  1.0  0.0  1.0  ...
# 3      Entire home/apt       4  1.0  1.0  1.0  ...
# 6      Entire home/apt       4  1.0  2.0  2.0  ...
# 8      Entire home/apt       4  1.0  1.0  2.0  ...
# ...                ...     ...  ...  ...  ...  ...
# 82649     Private room       2  1.0  1.0  1.0  ...
# 82975  Entire home/apt       2  1.0  1.0  0.0  ...
# 83073  Entire home/apt       4  1.0  2.0  2.0  ...
# 83158  Entire home/apt       6  1.0  2.0  3.0  ...
# 83393  Entire home/apt       5  1.0  1.0  3.0  ...
#
#        Exercise equipment: free weights, stationary bike, yoga mat  \
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 6                                                  False
# 8                                                  False
# ...                                                  ...
# 82649                                              False
# 82975                                              False
# 83073                                              False
# 83158                                              False
# 83393                                              False
#
#        Yves Rocher  conditioner  \
# 1                         False
# 2                         False
# 3                         False
# 6                         False
# 8                         False
# ...                         ...
# 82649                     False
# 82975                     False
# 83073                     False
# 83158                     False
# 83393                     False
#
#        Housekeeping available every day - included with your stay  \
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 6                                                  False
# 8                                                  False
# ...                                                  ...
# 82649                                              False
# 82975                                              False
# 83073                                              False
# 83158                                              False
# 83393                                              False
#
#        Paid parking garage on premises – 1 space  All kind conditioner  \
# 1                                           True                 False
# 2                                          False                 False
# 3                                          False                 False
# 6                                          False                 False
# 8                                          False                 False
# ...                                          ...                   ...
# 82649                                      False                 False
# 82975                                      False                 False
# 83073                                      False                 False
# 83158                                      False                 False
# 83393                                      False                 False
#
#        body_soup  shampoo  stove  refrigerator  sound
# 1          False     True  False          True  False
# 2           True     True   True          True  False
# 3          False     True  False          True  False
# 6          False     True   True          True  False
# 8           True     True   True          True   True
# ...          ...      ...    ...           ...    ...
# 82649       True    False  False         False  False
# 82975       True    False   True          True  False
# 83073      False    False  False          True  False
# 83158      False     True  False          True  False
# 83393      False    False   True          True  False
#
# [30990 rows x 867 columns]

# %%
conditioner_columns = [col for col in df.columns if 'conditioner' in col.lower()]

print(len(conditioner_columns))

df['conditioner'] = df[conditioner_columns].any(axis=1)

# 기존의 TV 관련 열 삭제
df.drop(columns=conditioner_columns, inplace=True)

df
# Out:
# 284
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\1724270404.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['conditioner'] = df[conditioner_columns].any(axis=1)
#                      숙소_id     호스트_id 슈퍼호스트  숙소_수              숙소_지역  \
# 1                   165409     788732     t   1.0             Temple
# 2                     5396       7903     f   3.0     Hôtel-de-Ville
# 3                   166370     793032     f   3.0           Entrepôt
# 6                     7397       2626     t   9.0     Hôtel-de-Ville
# 8                    41106     177387     t   2.0     Hôtel-de-Ville
# ...                    ...        ...   ...   ...                ...
# 82649  1103696635979533455  564997552     f   1.0  Buttes-Montmartre
# 82975  1104437899838519130   13118197     f   2.0  Buttes-Montmartre
# 83073  1105169305670543918   13262987     f   2.0  Buttes-Montmartre
# 83158  1105941359456285384  344916015     f  27.0       Observatoire
# 83393  1107148961327481954   36120497     f   1.0            Reuilly
#
#                  숙소_유형  수용_인원수  욕실수  침실수  침대수  ...  Private patio or balcony  \
# 1      Entire home/apt       2  1.0  0.0  1.0  ...                     False
# 2      Entire home/apt       2  1.0  0.0  1.0  ...                     False
# 3      Entire home/apt       4  1.0  1.0  1.0  ...                     False
# 6      Entire home/apt       4  1.0  2.0  2.0  ...                     False
# 8      Entire home/apt       4  1.0  1.0  2.0  ...                     False
# ...                ...     ...  ...  ...  ...  ...                       ...
# 82649     Private room       2  1.0  1.0  1.0  ...                     False
# 82975  Entire home/apt       2  1.0  1.0  0.0  ...                     False
# 83073  Entire home/apt       4  1.0  2.0  2.0  ...                     False
# 83158  Entire home/apt       6  1.0  2.0  3.0  ...                     False
# 83393  Entire home/apt       5  1.0  1.0  3.0  ...                     False
#
#        Exercise equipment: free weights, stationary bike, yoga mat  \
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 6                                                  False
# 8                                                  False
# ...                                                  ...
# 82649                                              False
# 82975                                              False
# 83073                                              False
# 83158                                              False
# 83393                                              False
#
#        Housekeeping available every day - included with your stay  \
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 6                                                  False
# 8                                                  False
# ...                                                  ...
# 82649                                              False
# 82975                                              False
# 83073                                              False
# 83158                                              False
# 83393                                              False
#
#        Paid parking garage on premises – 1 space  body_soup  shampoo  stove  \
# 1                                           True      False     True  False
# 2                                          False       True     True   True
# 3                                          False      False     True  False
# 6                                          False      False     True   True
# 8                                          False       True     True   True
# ...                                          ...        ...      ...    ...
# 82649                                      False       True    False  False
# 82975                                      False       True    False   True
# 83073                                      False      False    False  False
# 83158                                      False      False     True  False
# 83393                                      False      False    False   True
#
#        refrigerator  sound  conditioner
# 1              True  False        False
# 2              True  False        False
# 3              True  False        False
# 6              True  False        False
# 8              True   True        False
# ...             ...    ...          ...
# 82649         False  False        False
# 82975          True  False        False
# 83073          True  False        False
# 83158          True  False        False
# 83393          True  False        False
#
# [30990 rows x 584 columns]

# %%
housekeeping_columns = [col for col in df.columns if 'housekeeping' in col.lower()]

print(len(housekeeping_columns))

df['housekeeping'] = df[housekeeping_columns].any(axis=1)

# 기존의 TV 관련 열 삭제
df.drop(columns=housekeeping_columns, inplace=True)

df
# Out:
# 56
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\3768178896.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['housekeeping'] = df[housekeeping_columns].any(axis=1)
#                      숙소_id     호스트_id 슈퍼호스트  숙소_수              숙소_지역  \
# 1                   165409     788732     t   1.0             Temple
# 2                     5396       7903     f   3.0     Hôtel-de-Ville
# 3                   166370     793032     f   3.0           Entrepôt
# 6                     7397       2626     t   9.0     Hôtel-de-Ville
# 8                    41106     177387     t   2.0     Hôtel-de-Ville
# ...                    ...        ...   ...   ...                ...
# 82649  1103696635979533455  564997552     f   1.0  Buttes-Montmartre
# 82975  1104437899838519130   13118197     f   2.0  Buttes-Montmartre
# 83073  1105169305670543918   13262987     f   2.0  Buttes-Montmartre
# 83158  1105941359456285384  344916015     f  27.0       Observatoire
# 83393  1107148961327481954   36120497     f   1.0            Reuilly
#
#                  숙소_유형  수용_인원수  욕실수  침실수  침대수  ...  Private patio or balcony  \
# 1      Entire home/apt       2  1.0  0.0  1.0  ...                     False
# 2      Entire home/apt       2  1.0  0.0  1.0  ...                     False
# 3      Entire home/apt       4  1.0  1.0  1.0  ...                     False
# 6      Entire home/apt       4  1.0  2.0  2.0  ...                     False
# 8      Entire home/apt       4  1.0  1.0  2.0  ...                     False
# ...                ...     ...  ...  ...  ...  ...                       ...
# 82649     Private room       2  1.0  1.0  1.0  ...                     False
# 82975  Entire home/apt       2  1.0  1.0  0.0  ...                     False
# 83073  Entire home/apt       4  1.0  2.0  2.0  ...                     False
# 83158  Entire home/apt       6  1.0  2.0  3.0  ...                     False
# 83393  Entire home/apt       5  1.0  1.0  3.0  ...                     False
#
#        Exercise equipment: free weights, stationary bike, yoga mat  \
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 6                                                  False
# 8                                                  False
# ...                                                  ...
# 82649                                              False
# 82975                                              False
# 83073                                              False
# 83158                                              False
# 83393                                              False
#
#        Paid parking garage on premises – 1 space  body_soup  shampoo  stove  \
# 1                                           True      False     True  False
# 2                                          False       True     True   True
# 3                                          False      False     True  False
# 6                                          False      False     True   True
# 8                                          False       True     True   True
# ...                                          ...        ...      ...    ...
# 82649                                      False       True    False  False
# 82975                                      False       True    False   True
# 83073                                      False      False    False  False
# 83158                                      False      False     True  False
# 83393                                      False      False    False   True
#
#        refrigerator  sound  conditioner  housekeeping
# 1              True  False        False         False
# 2              True  False        False         False
# 3              True  False        False         False
# 6              True  False        False         False
# 8              True   True        False         False
# ...             ...    ...          ...           ...
# 82649         False  False        False         False
# 82975          True  False        False         False
# 83073          True  False        False         False
# 83158          True  False        False         False
# 83393          True  False        False         False
#
# [30990 rows x 530 columns]

# %%
parking_columns = [col for col in df.columns if 'parking' in col.lower()]

df['parking'] = df[parking_columns].any(axis=1)
print(len(parking_columns))


df.drop(columns=parking_columns, inplace=True)
df
# Out:
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\2109642488.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['parking'] = df[parking_columns].any(axis=1)

# %%
df
# Out:
#                      숙소_id     호스트_id 슈퍼호스트  숙소_수              숙소_지역  \
# 1                   165409     788732     t   1.0             Temple
# 2                     5396       7903     f   3.0     Hôtel-de-Ville
# 3                   166370     793032     f   3.0           Entrepôt
# 6                     7397       2626     t   9.0     Hôtel-de-Ville
# 8                    41106     177387     t   2.0     Hôtel-de-Ville
# ...                    ...        ...   ...   ...                ...
# 82649  1103696635979533455  564997552     f   1.0  Buttes-Montmartre
# 82975  1104437899838519130   13118197     f   2.0  Buttes-Montmartre
# 83073  1105169305670543918   13262987     f   2.0  Buttes-Montmartre
# 83158  1105941359456285384  344916015     f  27.0       Observatoire
# 83393  1107148961327481954   36120497     f   1.0            Reuilly
#
#                  숙소_유형  수용_인원수  욕실수  침실수  침대수  ...  Private patio or balcony  \
# 1      Entire home/apt       2  1.0  0.0  1.0  ...                     False
# 2      Entire home/apt       2  1.0  0.0  1.0  ...                     False
# 3      Entire home/apt       4  1.0  1.0  1.0  ...                     False
# 6      Entire home/apt       4  1.0  2.0  2.0  ...                     False
# 8      Entire home/apt       4  1.0  1.0  2.0  ...                     False
# ...                ...     ...  ...  ...  ...  ...                       ...
# 82649     Private room       2  1.0  1.0  1.0  ...                     False
# 82975  Entire home/apt       2  1.0  1.0  0.0  ...                     False
# 83073  Entire home/apt       4  1.0  2.0  2.0  ...                     False
# 83158  Entire home/apt       6  1.0  2.0  3.0  ...                     False
# 83393  Entire home/apt       5  1.0  1.0  3.0  ...                     False
#
#        Exercise equipment: free weights, stationary bike, yoga mat  body_soup  \
# 1                                                  False                False
# 2                                                  False                 True
# 3                                                  False                False
# 6                                                  False                False
# 8                                                  False                 True
# ...                                                  ...                  ...
# 82649                                              False                 True
# 82975                                              False                 True
# 83073                                              False                False
# 83158                                              False                False
# 83393                                              False                False
#
#        shampoo  stove  refrigerator  sound  conditioner  housekeeping  parking
# 1         True  False          True  False        False         False     True
# 2         True   True          True  False        False         False    False
# 3         True  False          True  False        False         False     True
# 6         True   True          True  False        False         False     True
# 8         True   True          True   True        False         False    False
# ...        ...    ...           ...    ...          ...           ...      ...
# 82649    False  False         False  False        False         False    False
# 82975    False   True          True  False        False         False    False
# 83073    False  False          True  False        False         False    False
# 83158     True  False          True  False        False         False     True
# 83393    False   True          True  False        False         False     True
#
# [30990 rows x 478 columns]

# %%
weights_columns = [
    col for col in df.columns if 'weights' in col.lower() or 'exercise' in col.lower()
]


df['weights'] = df[weights_columns].any(axis=1)
print(len(weights_columns))


df.drop(columns=weights_columns, inplace=True)
df
# Out:
# 10
#                      숙소_id     호스트_id 슈퍼호스트  숙소_수              숙소_지역  \
# 1                   165409     788732     t   1.0             Temple
# 2                     5396       7903     f   3.0     Hôtel-de-Ville
# 3                   166370     793032     f   3.0           Entrepôt
# 6                     7397       2626     t   9.0     Hôtel-de-Ville
# 8                    41106     177387     t   2.0     Hôtel-de-Ville
# ...                    ...        ...   ...   ...                ...
# 82649  1103696635979533455  564997552     f   1.0  Buttes-Montmartre
# 82975  1104437899838519130   13118197     f   2.0  Buttes-Montmartre
# 83073  1105169305670543918   13262987     f   2.0  Buttes-Montmartre
# 83158  1105941359456285384  344916015     f  27.0       Observatoire
# 83393  1107148961327481954   36120497     f   1.0            Reuilly
#
#                  숙소_유형  수용_인원수  욕실수  침실수  침대수  ...  \
# 1      Entire home/apt       2  1.0  0.0  1.0  ...
# 2      Entire home/apt       2  1.0  0.0  1.0  ...
# 3      Entire home/apt       4  1.0  1.0  1.0  ...
# 6      Entire home/apt       4  1.0  2.0  2.0  ...
# 8      Entire home/apt       4  1.0  1.0  2.0  ...
# ...                ...     ...  ...  ...  ...  ...
# 82649     Private room       2  1.0  1.0  1.0  ...
# 82975  Entire home/apt       2  1.0  1.0  0.0  ...
# 83073  Entire home/apt       4  1.0  2.0  2.0  ...
# 83158  Entire home/apt       6  1.0  2.0  3.0  ...
# 83393  Entire home/apt       5  1.0  1.0  3.0  ...
#
#        Paid crib - available upon request  Private patio or balcony  \
# 1                                   False                     False
# 2                                   False                     False
# 3                                   False                     False
# 6                                   False                     False
# 8                                   False                     False
# ...                                   ...                       ...
# 82649                               False                     False
# 82975                               False                     False
# 83073                               False                     False
# 83158                               False                     False
# 83393                               False                     False
#
#        body_soup  shampoo  stove  refrigerator  sound  conditioner  \
# 1          False     True  False          True  False        False
# 2           True     True   True          True  False        False
# 3          False     True  False          True  False        False
# 6          False     True   True          True  False        False
# 8           True     True   True          True   True        False
# ...          ...      ...    ...           ...    ...          ...
# 82649       True    False  False         False  False        False
# 82975       True    False   True          True  False        False
# 83073      False    False  False          True  False        False
# 83158      False     True  False          True  False        False
# 83393      False    False   True          True  False        False
#
#        housekeeping  parking
# 1             False     True
# 2             False    False
# 3             False     True
# 6             False     True
# 8             False    False
# ...             ...      ...
# 82649         False    False
# 82975         False    False
# 83073         False    False
# 83158         False     True
# 83393         False     True
#
# [30990 rows x 458 columns]

# %%
df.columns[:-20]
# Out:
# Index(['숙소_id', '호스트_id', '슈퍼호스트', '숙소_수', '숙소_지역', '숙소_유형', '수용_인원수', '욕실수',
#        '침실수', '침대수',
#        ...
#        'Lake access',
#        'Coffee maker: espresso machine, french press, Nespresso', 'Smart lock',
#        'BBQ grill: electric',
#        'Children’s books and toys for ages 0-2 years old, 2-5 years old, 5-10 years old, and 10+ years old',
#        'Private hot tub - available all year, open specific hours',
#        'Pre-stocking - included with your stay', 'Coffee',
#        'Public or shared beach access', 'Board games'],
#       dtype='object', length=438)

# %%
game_columns = [col for col in df.columns if 'game' in col.lower() ]


df['game'] = df[game_columns].any(axis=1)
print(len(game_columns))


df.drop(columns=game_columns, inplace=True)
df.columns[:-20]
# Out:
# 40
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\3583203014.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['game'] = df[game_columns].any(axis=1)
#                      숙소_id     호스트_id 슈퍼호스트  숙소_수              숙소_지역  \
# 1                   165409     788732     t   1.0             Temple
# 2                     5396       7903     f   3.0     Hôtel-de-Ville
# 3                   166370     793032     f   3.0           Entrepôt
# 6                     7397       2626     t   9.0     Hôtel-de-Ville
# 8                    41106     177387     t   2.0     Hôtel-de-Ville
# ...                    ...        ...   ...   ...                ...
# 82649  1103696635979533455  564997552     f   1.0  Buttes-Montmartre
# 82975  1104437899838519130   13118197     f   2.0  Buttes-Montmartre
# 83073  1105169305670543918   13262987     f   2.0  Buttes-Montmartre
# 83158  1105941359456285384  344916015     f  27.0       Observatoire
# 83393  1107148961327481954   36120497     f   1.0            Reuilly
#
#                  숙소_유형  수용_인원수  욕실수  침실수  침대수  ...  Private patio or balcony  \
# 1      Entire home/apt       2  1.0  0.0  1.0  ...                     False
# 2      Entire home/apt       2  1.0  0.0  1.0  ...                     False
# 3      Entire home/apt       4  1.0  1.0  1.0  ...                     False
# 6      Entire home/apt       4  1.0  2.0  2.0  ...                     False
# 8      Entire home/apt       4  1.0  1.0  2.0  ...                     False
# ...                ...     ...  ...  ...  ...  ...                       ...
# 82649     Private room       2  1.0  1.0  1.0  ...                     False
# 82975  Entire home/apt       2  1.0  1.0  0.0  ...                     False
# 83073  Entire home/apt       4  1.0  2.0  2.0  ...                     False
# 83158  Entire home/apt       6  1.0  2.0  3.0  ...                     False
# 83393  Entire home/apt       5  1.0  1.0  3.0  ...                     False
#
#        body_soup  shampoo  stove  refrigerator  sound  conditioner  \
# 1          False     True  False          True  False        False
# 2           True     True   True          True  False        False
# 3          False     True  False          True  False        False
# 6          False     True   True          True  False        False
# 8           True     True   True          True   True        False
# ...          ...      ...    ...           ...    ...          ...
# 82649       True    False  False         False  False        False
# 82975       True    False   True          True  False        False
# 83073      False    False  False          True  False        False
# 83158      False     True  False          True  False        False
# 83393      False    False   True          True  False        False
#
#        housekeeping  parking   game
# 1             False     True  False
# 2             False    False  False
# 3             False     True   True
# 6             False     True  False
# 8             False    False  False
# ...             ...      ...    ...
# 82649         False    False   True
# 82975         False    False  False
# 83073         False    False  False
# 83158         False     True  False
# 83393         False     True  False
#
# [30990 rows x 419 columns]

# %%
df.columns[:-20]
# Out:
# Index(['숙소_id', '호스트_id', '슈퍼호스트', '숙소_수', '숙소_지역', '숙소_유형', '수용_인원수', '욕실수',
#        '침실수', '침대수',
#        ...
#        'Sun loungers', 'Lake access',
#        'Coffee maker: espresso machine, french press, Nespresso', 'Smart lock',
#        'BBQ grill: electric',
#        'Children’s books and toys for ages 0-2 years old, 2-5 years old, 5-10 years old, and 10+ years old',
#        'Private hot tub - available all year, open specific hours',
#        'Pre-stocking - included with your stay', 'Coffee',
#        'Public or shared beach access'],
#       dtype='object', length=399)

# %%
coffee_columns = [col for col in df.columns if 'coffee' in col.lower() ]


df['coffee'] = df[coffee_columns].any(axis=1)
print(len(coffee_columns))


df.drop(columns=coffee_columns, inplace=True)
df.columns[:-20]
# Out:
# 45
# C:\Users\ciw96\AppData\Local\Temp\ipykernel_6300\992478911.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['coffee'] = df[coffee_columns].any(axis=1)
# Index(['숙소_id', '호스트_id', '슈퍼호스트', '숙소_수', '숙소_지역', '숙소_유형', '수용_인원수', '욕실수',
#        '침실수', '침대수',
#        ...
#        'Air conditioning',
#        'Shared outdoor pool - available all year, open specific hours, heated, olympic-sized',
#        'Shared outdoor pool - available seasonally, open specific hours, heated',
#        'Sun loungers', 'Lake access', 'Smart lock', 'BBQ grill: electric',
#        'Children’s books and toys for ages 0-2 years old, 2-5 years old, 5-10 years old, and 10+ years old',
#        'Private hot tub - available all year, open specific hours',
#        'Pre-stocking - included with your stay'],
#       dtype='object', length=355)

# %%
pool_columns = [col for col in df.columns if 'pool' in col.lower() ]

df['pool'] = df[pool_columns].any(axis=1)
print(len(pool_columns))


df.drop(columns=pool_columns, inplace=True)
df.columns[:80]
# Out:
# 1
# Index(['숙소_id', '호스트_id', '슈퍼호스트', '숙소_수', '숙소_지역', '숙소_유형', '수용_인원수', '욕실수',
#        '침실수', '침대수', '숙소_가격', '최소_숙박일', '최대_숙박일', '리뷰수', '30일_리뷰수', '리뷰점수',
#        '숙소_정확성_리뷰점수', '숙소_청결도_리뷰점수', '숙소_체크인_리뷰점수', '숙소_소통_리뷰점수', '숙소_위치_리뷰점수',
#        '숙소_가격_리뷰점수', '평균_리뷰수', 'url', '숙소_특징', '12개월_리뷰수', '예약가능여부', '마지막_리뷰',
#        'Host greets you', 'Garden view', 'Baby bath - always at the listing',
#        'Baking sheet', 'Wine cellar', 'EV charger - level 2, tesla only',
#        'Dryer – In unit', 'Shared outdoor kitchen', 'River view', 'Bikes',
#        'Courtyard view', 'Shared gym nearby', 'Gated community',
#        'First aid kit', 'Baby monitor', 'Kitchenette',
#        'Spa services – included with your stay', 'Gym nearby', 'Ironing board',
#        'Building staff', 'Washer', 'Table corner guards', 'Canal view',
#        'Paid washer – In unit', 'Sauna', 'Private BBQ grill: charcoal',
#        'Backyard - Fully fenced', 'Projector and screen', 'Cooking basics',
#        'Children’s books and toys for ages 2-5 years old and 10+ years old',
#        'Self check-in', 'Piano', 'Dryer',
#        'Pack ’n play/Travel crib - always at the listing', 'Gated property',
#        'Folding or convertible high chair - available upon request',
#        'Free washer', 'Bar',
#        'Paid folding or convertible high chair - always at the listing',
#        'Private BBQ grill: charcoal, wood-burning', 'BBQ grill: wood-burning',
#        'Crib', 'Laundromat nearby', 'Private gym nearby', 'Outdoor kitchen',
#        'Private BBQ grill: electric',
#        'Clothing storage: walk-in closet, wardrobe, and dresser',
#        'Portable air conditioning', 'Extra pillows and blankets',
#        'Beach access',
#        'Children’s books and toys for ages 0-2 years old, 2-5 years old, and 5-10 years old',
#        'Hot water'],
#       dtype='object')
