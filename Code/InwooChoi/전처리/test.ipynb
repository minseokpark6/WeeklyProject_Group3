# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
from matplotlib import font_manager, rc
import folium
from folium.plugins import MarkerCluster
from folium import FeatureGroup, LayerControl
from folium.features import GeoJson
from shapely.geometry import shape, Point
import json
import re  # 정규 표현식 라이브러리 추가
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from textblob import TextBlob
import nltk
import chardet

# 글꼴 경로 지정
font_path = "c:/Windows/Fonts/malgun.ttf"  # 윈도우에 설치된 맑은 고딕 폰트 경로

# 폰트 이름 얻어오기
font_name = font_manager.FontProperties(fname=font_path).get_name()

# matplotlib의 rc(run command) 기능을 이용하여 글꼴 설정
mpl.rc('font', family=font_name)

# 유니코드에서  음수 부호 설정
mpl.rc('axes', unicode_minus=False)

df_guest_prefer = pd.read_csv('../../../../../datasets/paris_prefer.csv')
df_non_guest_prefer = pd.read_csv('../../../../../datasets/paris_non_prefer.csv')
review = pd.read_csv('../../../../../datasets/paris_reviews.csv')

# %%
review = review.rename(columns={
    'listing_id':'숙소_id',
    'date' : '리뷰날짜',
    'comments' : '리뷰'
})

review = review[['숙소_id', '리뷰날짜', '리뷰']]
print(len(review))
# 전처리: 영어와 공백만 남김
review['review'] = review['리뷰'].apply(lambda x: re.sub(r'[^a-zA-Z\s]', '', str(x)))

# '리뷰날짜' 컬럼을 datetime 객체로 변환
review['리뷰날짜'] = pd.to_datetime(review['리뷰날짜'])

# 2022년 이후 데이터만 필터Q링
review_after_2022 = review[review['리뷰날짜'] >= '2022-01-01']

# 결과 확인
print(review_after_2022)
# Out:
# 1794006
#                        숙소_id       리뷰날짜  \
# 210                   165409 2022-08-07
# 211                   165409 2022-08-13
# 212                   165409 2022-08-24
# 213                   165409 2022-09-07
# 214                   165409 2022-09-08
# ...                      ...        ...
# 1794001  1107872133955829208 2024-03-16
# 1794002  1109396868279302811 2024-03-15
# 1794003  1108741370485532713 2024-03-10
# 1794004  1109220943409848089 2024-03-14
# 1794005  1110936505905289590 2024-03-17
#
#                                                         리뷰  \
# 210      Very cute apartment in a great location, which...
# 211      The place was perfect and matched the discript...
# 212      Heel prettig appartement in fijne buurt. Hele ...
# 213      Great location, close to many restaurants, rep...
# 214      The only decent thing about this flat is the l...
# ...                                                    ...
# 1794001  We had the best time staying at this apartment...
# 1794002  On a passé un magnifique séjour dans l'apparte...
# 1794003  Superbe découverte que cet appartement d Hugo ...
# 1794004  El apartamento es mejor que en las fotos. Todo...
# 1794005  Merci à Fabienne pour sa réactivité et son acc...
#
#                                                     review
# 210      Very cute apartment in a great location which ...
# 211      The place was perfect and matched the discript...
# 212      Heel prettig appartement in fijne buurt Hele f...
# 213      Great location close to many restaurants repub...
# 214      The only decent thing about this flat is the l...
# ...                                                    ...
# 1794001  We had the best time staying at this apartment...
# 1794002  On a pass un magnifique sjour dans lappartemen...
# 1794003  Superbe dcouverte que cet appartement d Hugo  ...
# 1794004  El apartamento es mejor que en las fotos Todo ...
# 1794005  Merci  Fabienne pour sa ractivit et son accuei...
#
# [923479 rows x 4 columns]

# %%
# review_after_2022와 df_guest_prefer 데이터프레임을 '숙소_id'를 기준으로 결합
df_guest_prefer_review = pd.merge(review_after_2022, df_guest_prefer, on='숙소_id', how='inner')

# 결과 확인
print(df_guest_prefer_review)
# Out:
#                       숙소_id       리뷰날짜  \
# 0                      9952 2022-02-19
# 1                      9952 2022-03-30
# 2                      9952 2022-04-18
# 3                      9952 2022-05-14
# 4                      9952 2022-05-25
# ...                     ...        ...
# 143179  1080946236732945943 2024-02-07
# 143180  1080946236732945943 2024-02-10
# 143181  1080946236732945943 2024-02-28
# 143182  1080946236732945943 2024-03-06
# 143183  1080946236732945943 2024-03-10
#
#                                                        리뷰  \
# 0       We really enjoyed our stay at Elizabeth's flat...
# 1       Fantastic stay! Great communication. Ideal loc...
# 2       Hemos pasado unos días fantásticos en París, a...
# 3       Place is great location! Very lively and the a...
# 4                           Very good place. I recommend.
# ...                                                   ...
# 143179  Super propre, chaud et cosy avec  vue sur la T...
# 143180  Très bon séjour, dans le cadre d’un déplacemen...
# 143181  Matyi a été super accueillant ! Le logement es...
# 143182                                             Merci)
# 143183  Loved staying here! Great location for a trip ...
#
#                                                    review    호스트_id 슈퍼호스트  \
# 0       We really enjoyed our stay at Elizabeths flat ...     33534     t
# 1       Fantastic stay Great communication Ideal locat...     33534     t
# 2       Hemos pasado unos das fantsticos en Pars aloja...     33534     t
# 3       Place is great location Very lively and the ai...     33534     t
# 4                             Very good place I recommend     33534     t
# ...                                                   ...       ...   ...
# 143179  Super propre chaud et cosy avec  vue sur la To...  22737597     t
# 143180  Trs bon sjour dans le cadre dun dplacement pro...  22737597     t
# 143181  Matyi a t super accueillant  Le logement est v...  22737597     t
# 143182                                              Merci  22737597     t
# 143183  Loved staying here Great location for a trip t...  22737597     t
#
#         숙소_수       숙소_지역            숙소_유형  수용_인원수  ...  \
# 0        1.0  Popincourt  Entire home/apt       2  ...
# 1        1.0  Popincourt  Entire home/apt       2  ...
# 2        1.0  Popincourt  Entire home/apt       2  ...
# 3        1.0  Popincourt  Entire home/apt       2  ...
# 4        1.0  Popincourt  Entire home/apt       2  ...
# ...      ...         ...              ...     ...  ...
# 143179   2.0      Élysée  Entire home/apt       2  ...
# 143180   2.0      Élysée  Entire home/apt       2  ...
# 143181   2.0      Élysée  Entire home/apt       2  ...
# 143182   2.0      Élysée  Entire home/apt       2  ...
# 143183   2.0      Élysée  Entire home/apt       2  ...
#
#         Devialet  Bluetooth sound system  Fast wifi – 372 Mbps  \
# 0                                  False                 False
# 1                                  False                 False
# 2                                  False                 False
# 3                                  False                 False
# 4                                  False                 False
# ...                                  ...                   ...
# 143179                             False                 False
# 143180                             False                 False
# 143181                             False                 False
# 143182                             False                 False
# 143183                             False                 False
#
#         Liebherr  refrigerator  50" HDTV with Netflix, premium cable  \
# 0                        False                                 False
# 1                        False                                 False
# 2                        False                                 False
# 3                        False                                 False
# 4                        False                                 False
# ...                        ...                                   ...
# 143179                   False                                 False
# 143180                   False                                 False
# 143181                   False                                 False
# 143182                   False                                 False
# 143183                   False                                 False
#
#         55" HDTV with standard cable, Netflix, premium cable  \
# 0                                                   False
# 1                                                   False
# 2                                                   False
# 3                                                   False
# 4                                                   False
# ...                                                   ...
# 143179                                              False
# 143180                                              False
# 143181                                              False
# 143182                                              False
# 143183                                              False
#
#         Exercise equipment: free weights, stationary bike, treadmill  \
# 0                                                   False
# 1                                                   False
# 2                                                   False
# 3                                                   False
# 4                                                   False
# ...                                                   ...
# 143179                                              False
# 143180                                              False
# 143181                                              False
# 143182                                              False
# 143183                                              False
#
#         Samsung  stainless steel double oven  L'Oréal shampoo  \
# 0                                      False            False
# 1                                      False            False
# 2                                      False            False
# 3                                      False            False
# 4                                      False            False
# ...                                      ...              ...
# 143179                                 False            False
# 143180                                 False            False
# 143181                                 False            False
# 143182                                 False            False
# 143183                                 False            False
#
#         55" HDTV with premium cable  65" HDTV
# 0                             False     False
# 1                             False     False
# 2                             False     False
# 3                             False     False
# 4                             False     False
# ...                             ...       ...
# 143179                        False     False
# 143180                        False     False
# 143181                        False     False
# 143182                        False     False
# 143183                        False     False
#
# [143184 rows x 2892 columns]

# %%
# review_after_2022와 df_guest_prefer 데이터프레임을 '숙소_id'를 기준으로 결합
df_non_guest_prefer_review = pd.merge(review_after_2022, df_non_guest_prefer, on='숙소_id', how='inner')

# 결과 확인
print(df_guest_prefer_review)
# Out:
#                       숙소_id       리뷰날짜  \
# 0                      9952 2022-02-19
# 1                      9952 2022-03-30
# 2                      9952 2022-04-18
# 3                      9952 2022-05-14
# 4                      9952 2022-05-25
# ...                     ...        ...
# 143179  1080946236732945943 2024-02-07
# 143180  1080946236732945943 2024-02-10
# 143181  1080946236732945943 2024-02-28
# 143182  1080946236732945943 2024-03-06
# 143183  1080946236732945943 2024-03-10
#
#                                                        리뷰  \
# 0       We really enjoyed our stay at Elizabeth's flat...
# 1       Fantastic stay! Great communication. Ideal loc...
# 2       Hemos pasado unos días fantásticos en París, a...
# 3       Place is great location! Very lively and the a...
# 4                           Very good place. I recommend.
# ...                                                   ...
# 143179  Super propre, chaud et cosy avec  vue sur la T...
# 143180  Très bon séjour, dans le cadre d’un déplacemen...
# 143181  Matyi a été super accueillant ! Le logement es...
# 143182                                             Merci)
# 143183  Loved staying here! Great location for a trip ...
#
#                                                    review    호스트_id 슈퍼호스트  \
# 0       We really enjoyed our stay at Elizabeths flat ...     33534     t
# 1       Fantastic stay Great communication Ideal locat...     33534     t
# 2       Hemos pasado unos das fantsticos en Pars aloja...     33534     t
# 3       Place is great location Very lively and the ai...     33534     t
# 4                             Very good place I recommend     33534     t
# ...                                                   ...       ...   ...
# 143179  Super propre chaud et cosy avec  vue sur la To...  22737597     t
# 143180  Trs bon sjour dans le cadre dun dplacement pro...  22737597     t
# 143181  Matyi a t super accueillant  Le logement est v...  22737597     t
# 143182                                              Merci  22737597     t
# 143183  Loved staying here Great location for a trip t...  22737597     t
#
#         숙소_수       숙소_지역            숙소_유형  수용_인원수  ...  \
# 0        1.0  Popincourt  Entire home/apt       2  ...
# 1        1.0  Popincourt  Entire home/apt       2  ...
# 2        1.0  Popincourt  Entire home/apt       2  ...
# 3        1.0  Popincourt  Entire home/apt       2  ...
# 4        1.0  Popincourt  Entire home/apt       2  ...
# ...      ...         ...              ...     ...  ...
# 143179   2.0      Élysée  Entire home/apt       2  ...
# 143180   2.0      Élysée  Entire home/apt       2  ...
# 143181   2.0      Élysée  Entire home/apt       2  ...
# 143182   2.0      Élysée  Entire home/apt       2  ...
# 143183   2.0      Élysée  Entire home/apt       2  ...
#
#         Devialet  Bluetooth sound system  Fast wifi – 372 Mbps  \
# 0                                  False                 False
# 1                                  False                 False
# 2                                  False                 False
# 3                                  False                 False
# 4                                  False                 False
# ...                                  ...                   ...
# 143179                             False                 False
# 143180                             False                 False
# 143181                             False                 False
# 143182                             False                 False
# 143183                             False                 False
#
#         Liebherr  refrigerator  50" HDTV with Netflix, premium cable  \
# 0                        False                                 False
# 1                        False                                 False
# 2                        False                                 False
# 3                        False                                 False
# 4                        False                                 False
# ...                        ...                                   ...
# 143179                   False                                 False
# 143180                   False                                 False
# 143181                   False                                 False
# 143182                   False                                 False
# 143183                   False                                 False
#
#         55" HDTV with standard cable, Netflix, premium cable  \
# 0                                                   False
# 1                                                   False
# 2                                                   False
# 3                                                   False
# 4                                                   False
# ...                                                   ...
# 143179                                              False
# 143180                                              False
# 143181                                              False
# 143182                                              False
# 143183                                              False
#
#         Exercise equipment: free weights, stationary bike, treadmill  \
# 0                                                   False
# 1                                                   False
# 2                                                   False
# 3                                                   False
# 4                                                   False
# ...                                                   ...
# 143179                                              False
# 143180                                              False
# 143181                                              False
# 143182                                              False
# 143183                                              False
#
#         Samsung  stainless steel double oven  L'Oréal shampoo  \
# 0                                      False            False
# 1                                      False            False
# 2                                      False            False
# 3                                      False            False
# 4                                      False            False
# ...                                      ...              ...
# 143179                                 False            False
# 143180                                 False            False
# 143181                                 False            False
# 143182                                 False            False
# 143183                                 False            False
#
#         55" HDTV with premium cable  65" HDTV
# 0                             False     False
# 1                             False     False
# 2                             False     False
# 3                             False     False
# 4                             False     False
# ...                             ...       ...
# 143179                        False     False
# 143180                        False     False
# 143181                        False     False
# 143182                        False     False
# 143183                        False     False
#
# [143184 rows x 2892 columns]

# %%
pip install langdetect
# Out:
# Requirement already satisfied: langdetect in c:\users\ciw96\appdata\local\programs\python\python310\lib\site-packages (1.0.9)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: six in c:\users\ciw96\appdata\local\programs\python\python310\lib\site-packages (from langdetect) (1.16.0)

# %%
from langdetect import detect, DetectorFactory
import pandas as pd

# langdetect가 일관된 결과를 반환하도록 설정
DetectorFactory.seed = 0
# 리뷰의 언어 감지를 수행하고 영어인 리뷰만 필터링하는 함수 정의
def is_english(text):
    try:
        # 텍스트의 언어 감지
        return detect(text) == 'en'
    except:
        # 언어 감지가 실패하면 False 반환
        return False

# '리뷰' 컬럼에 있는 텍스트가 영어인지 확인하여 새로운 컬럼에 결과 저장
df_non_guest_prefer_review['is_english'] = df_non_guest_prefer_review['리뷰'].apply(is_english)

# 영어 리뷰만 선택
df_non_guest_prefer_review = df_non_guest_prefer_review[df_non_guest_prefer_review['is_english']]

# 결과 확인
print(df_non_guest_prefer_review)
# Out:
#                       숙소_id       리뷰날짜  \
# 0                    171159 2022-01-10
# 6                    171159 2022-02-13
# 7                    171159 2022-02-16
# 11                   171159 2022-03-19
# 12                   171159 2022-03-22
# ...                     ...        ...
# 132578  1084102702408464568 2024-03-01
# 132584  1087934692821802498 2024-02-25
# 132589  1087934692821802498 2024-03-09
# 132590  1092099839702927754 2024-02-20
# 132592  1092099839702927754 2024-03-01
#
#                                                        리뷰  \
# 0       very conveniently located near opera and gare ...
# 6       Carole’s studio is perfect for a couple who wa...
# 7                   Lovely little nest in prime locality.
# 11      Lovely space right in one of the best areas of...
# 12      overall amazing, cozy but close to the metro a...
# ...                                                   ...
# 132578  I highly Recommend, Cozy place for staying nic...
# 132584                          host is very very helpful
# 132589  Did not stay in unit but had a wonderful stay....
# 132590  I regret to share my recent experience at the ...
# 132592  It‘s a nice choice if you have a short tour in...
#
#                                                    review     호스트_id 슈퍼호스트  \
# 0       very conveniently located near opera and gare ...     193142     f
# 6       Caroles studio is perfect for a couple who wan...     193142     f
# 7                    Lovely little nest in prime locality     193142     f
# 11      Lovely space right in one of the best areas of...     193142     f
# 12      overall amazing cozy but close to the metro an...     193142     f
# ...                                                   ...        ...   ...
# 132578  I highly Recommend Cozy place for staying nice...  556271850     f
# 132584                          host is very very helpful  252402325     f
# 132589  Did not stay in unit but had a wonderful stay ...  252402325     f
# 132590  I regret to share my recent experience at the ...  541551090     f
# 132592  Its a nice choice if you have a short tour in ...  541551090     f
#
#         숙소_수           숙소_지역            숙소_유형  수용_인원수  ...  \
# 0        3.0          Élysée  Entire home/apt       2  ...
# 6        3.0          Élysée  Entire home/apt       2  ...
# 7        3.0          Élysée  Entire home/apt       2  ...
# 11       3.0          Élysée  Entire home/apt       2  ...
# 12       3.0          Élysée  Entire home/apt       2  ...
# ...      ...             ...              ...     ...  ...
# 132578   2.0  Palais-Bourbon  Entire home/apt       2  ...
# 132584   3.0  Palais-Bourbon     Private room       2  ...
# 132589   3.0  Palais-Bourbon     Private room       2  ...
# 132590   9.0           Passy  Entire home/apt       3  ...
# 132592   9.0           Passy  Entire home/apt       3  ...
#
#         HDTV with Apple TV, premium cable  L'Oréal shampoo  \
# 0                                   False            False
# 6                                   False            False
# 7                                   False            False
# 11                                  False            False
# 12                                  False            False
# ...                                   ...              ...
# 132578                              False            False
# 132584                              False            False
# 132589                              False            False
# 132590                              False            False
# 132592                              False            False
#
#         Cave à vin refrigerator  Stainless steel double oven  \
# 0                         False                        False
# 6                         False                        False
# 7                         False                        False
# 11                        False                        False
# 12                        False                        False
# ...                         ...                          ...
# 132578                    False                        False
# 132584                    False                        False
# 132589                    False                        False
# 132590                    False                        False
# 132592                    False                        False
#
#         Byphasse body soap  Genova shampoo  Sholtes  oven  \
# 0                    False           False          False
# 6                    False           False          False
# 7                    False           False          False
# 11                   False           False          False
# 12                   False           False          False
# ...                    ...             ...            ...
# 132578               False           False          False
# 132584               False           False          False
# 132589               False           False          False
# 132590               False           False          False
# 132592               False           False          False
#
#         Table corner guards  50" HDTV with standard cable, Netflix  is_english
# 0                     False                                  False        True
# 6                     False                                  False        True
# 7                     False                                  False        True
# 11                    False                                  False        True
# 12                    False                                  False        True
# ...                     ...                                    ...         ...
# 132578                False                                  False        True
# 132584                False                                  False        True
# 132589                False                                  False        True
# 132590                False                                  False        True
# 132592                False                                  False        True
#
# [60044 rows x 1187 columns]

# %%
# '리뷰' 컬럼에 있는 텍스트가 영어인지 확인하여 새로운 컬럼에 결과 저장
df_guest_prefer_review['is_english'] = df_guest_prefer_review['리뷰'].apply(is_english)

# 영어 리뷰만 선택
df_guest_prefer_review = df_guest_prefer_review[df_guest_prefer_review['is_english']]

# 결과 확인
print(df_guest_prefer_review)
# Out:
#                       숙소_id       리뷰날짜  \
# 0                      9952 2022-02-19
# 1                      9952 2022-03-30
# 3                      9952 2022-05-14
# 4                      9952 2022-05-25
# 5                      9952 2022-06-10
# ...                     ...        ...
# 143161  1080250485815449505 2024-03-16
# 143175  1080943945230018972 2024-02-03
# 143177  1080943945230018972 2024-03-06
# 143178  1080943945230018972 2024-03-12
# 143183  1080946236732945943 2024-03-10
#
#                                                        리뷰  \
# 0       We really enjoyed our stay at Elizabeth's flat...
# 1       Fantastic stay! Great communication. Ideal loc...
# 3       Place is great location! Very lively and the a...
# 4                           Very good place. I recommend.
# 5       Elisabeth is such a caring nice and thoughtful...
# ...                                                   ...
# 143161  Great small neat apartment with easy access to...
# 143175  Thank you so much David again for your talent ...
# 143177  David is great! Very communicative, and his ap...
# 143178  David helped us out when another host cancelle...
# 143183  Loved staying here! Great location for a trip ...
#
#                                                    review     호스트_id 슈퍼호스트  \
# 0       We really enjoyed our stay at Elizabeths flat ...      33534     t
# 1       Fantastic stay Great communication Ideal locat...      33534     t
# 3       Place is great location Very lively and the ai...      33534     t
# 4                             Very good place I recommend      33534     t
# 5       Elisabeth is such a caring nice and thoughtful...      33534     t
# ...                                                   ...        ...   ...
# 143161  Great small neat apartment with easy access to...  242694272     t
# 143175  Thank you so much David again for your talent ...   33985517     t
# 143177  David is great Very communicative and his apar...   33985517     t
# 143178  David helped us out when another host cancelle...   33985517     t
# 143183  Loved staying here Great location for a trip t...   22737597     t
#
#         숙소_수              숙소_지역            숙소_유형  수용_인원수  ...  \
# 0        1.0         Popincourt  Entire home/apt       2  ...
# 1        1.0         Popincourt  Entire home/apt       2  ...
# 3        1.0         Popincourt  Entire home/apt       2  ...
# 4        1.0         Popincourt  Entire home/apt       2  ...
# 5        1.0         Popincourt  Entire home/apt       2  ...
# ...      ...                ...              ...     ...  ...
# 143161   3.0  Buttes-Montmartre  Entire home/apt       4  ...
# 143175  46.0              Opéra  Entire home/apt       6  ...
# 143177  46.0              Opéra  Entire home/apt       6  ...
# 143178  46.0              Opéra  Entire home/apt       6  ...
# 143183   2.0             Élysée  Entire home/apt       2  ...
#
#         Fast wifi – 372 Mbps  Liebherr  refrigerator  \
# 0                      False                   False
# 1                      False                   False
# 3                      False                   False
# 4                      False                   False
# 5                      False                   False
# ...                      ...                     ...
# 143161                 False                   False
# 143175                 False                   False
# 143177                 False                   False
# 143178                 False                   False
# 143183                 False                   False
#
#         50" HDTV with Netflix, premium cable  \
# 0                                      False
# 1                                      False
# 3                                      False
# 4                                      False
# 5                                      False
# ...                                      ...
# 143161                                 False
# 143175                                 False
# 143177                                 False
# 143178                                 False
# 143183                                 False
#
#         55" HDTV with standard cable, Netflix, premium cable  \
# 0                                                   False
# 1                                                   False
# 3                                                   False
# 4                                                   False
# 5                                                   False
# ...                                                   ...
# 143161                                              False
# 143175                                              False
# 143177                                              False
# 143178                                              False
# 143183                                              False
#
#         Exercise equipment: free weights, stationary bike, treadmill  \
# 0                                                   False
# 1                                                   False
# 3                                                   False
# 4                                                   False
# 5                                                   False
# ...                                                   ...
# 143161                                              False
# 143175                                              False
# 143177                                              False
# 143178                                              False
# 143183                                              False
#
#         Samsung  stainless steel double oven  L'Oréal shampoo  \
# 0                                      False            False
# 1                                      False            False
# 3                                      False            False
# 4                                      False            False
# 5                                      False            False
# ...                                      ...              ...
# 143161                                 False            False
# 143175                                 False            False
# 143177                                 False            False
# 143178                                 False            False
# 143183                                 False            False
#
#         55" HDTV with premium cable  65" HDTV  is_english
# 0                             False     False        True
# 1                             False     False        True
# 3                             False     False        True
# 4                             False     False        True
# 5                             False     False        True
# ...                             ...       ...         ...
# 143161                        False     False        True
# 143175                        False     False        True
# 143177                        False     False        True
# 143178                        False     False        True
# 143183                        False     False        True
#
# [92187 rows x 2893 columns]

# %%
pip uninstall scipy gensim

# %%
pip install scipy gensim

# %%
pip install --upgrade scipy
# Out:
# Requirement already satisfied: scipy in c:\users\ciw96\appdata\local\programs\python\python310\lib\site-packages (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in c:\users\ciw96\appdata\local\programs\python\python310\lib\site-packages (from scipy) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade gensim
# Out:
# Requirement already satisfied: gensim in c:\users\ciw96\appdata\local\programs\python\python310\lib\site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\ciw96\appdata\local\programs\python\python310\lib\site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\ciw96\appdata\local\programs\python\python310\lib\site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\ciw96\appdata\local\programs\python\python310\lib\site-packages (from gensim) (7.0.4)
# Requirement already satisfied: wrapt in c:\users\ciw96\appdata\local\programs\python\python310\lib\site-packages (from smart-open>=1.8.1->gensim) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from gensim.models import Word2Vec
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re


# 불용어 설정
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# 추가 불용어 목록
add_stopwords = ['great', 'good', 'nice', 'would', 'place', 'stay', 'apartment', 'house', 'room', 'host', 'comfortable',
                 'amazing', 'perfect', 'wonderful', 'excellent', 'lovely', 'highly', 'recommend', 'definitely', 'really',
                 'london', 'u', 'everything', 'well', 'home', 'helpful', 'also', 'like', 'location', 'staying', 'could',
                 'need', 'airbnb', 'host', 'room', 'u']

# 전체 불용어 집합
custom_stopwords = stop_words.union(set(add_stopwords))

# 어간 추출기 설정
lemma = WordNetLemmatizer()

# 전처리 함수
def preprocess(data):
    processed_words = []
    for title in data['리뷰']:
        en_words = re.sub(r"[^a-zA-Z]+", " ", str(title))  # 정규표현식 사용, 영문 대소문자 제외한 문자를 공백으로 변경
        en_words_token = word_tokenize(en_words.lower())  # 변환된 단어를 토큰화
        en_words_stop = [word for word in en_words_token if not word in custom_stopwords]  # 불용어 제거
        en_words_lemma = [lemma.lemmatize(word) for word in en_words_stop]  # 어간 추출

        processed_words.append(en_words_lemma)
    return processed_words

# 전처리
processed_reviews_t = preprocess(df_guest_prefer_review)
processed_reviews_f = preprocess(df_non_guest_prefer_review)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 3
#       1 import numpy as np
#       2 from sklearn.metrics.pairwise import cosine_similarity
# ----> 3 from gensim.models import Word2Vec
#       4 import pandas as pd
#       5 import nltk
#
# File c:\Users\ciw96\AppData\Local\Programs\Python\Python310\lib\site-packages\gensim\__init__.py:11
#       7 __version__ = '4.3.2'
#       9 import logging
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      14 logger = logging.getLogger('gensim')
#      15 if not logger.handlers:  # To ensure reload() doesn't add another one
#
# File c:\Users\ciw96\AppData\Local\Programs\Python\Python310\lib\site-packages\gensim\corpora\__init__.py:6
#       1 """
#       2 This package contains implementations of various streaming corpus I/O format.
#       3 """
#       5 # bring corpus classes directly into package namespace, to save some typing
# ----> 6 from .indexedcorpus import IndexedCorpus  # noqa:F401 must appear before the other classes
#       8 from .mmcorpus import MmCorpus  # noqa:F401
#       9 from .bleicorpus import BleiCorpus  # noqa:F401
#
# File c:\Users\ciw96\AppData\Local\Programs\Python\Python310\lib\site-packages\gensim\corpora\indexedcorpus.py:14
#      10 import logging
#      12 import numpy
# ---> 14 from gensim import interfaces, utils
#      16 logger = logging.getLogger(__name__)
#      19 class IndexedCorpus(interfaces.CorpusABC):
#
# File c:\Users\ciw96\AppData\Local\Programs\Python\Python310\lib\site-packages\gensim\interfaces.py:19
#       7 """Basic interfaces used across the whole Gensim package.
#       8
#       9 These interfaces are used for building corpora, model transformation and similarity queries.
#    (...)
#      14
#      15 """
#      17 import logging
# ---> 19 from gensim import utils, matutils
#      22 logger = logging.getLogger(__name__)
#      25 class CorpusABC(utils.SaveLoad):
#
# File c:\Users\ciw96\AppData\Local\Programs\Python\Python310\lib\site-packages\gensim\matutils.py:20
#      18 import scipy.sparse
#      19 from scipy.stats import entropy
# ---> 20 from scipy.linalg import get_blas_funcs, triu
#      21 from scipy.linalg.lapack import get_lapack_funcs
#      22 from scipy.special import psi  # gamma function utils
#
# ImportError: cannot import name 'triu' from 'scipy.linalg' (c:\Users\ciw96\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\linalg\__init__.py)
