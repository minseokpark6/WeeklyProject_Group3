# %% [markdown]
# 리뷰데이터 가져오기 / 전처리

# %%
# 기본 패키지 불러오기

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import matplotlib as mpl
from matplotlib import font_manager, rc

# 그래프를 노트북 안에 그리기 위해 설정
# %matplotlib inline

# 글꼴 경로 지정
font_path = '../../../../data/malgun.ttf'

# 폰트 이름 얻어오기
font_name = font_manager.FontProperties(fname=font_path).get_name()

# matplotlib의 rc(run command) 기능을 이용하여 글꼴 설정
mpl.rc('font', family=font_name)

# 유니코드에서  음수 부호 설정
mpl.rc('axes', unicode_minus=False)

# 데이터 불러오기

path = '../../../../data/Airbnb_London/reviews.csv'


df_review = pd.read_csv(path, encoding='utf-8')

df_review = df_review[['listing_id','date','comments']]

df_review = df_review.rename(columns= {
    'listing_id' : '숙소_id',
    'date': '리뷰날짜',
    'comments' : '리뷰'
})

#date >> 데이터타입 변경 datatime

df_review['리뷰날짜'] = pd.to_datetime(df_review['리뷰날짜'])

df_review.dropna(subset=['리뷰','리뷰날짜'], inplace=True)

#br/ 을 포함하고 있는 리뷰 >> br/을 공백(띄어쓰기)로 변경
df_review['리뷰'] = df_review['리뷰'].str.replace('<br/>', ' ', regex=False)

df_review['숙소_id'] = df_review['숙소_id'].astype(int)


#다른 나라 언어 삭제
path = '../../../../data/Airbnb_London_review/Not_englush_reviews.csv'

df_lang = pd.read_csv(path, encoding='utf-8')

df_lang.rename(columns={'not_english_reivew':'다른언어리뷰'}, inplace=True)
matching_rows = df_review[df_review['리뷰'].isin(df_lang['다른언어리뷰'])]
df_review = df_review.drop(matching_rows.index)
# Out:
# C:\Users\Master\AppData\Local\Temp\ipykernel_3548\1991688561.py:31: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_review = pd.read_csv(path, encoding='utf-8')

# %%
df_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 890313 entries, 0 to 1048574
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   숙소_id   890313 non-null  int32
#  1   리뷰날짜    890313 non-null  datetime64[ns]
#  2   리뷰      890313 non-null  object
# dtypes: datetime64[ns](1), int32(1), object(1)
# memory usage: 23.8+ MB

# %%
df_review.head()
# Out:
#    숙소_id       리뷰날짜                                                 리뷰
# 0  13913 2010-08-18  My girlfriend and I hadn't known Alina before ...
# 1  13913 2011-07-11  Alina was a really good host. The flat is clea...
# 2  13913 2011-09-13  Alina is an amazing host. She made me feel rig...
# 3  13913 2011-10-03  Alina's place is so nice, the room is big and ...
# 4  13913 2011-10-09  Nice location in Islington area, good for shor...

# %% [markdown]
# 언어감지 모듈(langdetect)를 이용하여 영어가 아닌 리뷰 찾기 (1시간30분걸림..)

# %%
# !pip install langdetect

# %%
# from langdetect import detect

# # 예시 리뷰 데이터
# comments = df['comments']

# # 영어가 아닌 리뷰를 담을 리스트
# non_english_reviews = []

# # 언어를 감지하고, 영어가 아닌 리뷰를 추출
# for comment in comments:
#     try:
#         lang = detect(comment)
#         if lang != 'en':  # 영어가 아닌 리뷰인 경우
#             non_english_reviews.append(comment)
#     except:
#         pass

# # 영어가 아닌 리뷰 출력
# print("Non-English Reviews:")
# for review in non_english_reviews:
#     print("-", review.count())

# %% [markdown]
# 숙소 데이터 가져오기 / 전처리

# %%
# 기본 패키지 불러오기 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns 
import matplotlib as mpl
from matplotlib import font_manager, rc

# 그래프를 노트북 안에 그리기 위해 설정
# %matplotlib inline

# 글꼴 경로 지정
font_path = '../../../../data/malgun.ttf'  # 윈도우에 설치된 맑은 고딕 폰트 경로

# 폰트 이름 얻어오기
font_name = font_manager.FontProperties(fname=font_path).get_name()

# matplotlib의 rc(run command) 기능을 이용하여 글꼴 설정
mpl.rc('font', family=font_name)

# 유니코드에서  음수 부호 설정
mpl.rc('axes', unicode_minus=False)

# 데이터 불러오기

path = '../../../../data/Airbnb_London/listings.csv'

london_lists = pd.read_csv(path)

# 1차 선별한 컬럼 25개 중 22개 2차 선별 + 1개(숙소_예약가능_여부)
# 최근 리뷰가 작성되었는지를 보기 위해 2개 컬럼 추가_240529 >> 'number_of_reviews_ltm' // 'last_review'
# URL 컬럼 london_lists에 적용_240530

columns_selected = ['id', 'listing_url', 'host_id', 'host_is_superhost', 'neighbourhood_cleansed', 'property_type', \
    'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'amenities', 'price', 'has_availability', 'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d', 'last_review', 'review_scores_rating', 'review_scores_accuracy', \
    'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'reviews_per_month']

# 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_total_listings_count', 'host_has_profile_pic', 'host_identity_verified', 'minimum_nights', 'maximum_nights', 'has_availability',

# 선별한 컬럼만 적용
london_lists = london_lists[columns_selected]

# 변수 정리 
london_lists = london_lists.rename(columns={
    'id': '숙소_id',
    'listing_url' : '숙소_url',
    'host_id': '호스트_id',
    # 'host_response_time': '답변_평균시간',
    # 'host_response_rate': '문의_응답률',
    # 'host_acceptance_rate': '예약_수락률',
    'host_is_superhost': '슈퍼호스트',
    # 'host_total_listings_count': '숙소_수',
    # 'host_has_profile_pic' : '프로필_사진',
    # 'host_identity_verified' : '호스트_신원',
    'neighbourhood_cleansed': '숙소_지역',
    'property_type' : '숙소_특징',
    'room_type': '숙소_유형',
    'accommodates': '수용_인원수',
    'bathrooms': '욕실수',
    'bedrooms': '침실수',
    'beds': '침대수',
    'amenities': '편의시설',
    'price': '숙소_가격',
    # 'minimum_nights': '최소_숙박일',
    # 'maximum_nights': '최대_숙박일',
    'has_availability' : '예약가능여부',
    'number_of_reviews': '리뷰수',
    'number_of_reviews_ltm' : '12개월리뷰수',
    'number_of_reviews_l30d': '30일리뷰수',
    'last_review' : '마지막리뷰',
    'review_scores_rating': '리뷰점수',
    'review_scores_accuracy': '숙소_정확성_리뷰점수',
    'review_scores_cleanliness': '숙소_청결도_리뷰점수',
    'review_scores_checkin': '숙소_체크인_리뷰점수',
    'review_scores_communication': '숙소_소통_리뷰점수',
    'review_scores_location': '숙소_위치_리뷰점수',
    'review_scores_value': '숙소_가격_리뷰점수',
    'reviews_per_month': '평균_리뷰수'
 
})

temp = london_lists.copy()
raw = london_lists.copy()

# 컬럼명 확인
london_lists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90852 entries, 0 to 90851
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   숙소_id        90852 non-null  int64
#  1   숙소_url       90852 non-null  object
#  2   호스트_id       90852 non-null  int64
#  3   슈퍼호스트        90463 non-null  object
#  4   숙소_지역        90852 non-null  object
#  5   숙소_특징        90852 non-null  object
#  6   숙소_유형        90852 non-null  object
#  7   수용_인원수       90852 non-null  int64
#  8   욕실수          57894 non-null  float64
#  9   침실수          78118 non-null  float64
#  10  침대수          57837 non-null  float64
#  11  편의시설         90852 non-null  object
#  12  숙소_가격        57885 non-null  object
#  13  예약가능여부       86773 non-null  object
#  14  리뷰수          90852 non-null  int64
#  15  12개월리뷰수      90852 non-null  int64
#  16  30일리뷰수       90852 non-null  int64
#  17  마지막리뷰        65869 non-null  object
#  18  리뷰점수         65869 non-null  float64
#  19  숙소_정확성_리뷰점수  65838 non-null  float64
#  20  숙소_청결도_리뷰점수  65843 non-null  float64
#  21  숙소_체크인_리뷰점수  65808 non-null  float64
#  22  숙소_소통_리뷰점수   65833 non-null  float64
#  23  숙소_위치_리뷰점수   65808 non-null  float64
#  24  숙소_가격_리뷰점수   65806 non-null  float64
#  25  평균_리뷰수       65869 non-null  float64
# dtypes: float64(11), int64(6), object(9)
# memory usage: 18.0+ MB

# %%
# 리뷰수가 0인 컬럼 조건 
condition_review_0 = london_lists['리뷰수'] == 0

# 별도의 DF로 저장
london_lists_review_0 = london_lists[condition_review_0]

# 리뷰 개수가 0이 아닌 컬럼 조건 설정
condition_review = london_lists['리뷰수'] != 0

# 리뷰 개수가 0이 아닌 컬럼으로 df 업데이트 
london_lists = london_lists[condition_review]
temp = london_lists.copy()

#숙소 유형 제거 
# 조건 설정
condition_room_entirehomeapt = london_lists['숙소_유형'] == 'Entire home/apt'
condition_room_privateroom = london_lists['숙소_유형'] == 'Private room'

# 데이터 제거
london_lists = london_lists[(condition_room_entirehomeapt | condition_room_privateroom)]

# 예약가능여부 결측치 제거
london_lists = london_lists[london_lists["예약가능여부"].notnull()]


# 가격이 null값/notnull값 조건 생성 
condition_price_notnull = london_lists['숙소_가격'].notnull()
condition_price_null = london_lists['숙소_가격'].isnull()

# 가격이 null값/null값이 아닌 df 분리
london_lists_price = london_lists[condition_price_notnull] 
london_lists_price_null = london_lists[condition_price_null]

# 변수명 정리 널값이 아닌 데이터
london_lists = london_lists_price

#슈퍼호스트 결측치 제거
london_lists = london_lists.dropna(subset=['슈퍼호스트'])

#욕실,침대,침실수 결측츠제거
london_lists = london_lists.dropna(subset=['욕실수', '침실수', '침대수'])

#리뷰점수 결측치제거
london_lists = london_lists.dropna(subset=['숙소_정확성_리뷰점수', '숙소_청결도_리뷰점수', '숙소_체크인_리뷰점수', '숙소_소통_리뷰점수', '숙소_위치_리뷰점수', '숙소_가격_리뷰점수'])

#12개월 리뷰수 0인것 제거 
london_lists = london_lists[london_lists['12개월리뷰수'] != 0]

london_lists['숙소_가격'] = london_lists['숙소_가격'].str.lstrip('$').str.replace(',', '').astype('float')

#가격이 0 인값 제거 
london_lists = london_lists[london_lists['숙소_가격'] != 0.0]

# 슈퍼호스트를 f로 바꿈 
london_lists.loc[(london_lists['슈퍼호스트'] == 't') & (london_lists['리뷰점수'] < 4.8), '슈퍼호스트'] = 'f'

#게스트 선호 컬럼 추가 
# 새로운 '게스트선호' 컬럼을 추가하고 기본값으로 'f' 설정
london_lists['게스트선호'] = 'f'
# 조건에 맞는 행의 '게스트선호' 값을 't'로 변경
london_lists.loc[(london_lists['리뷰점수'] >= 4.9) & (london_lists['리뷰수'] >= 5) & (london_lists['슈퍼호스트'] == 't'), '게스트선호'] = 't'

#이상치 처리 

#수용 인원수 이상치 제거 

import pandas as pd


# 이상치를 제거하는 함수 정의
def remove_price_outliers(df, price_column, type):
    
    condition = (df['숙소_유형'] == type)
    
    if price_column != '숙소_가격':
        Q1 = df[price_column].quantile(0.25)
        Q3 = df[price_column].quantile(0.75)
        IQR = Q3 - Q1
        upper_bound = Q3 + 1.5 * IQR

        
        outlier = df[price_column][condition] > upper_bound
        upper_outlier = df[condition][outlier]
        
        upper_outlier_indices = upper_outlier.index
        london_lists_cleaned = df.drop(index=upper_outlier_indices, inplace=True)
        df = london_lists_cleaned
        return df 
    else:
        Q1 = df[price_column].quantile(0.25)
        Q3 = df[price_column].quantile(0.75)
        IQR = Q3 - Q1
        upper_bound = Q3 + 3 * IQR

        
        outlier = df[price_column][condition] > upper_bound
        upper_outlier = df[condition][outlier]
        
        upper_outlier_indices = upper_outlier.index
        london_lists_cleaned = df.drop(index=upper_outlier_indices, inplace=True)
        df = london_lists_cleaned
        return df 
# 숙소 가격의 이상치 제거
remove_price_outliers(london_lists, '수용_인원수', 'Entire home/apt')
remove_price_outliers(london_lists, '수용_인원수', 'Private room')
remove_price_outliers(london_lists, '숙소_가격', 'Entire home/apt')
remove_price_outliers(london_lists, '숙소_가격', 'Private room')

# %% [markdown]
# 전처리된 숙소 데이터 의 숙소 id 값이 있는 리뷰데이터만 가져오기

# %%
london_lists_ids = london_lists['숙소_id'].values.tolist()
london_lists_ids
# Out:
# [312761,
#  13913,
#  15400,
#  159736,
#  165336,
#  17402,
#  314164,
#  34935,
#  36299,
#  173082,
#  174132,
#  174635,
#  315238,
#  316137,
#  36660,
#  316864,
#  38610,
#  38995,
#  181664,
#  318287,
#  182802,
#  41445,
#  183128,
#  320629,
#  41712,
#  321411,
#  198279,
#  43129,
#  322606,
#  200713,
#  323473,
#  201463,
#  203163,
#  47192,
#  207542,
#  47687,
#  55402,
#  216350,
#  326633,
#  56229,
#  326655,
#  63948,
#  219665,
#  329585,
#  66772,
#  331058,
#  334310,
#  231452,
#  231692,
#  73125,
#  73431,
#  338198,
#  78892,
#  232240,
#  338354,
#  232983,
#  79129,
#  236956,
#  80123,
#  341779,
#  81410,
#  81449,
#  241621,
#  241975,
#  342003,
#  81635,
#  83027,
#  342804,
#  344094,
#  244126,
#  84223,
#  344102,
#  84532,
#  84640,
#  346523,
#  85191,
#  86092,
#  248291,
#  254996,
#  263822,
#  348215,
#  264777,
#  264778,
#  264779,
#  264780,
#  264781,
#  91287,
#  92352,
#  92399,
#  93015,
#  264782,
#  264783,
#  349930,
#  266037,
#  93783,
#  270600,
#  273941,
#  351727,
#  96052,
#  97506,
#  274740,
#  274918,
#  353133,
#  275140,
#  98541,
#  356073,
#  102565,
#  276888,
#  103865,
#  358360,
#  280234,
#  107051,
#  359974,
#  116268,
#  117203,
#  362026,
#  127652,
#  284532,
#  137581,
#  137907,
#  365069,
#  289422,
#  142117,
#  367207,
#  294177,
#  145612,
#  294247,
#  294887,
#  375657,
#  300723,
#  157714,
#  389544,
#  377982,
#  389786,
#  379053,
#  389967,
#  390319,
#  390320,
#  379137,
#  307923,
#  380188,
#  308005,
#  390356,
#  380714,
#  390750,
#  390987,
#  390988,
#  391035,
#  311430,
#  442178,
#  391273,
#  442992,
#  382634,
#  391672,
#  392141,
#  392246,
#  384315,
#  446900,
#  384770,
#  395062,
#  396235,
#  396523,
#  446912,
#  447891,
#  448589,
#  448739,
#  397262,
#  384780,
#  449399,
#  450460,
#  398147,
#  387835,
#  387935,
#  388030,
#  401972,
#  453797,
#  388032,
#  402739,
#  388315,
#  454008,
#  454047,
#  406898,
#  388674,
#  407303,
#  456200,
#  458015,
#  389125,
#  504810,
#  410971,
#  505926,
#  414115,
#  460934,
#  460935,
#  460938,
#  461923,
#  415825,
#  415926,
#  416047,
#  416238,
#  461987,
#  507677,
#  464579,
#  508343,
#  510116,
#  417090,
#  464922,
#  465435,
#  510386,
#  511429,
#  511768,
#  469187,
#  469189,
#  469198,
#  420083,
#  512853,
#  512882,
#  469676,
#  513198,
#  472185,
#  514637,
#  427936,
#  477286,
#  428631,
#  517283,
#  429444,
#  478627,
#  481999,
#  432841,
#  519660,
#  486627,
#  487430,
#  434962,
#  520959,
#  435600,
#  436257,
#  436446,
#  436458,
#  487783,
#  489405,
#  491730,
#  438421,
#  492756,
#  521274,
#  492883,
#  492946,
#  438531,
#  441459,
#  521771,
#  441525,
#  521982,
#  494343,
#  522729,
#  497373,
#  558664,
#  523635,
#  558694,
#  523749,
#  559415,
#  559579,
#  501837,
#  559643,
#  526388,
#  560068,
#  502566,
#  563229,
#  503331,
#  563243,
#  527310,
#  564861,
#  604687,
#  528124,
#  605812,
#  529070,
#  565770,
#  529558,
#  566364,
#  606382,
#  530395,
#  571265,
#  530448,
#  571906,
#  607129,
#  607704,
#  572805,
#  607885,
#  531050,
#  608431,
#  608438,
#  573155,
#  609973,
#  611025,
#  574599,
#  575053,
#  611709,
#  613103,
#  536121,
#  615147,
#  615347,
#  536751,
#  583333,
#  617678,
#  583705,
#  619010,
#  537305,
#  539042,
#  588044,
#  620164,
#  620282,
#  542646,
#  622068,
#  544613,
#  590293,
#  590575,
#  625296,
#  544824,
#  626710,
#  590823,
#  627123,
#  627920,
#  629409,
#  545404,
#  546039,
#  547462,
#  630933,
#  593780,
#  594107,
#  631061,
#  632377,
#  594831,
#  550492,
#  595036,
#  632672,
#  595071,
#  633856,
#  635233,
#  554694,
#  596823,
#  597005,
#  647243,
#  555419,
#  599058,
#  699729,
#  656590,
#  705523,
#  705526,
#  660891,
#  601392,
#  668172,
#  668819,
#  601550,
#  601584,
#  602302,
#  709912,
#  602475,
#  603959,
#  672080,
#  672081,
#  711333,
#  673067,
#  711425,
#  713475,
#  814021,
#  814659,
#  816985,
#  714364,
#  714723,
#  819977,
#  823097,
#  680305,
#  680656,
#  680739,
#  825821,
#  682609,
#  719487,
#  834616,
#  721267,
#  836442,
#  726882,
#  852486,
#  727655,
#  854102,
#  854116,
#  855465,
#  730831,
#  731022,
#  863652,
#  980289,
#  981654,
#  865843,
#  872544,
#  740600,
#  740867,
#  874329,
#  741021,
#  985438,
#  987092,
#  874463,
#  742149,
#  742379,
#  743918,
#  991064,
#  744746,
#  880100,
#  745090,
#  993428,
#  998578,
#  745091,
#  745213,
#  999147,
#  999691,
#  999835,
#  1000926,
#  747789,
#  1002115,
#  1002787,
#  1003616,
#  1003867,
#  891874,
#  1003956,
#  751606,
#  897581,
#  1011777,
#  1011983,
#  900063,
#  754867,
#  906474,
#  910252,
#  1013398,
#  1015806,
#  1018171,
#  1018624,
#  1022977,
#  919261,
#  925550,
#  1028784,
#  755623,
#  1035339,
#  928588,
#  928721,
#  1038126,
#  933693,
#  1042006,
#  1042849,
#  934366,
#  943363,
#  1044109,
#  1044356,
#  1044873,
#  945717,
#  761273,
#  948461,
#  1046023,
#  1046055,
#  1047227,
#  953350,
#  1056379,
#  764669,
#  1060899,
#  956310,
#  1063188,
#  769383,
#  964547,
#  1066230,
#  1067936,
#  970465,
#  772580,
#  1070928,
#  972574,
#  772992,
#  972636,
#  1084977,
#  972717,
#  1093943,
#  779186,
#  973332,
#  976422,
#  1145066,
#  1103795,
#  1105934,
#  1166216,
#  1109914,
#  792305,
#  1172280,
#  1174411,
#  1113541,
#  1177530,
#  792956,
#  1116245,
#  797036,
#  802401,
#  1117796,
#  1122835,
#  1123121,
#  805005,
#  1186492,
#  1123133,
#  805851,
#  1126108,
#  1188836,
#  1188938,
#  1126252,
#  1126638,
#  1192978,
#  810126,
#  1286611,
#  1128785,
#  1131354,
#  1197911,
#  1199554,
#  1199580,
#  1443909,
#  1289534,
#  1202455,
#  1202617,
#  1291630,
#  1204627,
#  1208158,
#  1295608,
#  1208955,
#  1210559,
#  1211331,
#  1452643,
#  1453105,
#  1298770,
#  1457328,
#  1211486,
#  1212794,
#  1213679,
#  1217116,
#  1458205,
#  1304277,
#  1459886,
#  1217387,
#  1461415,
#  1311837,
#  1466259,
#  1313503,
#  1468034,
#  1218877,
#  1319049,
#  1220209,
#  1319498,
#  1220217,
#  1221737,
#  1222924,
#  1477025,
#  1323647,
#  1223650,
#  1325052,
#  1325597,
#  1224630,
#  1226016,
#  1227523,
#  1488173,
#  1488482,
#  1334961,
#  1506850,
#  1230313,
#  1231484,
#  1231839,
#  1509446,
#  1234354,
#  1515387,
#  1339408,
#  1339785,
#  1520434,
#  1340559,
#  1525275,
#  1241481,
#  1340622,
#  1341379,
#  1529116,
#  1244325,
#  1342152,
#  1342180,
#  1532025,
#  1534817,
#  1342795,
#  1249846,
#  1254710,
#  1538056,
#  1538293,
#  1342810,
#  1255710,
#  1344695,
#  1541373,
#  1262168,
#  1543097,
#  1346303,
#  1266951,
#  1548874,
#  1350621,
#  1270251,
#  1352070,
#  1354206,
#  1554893,
#  1354331,
#  1357673,
#  1357846,
#  1278020,
#  1555216,
#  1360300,
#  1558183,
#  1279313,
#  1362167,
#  1282891,
#  1563568,
#  1566565,
#  1571980,
#  1635433,
#  1638730,
#  1573196,
#  1370162,
#  1574249,
#  1644873,
#  1647720,
#  1576264,
#  1650494,
#  1383888,
#  1651191,
#  1585716,
#  1588282,
#  1394692,
#  1663184,
#  1395088,
#  1664436,
#  1395902,
#  1595060,
#  1668374,
#  1396026,
#  1397382,
#  1682982,
#  1612301,
#  1687742,
#  1615242,
#  1621302,
#  1413870,
#  1623611,
#  1836379,
#  1716200,
#  1716786,
#  1422528,
#  1719900,
#  1425110,
#  1840547,
#  1720539,
#  1723349,
#  1427095,
#  1427868,
#  1723382,
#  1430154,
#  1727002,
#  1430558,
#  1432552,
#  1732330,
#  1436172,
#  1851018,
#  1436177,
#  1436259,
#  1738897,
#  1862535,
#  1870367,
#  1739911,
#  1999530,
#  2002358,
#  2002712,
#  1754344,
#  1883810,
#  2007051,
#  1885870,
#  1758791,
#  1759974,
#  1760271,
#  2007059,
#  1760593,
#  2008413,
#  1891362,
#  1761152,
#  2009703,
#  1766292,
#  1891773,
#  1894904,
#  2011165,
#  1895354,
#  2011406,
#  1786015,
#  1904019,
#  1904439,
#  2020348,
#  2021039,
#  1791458,
#  1791742,
#  2021361,
#  1796751,
#  1796888,
#  1797244,
#  1912320,
#  1798930,
#  1802813,
#  1804130,
#  1916940,
#  1809084,
#  1919337,
#  2033384,
#  1813965,
#  2034808,
#  1816747,
#  1926208,
#  1926865,
#  1822243,
#  2035493,
#  2035532,
#  1927679,
#  2036125,
#  1930269,
#  2036152,
#  1827533,
#  1830958,
#  2164284,
#  1935885,
#  2167502,
#  2169916,
#  1948199,
#  1948750,
#  2173335,
#  2046402,
#  1951947,
#  2051141,
#  1953532,
#  2052284,
#  2181825,
#  2182759,
#  2055370,
#  1964074,
#  1973506,
#  2184602,
#  2184786,
#  1980662,
#  1981198,
#  1983382,
#  2077094,
#  2085572,
#  1985593,
#  2090734,
#  2208769,
#  2095257,
#  1990616,
#  2211564,
#  2119319,
#  2213040,
#  2119937,
#  2354700,
#  2214673,
#  2357072,
#  2215685,
#  2218521,
#  2363826,
#  2369323,
#  2125974,
#  2126708,
#  2371649,
#  2221286,
#  2373926,
#  2230069,
#  2375962,
#  2382883,
#  2234102,
#  2245980,
#  2388750,
#  2145108,
#  2392700,
#  2145993,
#  2248949,
#  2153716,
#  2253316,
#  2157833,
#  2254222,
#  2157875,
#  2157890,
#  2400692,
#  2261943,
#  2158844,
#  2269760,
#  2408578,
#  2270176,
#  2559515,
#  2416056,
#  2559562,
#  2271369,
#  2275734,
#  2279473,
#  2279831,
#  2559816,
#  2283136,
#  2283610,
#  2286988,
#  2288669,
#  2575218,
#  2441568,
#  2575413,
#  2453343,
#  2576674,
#  2300971,
#  2456014,
#  2582659,
#  2308269,
#  2456122,
#  2456463,
#  2459362,
#  2589855,
#  2460016,
#  2322718,
#  2591139,
#  2469465,
#  2472822,
#  2328836,
#  2476083,
#  2336065,
#  2599287,
#  2477621,
#  2345007,
#  2602971,
#  2487880,
#  2607943,
#  2498530,
#  2755176,
#  2610211,
#  2500528,
#  2502046,
#  2502453,
#  2624292,
#  2760693,
#  2518024,
#  2519161,
#  2524440,
#  2524622,
#  2527201,
#  2762514,
#  2529188,
#  2773139,
#  2779754,
#  2780524,
#  2541735,
#  2648915,
#  2807287,
#  2552440,
#  2652917,
#  2813876,
#  2654622,
#  2555135,
#  2556330,
#  2656826,
#  2657796,
#  2822720,
#  2557474,
#  2557770,
#  2557853,
#  2659707,
#  2557892,
#  2827200,
#  2660137,
#  2662066,
#  2974379,
#  2977750,
#  2673638,
#  2835266,
#  2986844,
#  2839143,
#  3003685,
#  3008303,
#  3008678,
#  2689987,
#  2850742,
#  2690320,
#  2690476,
#  2690828,
#  2852239,
#  2691533,
#  2692069,
#  3024491,
#  3035487,
#  2860059,
#  2862816,
#  2865537,
#  3037602,
#  2697472,
#  2867009,
#  3041621,
#  3045804,
#  2704745,
#  2705865,
#  2706674,
#  2880265,
#  2707775,
#  2708091,
#  2889261,
#  2890867,
#  2895528,
#  2895862,
#  3071519,
#  2897363,
#  2715481,
#  2916767,
#  2720830,
#  2917935,
#  2721250,
#  2925012,
#  2926013,
#  3086305,
#  3086844,
#  2728159,
#  2926458,
#  2728436,
#  3093102,
#  2736493,
#  3100592,
#  2934134,
#  2934808,
#  2738049,
#  3108168,
#  3108670,
#  3183354,
#  2947896,
#  3111082,
#  3184830,
#  2948340,
#  3186798,
#  2955746,
#  3113236,
#  3188938,
#  3114243,
#  3190413,
#  3123465,
#  2961981,
#  3191081,
#  2964617,
#  2971708,
#  2973945,
#  3135135,
#  3141414,
#  3330074,
#  3202186,
#  3202462,
#  3151480,
#  3205932,
#  3206198,
#  3342278,
#  3214118,
#  3165691,
#  3170396,
#  3173050,
#  3348338,
#  3178765,
#  3181201,
#  3355641,
#  3181845,
#  3237695,
#  3238145,
#  3362818,
#  3239200,
#  3364246,
#  3240539,
#  3365015,
#  3365023,
#  3455629,
#  3241024,
#  3365479,
#  3370472,
#  3370968,
#  3463936,
#  3378742,
#  3478181,
#  3259990,
#  3383015,
#  3383457,
#  3480534,
#  3260426,
#  3481931,
#  3385589,
#  3387650,
#  3482462,
#  3483914,
#  3270479,
#  3492159,
#  3275469,
#  3275911,
#  3393633,
#  3498228,
#  3499321,
#  3400029,
#  3279376,
#  3287526,
#  3406768,
#  3409931,
#  3293028,
#  3413200,
#  3417708,
#  3294824,
#  3421659,
#  3295048,
#  ...]

# %%
# df_filtered에서 listing_ids에 없는 숙소_id 제거
df_review = df_review[df_review['숙소_id'].isin(london_lists_ids)]
df_review
# Out:
#             숙소_id       리뷰날짜  \
# 0           13913 2010-08-18
# 1           13913 2011-07-11
# 2           13913 2011-09-13
# 3           13913 2011-10-03
# 4           13913 2011-10-09
# ...           ...        ...
# 1048567  39029180 2023-12-12
# 1048568  39029216 2019-10-13
# 1048569  39070453 2023-11-04
# 1048571  39070453 2023-12-30
# 1048572  39070453 2024-02-03
#
#                                                         리뷰
# 0        My girlfriend and I hadn't known Alina before ...
# 1        Alina was a really good host. The flat is clea...
# 2        Alina is an amazing host. She made me feel rig...
# 3        Alina's place is so nice, the room is big and ...
# 4        Nice location in Islington area, good for shor...
# ...                                                    ...
# 1048567  I had a great stay at Miche?l’s place.  Clean,...
# 1048568  Anna is an exceptional host, she met us at Pad...
# 1048569  Room was clean, but smelt of feet. One pillow ...
# 1048571                           It was a nice experience
# 1048572                            Good and easy to locate
#
# [577260 rows x 3 columns]

# %%
df_review.shape
# Out:
# (577260, 3)

# %% [markdown]
# 랜덤 20000만개 데이터 추출

# %%
import pandas as pd

# 리뷰 데이터가 담긴 DataFrame (예: df)
# 예시로 df를 생성합니다. 실제 데이터 프레임을 사용하세요.
# df = pd.read_csv('path_to_your_file.csv')

# 10,000개의 랜덤 샘플 추출
random_sample = df_review.sample(n=20000, random_state=42)

# 결과를 확인합니다.
print(random_sample)
# Out:
#            숙소_id       리뷰날짜                                                 리뷰
# 631947  19213942 2023-05-31  Suzan is an excellent host & Lorinka is a prof...
# 915683  31458289 2023-07-01  Mark’s place called itself a hotel, but missed...
# 130418   2007051 2017-10-15  An extremely clean, tidy and homely guest hous...
# 785553  24389958 2019-09-05                           Good but a little noisy.
# 840710  27503376 2023-11-01  Isabelle’ home is quiet and spacious and has e...
# ...          ...        ...                                                ...
# 22084     280234 2018-07-17  Jenny‘s place is just like the pictures show. ...
# 352240   9438816 2024-03-02  I was in london for work and i stayed there fo...
# 773932  24297664 2019-07-03  Jennifer is a wonderful hostess. The apartment...
# 795503  25046044 2019-06-21  It was the first time, we stayed in an airbnb ...
# 262111   6224560 2019-07-08  Lovely flat, comfortable beds, with fantastic ...
#
# [20000 rows x 3 columns]

# %%
# 추출한 데이터를 CSV 파일로 저장
random_sample.to_csv('../../../../data/Airbnb_London/random_review_20000.csv', index=False)

# %% [markdown]
# <h3>숙소데이터 패턴 분석 </h3>

# %%
#랜덤으로 뽑은 샘플리뷰의 숙소id가 있는 london_lists 데이터 추출
random_samples_ids = random_sample['숙소_id'].drop_duplicates().values.tolist()
random_samples_ids
# Out:
# [19213942,
#  31458289,
#  2007051,
#  24389958,
#  27503376,
#  32223337,
#  17748259,
#  7600939,
#  35079425,
#  1981198,
#  2691533,
#  33541697,
#  4022582,
#  7878442,
#  32037180,
#  3206198,
#  13512606,
#  6720954,
#  21223966,
#  17337545,
#  32017126,
#  27920779,
#  13907937,
#  4748665,
#  11770338,
#  19670926,
#  3297912,
#  19821097,
#  38603674,
#  13679880,
#  20539899,
#  12833203,
#  32374189,
#  11939786,
#  2476083,
#  4610589,
#  35934806,
#  13324052,
#  3205932,
#  7192421,
#  24732512,
#  10735129,
#  17230448,
#  2145108,
#  30760224,
#  4439155,
#  25545928,
#  1436172,
#  19904707,
#  15148205,
#  1985593,
#  33312087,
#  25182647,
#  2498530,
#  5804904,
#  37181320,
#  35145239,
#  23363114,
#  13838744,
#  37146345,
#  13622773,
#  4283521,
#  13557864,
#  29430696,
#  21527377,
#  5996097,
#  2477621,
#  1650494,
#  344094,
#  9948310,
#  36104556,
#  32528957,
#  9518359,
#  6947277,
#  16075567,
#  24045624,
#  27120569,
#  35152393,
#  2051141,
#  7409745,
#  6391074,
#  24376175,
#  21185641,
#  26766399,
#  1339785,
#  30516718,
#  27025816,
#  16117257,
#  29129550,
#  1520434,
#  2518024,
#  31837346,
#  1973506,
#  30903344,
#  38058053,
#  1951947,
#  23231054,
#  14146496,
#  18328421,
#  8834649,
#  18766603,
#  22596117,
#  21732966,
#  6087810,
#  2559515,
#  25569512,
#  4999297,
#  3855375,
#  11234733,
#  17419730,
#  14511119,
#  16759676,
#  37703150,
#  13306200,
#  19513588,
#  16107739,
#  30764707,
#  8144640,
#  13474477,
#  31040204,
#  6618185,
#  47687,
#  24428774,
#  36137939,
#  3664786,
#  606382,
#  13533628,
#  511429,
#  22459924,
#  36660,
#  22353530,
#  17149736,
#  7203121,
#  20613613,
#  15510717,
#  36872461,
#  14054800,
#  599058,
#  27107300,
#  16883418,
#  19036372,
#  30390085,
#  973332,
#  15615789,
#  35026205,
#  13250843,
#  20399917,
#  37713844,
#  2692069,
#  23414905,
#  23685520,
#  36515310,
#  18076604,
#  14540413,
#  9447772,
#  456200,
#  231452,
#  22546237,
#  7814040,
#  27863349,
#  13537141,
#  9211765,
#  711333,
#  3928831,
#  891874,
#  20877461,
#  1015806,
#  454008,
#  34116541,
#  32484354,
#  14104610,
#  21932467,
#  420083,
#  8989885,
#  21175492,
#  23022135,
#  19941110,
#  11353017,
#  14335002,
#  12102655,
#  22610015,
#  855465,
#  33967728,
#  19093817,
#  14687689,
#  7071134,
#  3840204,
#  35859811,
#  34339000,
#  23076179,
#  17619738,
#  37614032,
#  13309995,
#  33014457,
#  1738897,
#  7594566,
#  22081628,
#  17005261,
#  27252599,
#  5494642,
#  27273278,
#  27711272,
#  21930268,
#  4332039,
#  33406619,
#  4792857,
#  31509892,
#  21107001,
#  17247557,
#  9127324,
#  37625242,
#  32048215,
#  16892168,
#  24558206,
#  23407169,
#  12551776,
#  22981760,
#  26701198,
#  10149001,
#  9774641,
#  3498228,
#  4985649,
#  32920082,
#  14831133,
#  2363826,
#  11469499,
#  19562388,
#  18474957,
#  9425208,
#  12188577,
#  14850865,
#  21549106,
#  17332069,
#  10163641,
#  21116139,
#  4043964,
#  1638730,
#  12341282,
#  29917214,
#  12518330,
#  27807685,
#  10762870,
#  6631727,
#  529558,
#  19806370,
#  28599087,
#  17727652,
#  24478488,
#  4676926,
#  461923,
#  38317464,
#  1916940,
#  19753982,
#  8332218,
#  29592985,
#  31423797,
#  37595697,
#  23234902,
#  8452755,
#  10647394,
#  8182073,
#  21682378,
#  25912554,
#  17811032,
#  9568440,
#  37511619,
#  28609043,
#  12820614,
#  216350,
#  2164284,
#  4623309,
#  2126708,
#  33898881,
#  13732292,
#  38405786,
#  19136052,
#  23939425,
#  21262115,
#  19007627,
#  1109914,
#  25992547,
#  3620794,
#  254996,
#  2441568,
#  31645964,
#  14629530,
#  13899697,
#  19015779,
#  23699779,
#  6432372,
#  18893565,
#  25875591,
#  36769754,
#  7618834,
#  29735689,
#  1397382,
#  28206131,
#  21468810,
#  1234354,
#  8000600,
#  7053034,
#  38659271,
#  14757410,
#  10624049,
#  13029344,
#  5367754,
#  7550548,
#  367207,
#  20896932,
#  24917182,
#  322606,
#  16197381,
#  30279726,
#  34223450,
#  29961195,
#  15049077,
#  18961480,
#  348215,
#  14641982,
#  13606215,
#  1325052,
#  329585,
#  20704116,
#  31588430,
#  12301456,
#  27827260,
#  34340621,
#  22113358,
#  2715481,
#  1174411,
#  3602711,
#  19050603,
#  15370093,
#  27028238,
#  36036536,
#  16985403,
#  23822412,
#  15115742,
#  32758312,
#  3860604,
#  7852769,
#  7742194,
#  1188938,
#  11419334,
#  26421685,
#  18000081,
#  8321770,
#  464922,
#  20885649,
#  1822243,
#  2371649,
#  6669426,
#  21718300,
#  7647865,
#  1018171,
#  436458,
#  6611516,
#  6127095,
#  33492711,
#  15940714,
#  32321548,
#  12925678,
#  31634572,
#  13266710,
#  3974384,
#  22215128,
#  21558448,
#  9875680,
#  12272416,
#  12316321,
#  563243,
#  34957854,
#  21798514,
#  6228511,
#  583705,
#  16421242,
#  17959938,
#  7600303,
#  18628698,
#  15318457,
#  6087949,
#  5751270,
#  16625284,
#  14244463,
#  13457207,
#  4656250,
#  18914878,
#  15641040,
#  7377212,
#  2690320,
#  5714955,
#  25972462,
#  12280413,
#  294247,
#  16953154,
#  14628902,
#  31918465,
#  14270575,
#  17724681,
#  27864675,
#  19835554,
#  18643066,
#  38071325,
#  24111868,
#  1422528,
#  36224071,
#  20347748,
#  4664279,
#  33966776,
#  9408750,
#  15406836,
#  8322445,
#  30953716,
#  28121162,
#  3417708,
#  1809084,
#  30269309,
#  8958658,
#  11966878,
#  24490020,
#  24573497,
#  38693553,
#  11238883,
#  22045052,
#  30338148,
#  16577162,
#  6884941,
#  388032,
#  4451913,
#  14863559,
#  9527125,
#  608431,
#  34518655,
#  26043274,
#  6341737,
#  1357846,
#  1047227,
#  3986296,
#  24128067,
#  12596630,
#  275140,
#  13055958,
#  36299,
#  14907104,
#  18844197,
#  358360,
#  23958660,
#  38571732,
#  21721662,
#  19977938,
#  21403035,
#  434962,
#  34774366,
#  16648010,
#  30703403,
#  26523011,
#  2169916,
#  37975043,
#  2184786,
#  30366708,
#  18204906,
#  33238552,
#  6272920,
#  21508510,
#  1383888,
#  3238145,
#  31858341,
#  12198477,
#  12076769,
#  24672257,
#  19938428,
#  19444422,
#  18895996,
#  721267,
#  26883154,
#  31140936,
#  9859401,
#  13917843,
#  779186,
#  1350621,
#  23210819,
#  22827426,
#  23936710,
#  530448,
#  21676258,
#  34465905,
#  9236221,
#  22937921,
#  15465132,
#  16211130,
#  11259161,
#  37552405,
#  13804067,
#  29058586,
#  21880752,
#  21438070,
#  18120660,
#  9922423,
#  9964865,
#  31328470,
#  1509446,
#  21608077,
#  2934134,
#  22428604,
#  6745039,
#  5742008,
#  647243,
#  17083723,
#  20043249,
#  36544227,
#  16210909,
#  13339882,
#  29213065,
#  31395242,
#  31423378,
#  5657123,
#  21075132,
#  32695038,
#  26728262,
#  6535321,
#  447891,
#  6014212,
#  30415048,
#  39025542,
#  14300513,
#  1291630,
#  16642140,
#  4679291,
#  17252081,
#  33311334,
#  18071645,
#  20646758,
#  919261,
#  999691,
#  37182400,
#  1912320,
#  232983,
#  24366035,
#  874329,
#  7799465,
#  33632999,
#  36191012,
#  21617650,
#  14388109,
#  22665017,
#  19193468,
#  15826252,
#  7977745,
#  31396910,
#  6950991,
#  18631428,
#  20829956,
#  8061186,
#  32867236,
#  38045464,
#  8143954,
#  35487052,
#  22530519,
#  4982166,
#  5493751,
#  436257,
#  900063,
#  1218877,
#  22043164,
#  28064534,
#  30808754,
#  30906165,
#  21521250,
#  24385068,
#  17396911,
#  18985602,
#  7676396,
#  28078356,
#  4928798,
#  15800091,
#  23986461,
#  24880026,
#  23538494,
#  27833488,
#  19999217,
#  37378012,
#  22476268,
#  1211331,
#  4735748,
#  26459566,
#  14832630,
#  84223,
#  16472888,
#  26219648,
#  18590863,
#  29271201,
#  17976639,
#  17563121,
#  3830158,
#  32783593,
#  3259990,
#  16809327,
#  4691584,
#  15965107,
#  3202186,
#  13572875,
#  1352070,
#  15267243,
#  21982395,
#  5911792,
#  17808694,
#  2557770,
#  19772234,
#  30123175,
#  24030364,
#  34993640,
#  25320216,
#  17771404,
#  35803815,
#  29890672,
#  14765936,
#  34122756,
#  6498157,
#  10647121,
#  19269203,
#  415825,
#  874463,
#  25651877,
#  5157654,
#  12821368,
#  571265,
#  3699428,
#  1128785,
#  668819,
#  16155609,
#  19012917,
#  20914935,
#  22317755,
#  3355641,
#  1425110,
#  266037,
#  26482627,
#  2917935,
#  31070729,
#  20390408,
#  2602971,
#  6137157,
#  22536953,
#  477286,
#  13836324,
#  23824693,
#  5930549,
#  11780466,
#  13390008,
#  1990616,
#  20833245,
#  10976789,
#  20615908,
#  17570049,
#  12921455,
#  1113541,
#  23291360,
#  539042,
#  11013108,
#  15962317,
#  36577382,
#  7633036,
#  1266951,
#  5010158,
#  560068,
#  390356,
#  1452643,
#  7558001,
#  35718200,
#  1585716,
#  15540290,
#  15723140,
#  25175483,
#  12201334,
#  31532632,
#  15278841,
#  28194114,
#  26704001,
#  37885259,
#  15493902,
#  740600,
#  3992557,
#  17459582,
#  21500843,
#  22403401,
#  21187485,
#  9244494,
#  34006508,
#  27027855,
#  9499966,
#  5182832,
#  934366,
#  8708403,
#  16673248,
#  19261471,
#  11733660,
#  9582415,
#  33684230,
#  1122835,
#  41712,
#  19928998,
#  28488920,
#  37364879,
#  1046055,
#  3183354,
#  16814683,
#  29330219,
#  11392403,
#  19234939,
#  17529555,
#  4953869,
#  30693568,
#  4284972,
#  4193625,
#  21688692,
#  2416056,
#  32760358,
#  1289534,
#  29449990,
#  4017122,
#  772992,
#  29624586,
#  20794389,
#  26045118,
#  10694086,
#  308005,
#  2046402,
#  28657276,
#  5084774,
#  21785128,
#  30850801,
#  137581,
#  625296,
#  4919790,
#  32651609,
#  36599590,
#  34518728,
#  9391266,
#  4122753,
#  11588723,
#  18158812,
#  5902247,
#  4461052,
#  19464569,
#  21527531,
#  34484870,
#  21722685,
#  27895127,
#  30260117,
#  34999559,
#  25120137,
#  19920441,
#  22584269,
#  18913727,
#  34491809,
#  19172785,
#  12893666,
#  19051315,
#  19657454,
#  3639077,
#  7167157,
#  741021,
#  24010040,
#  36686355,
#  3294824,
#  11152928,
#  30001604,
#  4706935,
#  29973218,
#  19503311,
#  8279354,
#  34110581,
#  9537177,
#  73125,
#  38071219,
#  9794594,
#  15673508,
#  14653428,
#  3666520,
#  8367891,
#  182802,
#  34963590,
#  11178621,
#  17846914,
#  21833071,
#  8059907,
#  25400960,
#  12394542,
#  21580482,
#  24448200,
#  24387249,
#  2011406,
#  10738655,
#  18696477,
#  12819909,
#  547462,
#  31623278,
#  24576893,
#  1060899,
#  3421659,
#  1084977,
#  18519210,
#  1286611,
#  1325597,
#  730831,
#  7311955,
#  63948,
#  33507565,
#  2119937,
#  5456530,
#  37949925,
#  7987446,
#  13692946,
#  3700190,
#  12330363,
#  18596858,
#  28409903,
#  29957778,
#  12829521,
#  3872299,
#  15813077,
#  4167105,
#  1719900,
#  32719472,
#  5588060,
#  29987979,
#  6051807,
#  7276307,
#  4726335,
#  35648891,
#  37915454,
#  8047114,
#  23239726,
#  27756731,
#  1468034,
#  25533339,
#  31013954,
#  20614029,
#  21560224,
#  21184622,
#  20533518,
#  31361753,
#  17380967,
#  15474265,
#  19561993,
#  15278535,
#  6441442,
#  15319015,
#  14069119,
#  38845362,
#  10761585,
#  16108857,
#  28337924,
#  3853766,
#  25931164,
#  23956691,
#  20518771,
#  33221806,
#  13220864,
#  38097862,
#  3621512,
#  14589222,
#  23852456,
#  38038192,
#  1197911,
#  12727063,
#  2964617,
#  9923518,
#  5597649,
#  8854954,
#  14177406,
#  21728956,
#  32907206,
#  3594336,
#  28492377,
#  16440799,
#  24443609,
#  6124398,
#  26400351,
#  5005887,
#  19686394,
#  627123,
#  2524622,
#  14551424,
#  4478603,
#  17982878,
#  6483536,
#  16186061,
#  17819949,
#  711425,
#  1816747,
#  14287120,
#  4478623,
#  21132684,
#  20570090,
#  629409,
#  3519652,
#  28335900,
#  20157585,
#  6969974,
#  454047,
#  21332614,
#  19172708,
#  1105934,
#  18498218,
#  37062224,
#  25862887,
#  20022343,
#  29953718,
#  4029703,
#  29237541,
#  12571883,
#  9152364,
#  38871324,
#  14437751,
#  26634620,
#  7547993,
#  19708962,
#  15996748,
#  19726660,
#  18838317,
#  37956814,
#  469187,
#  9674577,
#  8713302,
#  11133717,
#  14394441,
#  14957016,
#  38323114,
#  23068020,
#  3178765,
#  107051,
#  16881957,
#  16734921,
#  16907014,
#  10761622,
#  3709549,
#  18436650,
#  14089247,
#  29528383,
#  29023661,
#  25730258,
#  18594158,
#  32582637,
#  31021743,
#  31650678,
#  312761,
#  5068357,
#  29591387,
#  872544,
#  17003926,
#  12827223,
#  5911737,
#  12825082,
#  1395902,
#  17598314,
#  2659707,
#  2852239,
#  16091571,
#  18663326,
#  25435268,
#  21980231,
#  30249154,
#  36069213,
#  10372720,
#  33932691,
#  21300718,
#  21108020,
#  453797,
#  19353883,
#  7281936,
#  34012533,
#  37385778,
#  23538032,
#  27103702,
#  880100,
#  4265363,
#  31614824,
#  6979478,
#  20605145,
#  2173335,
#  13009794,
#  13853774,
#  30903475,
#  512882,
#  8436743,
#  12118466,
#  13244001,
#  24884713,
#  4761737,
#  17691357,
#  21132407,
#  11920290,
#  30552232,
#  38122243,
#  14600591,
#  35116851,
#  15764482,
#  26352321,
#  34499687,
#  ...]

# %%
# df_filtered에서 listing_ids에 없는 숙소_id 제거
london_lists_20000 = london_lists[london_lists['숙소_id'].isin(random_samples_ids)]
london_lists_20000
# Out:
#           숙소_id                                 숙소_url     호스트_id 슈퍼호스트  \
# 0        312761    https://www.airbnb.com/rooms/312761    1608226     t
# 1         13913     https://www.airbnb.com/rooms/13913      54730     t
# 2         15400     https://www.airbnb.com/rooms/15400      60302     f
# 3        159736    https://www.airbnb.com/rooms/159736     766056     f
# 4        165336    https://www.airbnb.com/rooms/165336     761400     f
# ...         ...                                    ...        ...   ...
# 33962  38867016  https://www.airbnb.com/rooms/38867016  402191311     f
# 33964  39049983  https://www.airbnb.com/rooms/39049983   35424755     f
# 33982  38871324  https://www.airbnb.com/rooms/38871324  288665110     f
# 33985  39057470  https://www.airbnb.com/rooms/39057470  299347389     f
# 33995  38876344  https://www.airbnb.com/rooms/38876344   93729482     f
#
#                         숙소_지역                        숙소_특징            숙소_유형  \
# 0                     Hackney           Entire rental unit  Entire home/apt
# 1                   Islington  Private room in rental unit     Private room
# 2      Kensington and Chelsea           Entire rental unit  Entire home/apt
# 3                     Lambeth  Private room in rental unit     Private room
# 4      Kensington and Chelsea           Entire rental unit  Entire home/apt
# ...                       ...                          ...              ...
# 33962           Tower Hamlets           Entire rental unit  Entire home/apt
# 33964              Hillingdon         Private room in home     Private room
# 33982                  Camden    Private room in townhouse     Private room
# 33985                  Sutton                  Entire home  Entire home/apt
# 33995               Islington         Private room in home     Private room
#
#        수용_인원수  욕실수  침실수  ...       마지막리뷰  리뷰점수  숙소_정확성_리뷰점수 숙소_청결도_리뷰점수  \
# 0           2  1.0  1.0  ...  2024-02-03  4.96         4.97        4.93
# 1           1  1.0  1.0  ...  2023-11-26  4.80         4.73        4.73
# 2           2  1.0  1.0  ...  2023-05-01  4.80         4.85        4.88
# 3           2  1.0  1.0  ...  2023-04-29  4.72         4.79        4.66
# 4           2  1.0  1.0  ...  2024-03-17  4.74         4.88        4.79
# ...       ...  ...  ...  ...         ...   ...          ...         ...
# 33962       3  1.0  1.0  ...  2023-12-17  4.68         4.95        4.55
# 33964       2  1.0  1.0  ...  2024-02-15  3.94         4.06        4.13
# 33982       4  1.5  1.0  ...  2024-03-03  4.75         4.85        4.83
# 33985       2  1.0  1.0  ...  2024-02-09  4.77         4.83        4.93
# 33995       2  2.5  1.0  ...  2024-03-02  4.57         4.65        4.32
#
#        숙소_체크인_리뷰점수  숙소_소통_리뷰점수  숙소_위치_리뷰점수 숙소_가격_리뷰점수  평균_리뷰수  게스트선호
# 0             4.96        5.00        4.89       4.93    0.86      t
# 1             4.75        4.83        4.70       4.70    0.25      f
# 2             4.88        4.83        4.93       4.74    0.54      f
# 3             4.75        4.89        4.34       4.66    0.62      f
# 4             4.94        4.96        4.87       4.71    1.57      f
# ...            ...         ...         ...        ...     ...    ...
# 33962         4.86        4.91        4.86       4.36    0.41      f
# 33964         4.19        4.19        4.19       4.13    0.57      f
# 33982         4.94        4.93        4.83       4.72    6.15      f
# 33985         4.97        5.00        5.00       4.87    0.56      f
# 33995         4.81        4.80        4.71       4.61    5.12      f
#
# [5931 rows x 27 columns]

# %%
london_lists_20000['게스트선호'].value_counts().plot(kind='bar', figsize=(10,8))
for i, v in enumerate(london_lists_20000['게스트선호'].value_counts()):
    plt.text(i, v, str(v)+ "개", ha='center', va='bottom', fontsize=15)

plt.title('게스트선호 유형별 숙소 수',fontsize=14)
plt.xlabel('게스트 선호 숙소 유무',fontsize=14)
plt.ylabel('숙소수',fontsize=14)
plt.xticks(rotation=0, fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
london_lists_20000.columns
# Out:
# Index(['숙소_id', '숙소_url', '호스트_id', '슈퍼호스트', '숙소_지역', '숙소_특징', '숙소_유형',
#        '수용_인원수', '욕실수', '침실수', '침대수', '편의시설', '숙소_가격', '예약가능여부', '리뷰수',
#        '12개월리뷰수', '30일리뷰수', '마지막리뷰', '리뷰점수', '숙소_정확성_리뷰점수', '숙소_청결도_리뷰점수',
#        '숙소_체크인_리뷰점수', '숙소_소통_리뷰점수', '숙소_위치_리뷰점수', '숙소_가격_리뷰점수', '평균_리뷰수',
#        '게스트선호'],
#       dtype='object')

# %% [markdown]
# 랜덤샘플
#
# - 숙소_정확성_리뷰점수    4.813839
# - 숙소_체크인_리뷰점수    4.864104
# - 숙소_소통_리뷰점수     4.881526
#
# 점수가 높음 <br>
#
# 리뷰점수 평균은 4.76

# %%
review_scores = london_lists_20000[['숙소_정확성_리뷰점수', '숙소_청결도_리뷰점수',
       '숙소_체크인_리뷰점수', '숙소_소통_리뷰점수', '숙소_위치_리뷰점수', '숙소_가격_리뷰점수']].mean().sort_values()
review_scores
# Out:
# 숙소_가격_리뷰점수     4.705665
# 숙소_청결도_리뷰점수    4.743593
# 숙소_위치_리뷰점수     4.789174
# 숙소_정확성_리뷰점수    4.813839
# 숙소_체크인_리뷰점수    4.864104
# 숙소_소통_리뷰점수     4.881526
# dtype: float64

# %%
london_lists_20000['리뷰점수'].mean()
# Out:
# 4.762711178553364

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 예시로 london_lists_20000을 생성합니다. 실제 데이터 프레임을 사용하세요.
# london_lists_20000 = pd.read_csv('path_to_your_file.csv')

# 리뷰 점수 컬럼 선택
review_scores = london_lists_20000[['숙소_정확성_리뷰점수', '숙소_청결도_리뷰점수',
                                    '숙소_체크인_리뷰점수', '숙소_소통_리뷰점수',
                                    '숙소_위치_리뷰점수', '숙소_가격_리뷰점수']]

# 각 리뷰 점수의 분포도 시각화
plt.figure(figsize=(12, 8))
for i, column in enumerate(review_scores.columns, 1):
    plt.subplot(2, 3, i)
    sns.histplot(review_scores[column], bins=30, kde=True)
    plt.title(column)
    plt.xlabel('Score')
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# 리뷰점수 분포 확인

# %%
import plotly.express as px
import plotly.graph_objs as go


# '리뷰점수' 데이터 분포를 시각화
fig = px.histogram(london_lists_20000, x='리뷰점수', nbins=50, title='리뷰점수 분포')
fig.update_layout(bargap=0.2, 
                  width=800, # 그래프 크기 조정
                  height=500,
                  xaxis_title='리뷰점수',
                  yaxis_title='빈도')
fig.show()

# %% [markdown]
# 침대침실욕실 분포<br>
#
# - 침대수 2개
# - 침실수 1개
# - 욕실수 1개

# %%
review_scores = london_lists_20000[['욕실수','침실수','침대수']].mean()

# %%
# 시각화
ax = review_scores.plot(kind='barh', figsize=(10, 8))
plt.title('게스트선호 여부에 따른 욕실침대침실수 비교',fontsize=14)
plt.xlabel('게스트선호 여부',fontsize=14)
plt.ylabel('욕실침대침실수', fontsize=14)
plt.xticks(rotation=0, fontsize=14)
plt.yticks(rotation=0, fontsize=14)

plt.legend(title='욕실침대침실수', bbox_to_anchor=(1., 1), loc='upper left')

# 각 막대 위에 값 표시
for p in ax.patches:
    ax.annotate(f'{round(p.get_width(),0):.2f}개', (p.get_width(), p.get_y() + p.get_height() / 2.), 
                ha='center', va='center', xytext=(10, 0), textcoords='offset points', fontsize=13)
    
plt.show()
# Out:
# C:\Users\Master\AppData\Local\Temp\ipykernel_3548\2613991652.py:9: UserWarning:
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# 수용인원수 분포

# %%
import plotly.express as px
import plotly.graph_objs as go


# '리뷰점수' 데이터 분포를 시각화
fig = px.histogram(london_lists_20000, x='수용_인원수', nbins=50, title='수용인원수 분포')
fig.update_layout(bargap=0.2, 
                  width=800, # 그래프 크기 조정
                  height=500,
                  xaxis_title='수용인원수',
                  yaxis_title='빈도')
fig.show()

# %%
random_sample['리뷰날짜'] = random_sample['리뷰날짜'].dt.year

# %%
random_sample.groupby('숙소_id')['리뷰날짜'].value_counts()
# Out:
# 숙소_id     리뷰날짜
# 13913     2011    1
#           2013    1
# 15400     2011    1
# 17402     2014    2
#           2018    1
#                  ..
# 38999399  2022    3
# 39016057  2020    1
# 39025542  2022    1
# 39049983  2024    1
# 39057470  2022    1
# Name: count, Length: 13861, dtype: int64

# %% [markdown]
# 2019, 2022,2023년의 숙소수가 많이 샘플링 되었다

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

comments_by_year = random_sample.groupby('리뷰날짜')['숙소_id'].count()

for i, v in enumerate(comments_by_year):
    plt.text(i, v, str(v)+ "개", ha='center', va='bottom', fontsize=15)

comments_by_year.plot(kind='bar', figsize=(10, 6))
plt.title('리뷰날짜별 숙소수')
plt.xlabel('작성년도')
plt.ylabel('숙소수')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# 지역별 분포

# %%
import plotly.express as px
import plotly.graph_objs as go

listing_area = london_lists_20000.groupby('숙소_지역').count()

# '리뷰점수' 데이터 분포를 시각화
fig = px.histogram(listing_area, x='숙소_id', nbins=50, title='수용인원수 분포')
fig.update_layout(bargap=0.2, 
                  width=800, # 그래프 크기 조정
                  height=500,
                  xaxis_title='수용인원수',
                  yaxis_title='빈도')
fig.show()

# %% [markdown]
# random_sample 분석

# %%
# !pip install nltk
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp310-cp310-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\master\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\master\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (10.3.0)
# Requirement already satisfied: matplotlib in c:\users\master\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\master\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\master\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\master\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\master\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\master\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\master\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\master\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\master\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp310-cp310-win_amd64.whl (299 kB)
#    ---------------------------------------- 0.0/300.0 kB ? eta -:--:--
#    ---------------------------------------- 300.0/300.0 kB 6.2 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3

# %%
# !pip install textblob

import nltk
nltk.download('brown')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('conll2000')
nltk.download('movie_reviews')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\Master\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Master\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Master\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     C:\Users\Master\AppData\Roaming\nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\Master\AppData\Roaming\nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Master\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Master\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# 텍스트 전처리
#
#
# - 소문자로 변경
# - 토큰화
# - 불용어 제거
# - 어간 추출

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import glob
import re  #정규표현식

from functools import reduce #2차원 >> 1차원

from nltk.tokenize import word_tokenize # word >> token
from nltk.corpus import stopwords  #stopwords >> 불용어
from nltk.stem import WordNetLemmatizer # 어간 분석

from collections import Counter

from wordcloud import STOPWORDS, WordCloud

stopWords = set(stopwords.words('english'))
lemma = WordNetLemmatizer()

words = []
def Pretreatment(text):

    for title in random_sample['리뷰']:
        en_words = re.sub(r"[^a-zA-Z]+"," ",str(title)) #정규표현식 사용, 영문 대소문자 ^ 제외한 문자를 공백 (" ")변경
        en_words_token = word_tokenize(en_words.lower()) # 변환 된 단어를 토큰화
        en_words_stop = [word for word in en_words_token if not word in stopWords] # 불용어 제거
        en_words_lemma = [lemma.lemmatize(word) for word in en_words_stop]  #어간 추출
        words.append(en_words_lemma)

# #진행사항 표시
tqdm.pandas()


Pretreatment(random_sample['리뷰'])

# %%
word_list = list(reduce(lambda x, y: x + y, words))

# %%
word_list
# Out:
# ['suzan',
#  'excellent',
#  'host',
#  'lorinka',
#  'professional',
#  'manager',
#  'flat',
#  'extremely',
#  'well',
#  'situated',
#  'west',
#  'london',
#  'surrey',
#  'border',
#  'mark',
#  'place',
#  'called',
#  'hotel',
#  'missed',
#  'whole',
#  'welcoming',
#  'part',
#  'real',
#  'shame',
#  'expensive',
#  'place',
#  'stay',
#  'terrible',
#  'communication',
#  'wifi',
#  'info',
#  'missing',
#  'room',
#  'one',
#  'answered',
#  'message',
#  'hour',
#  'found',
#  'owner',
#  'detail',
#  'downstairs',
#  'repeatedly',
#  'assured',
#  'wrong',
#  'password',
#  'got',
#  'sorted',
#  'following',
#  'day',
#  'bed',
#  'comfy',
#  'clean',
#  'lovely',
#  'location',
#  'though',
#  'street',
#  'noise',
#  'loud',
#  'carpet',
#  'old',
#  'extremely',
#  'clean',
#  'tidy',
#  'homely',
#  'guest',
#  'house',
#  'warm',
#  'welcome',
#  'helpful',
#  'reliance',
#  'good',
#  'little',
#  'noisy',
#  'isabelle',
#  'home',
#  'quiet',
#  'spacious',
#  'everything',
#  'need',
#  'photo',
#  'describe',
#  'extremely',
#  'accurate',
#  'thank',
#  'isabelle',
#  'friend',
#  'lovely',
#  'stay',
#  'peaceful',
#  'spot',
#  'notting',
#  'hill',
#  'away',
#  'busyness',
#  'central',
#  'london',
#  'also',
#  'super',
#  'close',
#  'shopping',
#  'eating',
#  'neighborhood',
#  'offer',
#  'space',
#  'well',
#  'organized',
#  'perfect',
#  'blend',
#  'modern',
#  'cozy',
#  'clifford',
#  'super',
#  'easy',
#  'communicate',
#  'generous',
#  'host',
#  'seamless',
#  'comfortable',
#  'glad',
#  'landed',
#  'scared',
#  'say',
#  'ho',
#  'wonderful',
#  'stay',
#  'always',
#  'denize',
#  'robert',
#  'may',
#  'get',
#  'stay',
#  'need',
#  'fantastic',
#  'really',
#  'susan',
#  'place',
#  'great',
#  'location',
#  'outside',
#  'main',
#  'hub',
#  'bub',
#  'city',
#  'short',
#  'walking',
#  'distance',
#  'shop',
#  'restaurant',
#  'pub',
#  'tube',
#  'house',
#  'big',
#  'comfortable',
#  'bed',
#  'large',
#  'master',
#  'suite',
#  'bathroom',
#  'great',
#  'three',
#  'u',
#  'could',
#  'fit',
#  'two',
#  'nicely',
#  'susan',
#  'great',
#  'host',
#  'town',
#  'responded',
#  'quickly',
#  'request',
#  'happy',
#  'stay',
#  'home',
#  'clean',
#  'comfortable',
#  'well',
#  'designed',
#  'julija',
#  'vilius',
#  'outstanding',
#  'host',
#  'two',
#  'lovely',
#  'week',
#  'aida',
#  'place',
#  'could',
#  'visit',
#  'area',
#  'due',
#  'self',
#  'isolation',
#  'aida',
#  'helpful',
#  'anyways',
#  'recommend',
#  'close',
#  'tube',
#  'restaurant',
#  'shopping',
#  'unique',
#  'part',
#  'town',
#  'building',
#  'flat',
#  'de',
#  'communicative',
#  'provided',
#  'excellent',
#  'instruction',
#  'enter',
#  'flat',
#  'lot',
#  'cozy',
#  'homey',
#  'touch',
#  'bit',
#  'far',
#  'central',
#  'london',
#  'bar',
#  'club',
#  'light',
#  'sleeper',
#  'might',
#  'best',
#  'choice',
#  'naomi',
#  'accomodating',
#  'room',
#  'clean',
#  'advertised',
#  'would',
#  'stay',
#  'decent',
#  'kitchen',
#  'well',
#  'equipped',
#  'tenant',
#  'friendly',
#  'would',
#  'definitely',
#  'stay',
#  'great',
#  'location',
#  'family',
#  'live',
#  'area',
#  'second',
#  'time',
#  'booking',
#  'place',
#  'spacious',
#  'river',
#  'view',
#  'parking',
#  'code',
#  'bit',
#  'hassle',
#  'contact',
#  'sort',
#  'quickly',
#  'second',
#  'stay',
#  'juan',
#  'carlos',
#  'everything',
#  'great',
#  'clean',
#  'place',
#  'quiet',
#  'close',
#  'plenty',
#  'restaurant',
#  'tube',
#  'complaint',
#  'definitely',
#  'stay',
#  'always',
#  'real',
#  'pleasure',
#  'spend',
#  'time',
#  'alice',
#  'home',
#  'alice',
#  'lively',
#  'immediately',
#  'respond',
#  'friendly',
#  'many',
#  'thanks',
#  'great',
#  'location',
#  'easy',
#  'jump',
#  'underground',
#  'lot',
#  'shopping',
#  'ton',
#  'restaurant',
#  'tourist',
#  'site',
#  'within',
#  'walking',
#  'distance',
#  'well',
#  'stay',
#  'mary',
#  'place',
#  'great',
#  'really',
#  'nice',
#  'also',
#  'helpful',
#  'especially',
#  'thing',
#  'brixton',
#  'london',
#  'general',
#  'friend',
#  'would',
#  'book',
#  'room',
#  'nice',
#  'apartment',
#  'amit',
#  'great',
#  'understanding',
#  'host',
#  'lovely',
#  'studio',
#  'set',
#  'nice',
#  'location',
#  'london',
#  'close',
#  'transport',
#  'link',
#  'nice',
#  'restaurant',
#  'option',
#  'everything',
#  'needed',
#  'including',
#  'fridge',
#  'washer',
#  'dryer',
#  'great',
#  'communication',
#  'host',
#  'would',
#  'recommend',
#  'great',
#  'stay',
#  'antonio',
#  'place',
#  'night',
#  'bus',
#  'stop',
#  'outside',
#  'flat',
#  'close',
#  'proximity',
#  'underground',
#  'min',
#  'walking',
#  'distance',
#  'nice',
#  'attraction',
#  'min',
#  'good',
#  'local',
#  'tip',
#  'term',
#  'see',
#  'especially',
#  'restaurant',
#  'wonderful',
#  'place',
#  'stay',
#  'would',
#  'definitely',
#  'stay',
#  'welcoming',
#  'helpful',
#  'friendly',
#  'clean',
#  'comfortable',
#  'much',
#  'enjoyed',
#  'stay',
#  'excellent',
#  'hospitality',
#  'exactly',
#  'described',
#  'lovely',
#  'breakfast',
#  'thanks',
#  'anna',
#  'everything',
#  'needed',
#  'look',
#  'forward',
#  'staying',
#  'warm',
#  'stylish',
#  'comfortable',
#  'flat',
#  'ideal',
#  'location',
#  'u',
#  'near',
#  'family',
#  'public',
#  'transit',
#  'shopping',
#  'michael',
#  'pleasure',
#  'deal',
#  'always',
#  'responsive',
#  'helpful',
#  'stayed',
#  'month',
#  'truly',
#  'made',
#  'home',
#  'away',
#  'home',
#  'feature',
#  'include',
#  'separate',
#  'well',
#  'equipped',
#  'kitchen',
#  'bedroom',
#  'probably',
#  'comfortable',
#  'bed',
#  'ever',
#  'slept',
#  'nice',
#  'size',
#  'living',
#  'room',
#  'balcony',
#  'versatile',
#  'dining',
#  'area',
#  'enough',
#  'seating',
#  'make',
#  'hanging',
#  'easy',
#  'liked',
#  'looking',
#  'arsenal',
#  'watching',
#  'neighborhood',
#  'folk',
#  'take',
#  'advantage',
#  'public',
#  'plaza',
#  'well',
#  'insulated',
#  'window',
#  'made',
#  'noise',
#  'non',
#  'issue',
#  'neighborhood',
#  'lot',
#  'international',
#  'restaurant',
#  'grocery',
#  'store',
#  'building',
#  'resident',
#  'friendly',
#  'would',
#  'definitely',
#  'stay',
#  'best',
#  'time',
#  'taylan',
#  'room',
#  'lovely',
#  'clean',
#  'comfortable',
#  'bathroom',
#  'kitchen',
#  'great',
#  'everything',
#  'need',
#  'wifi',
#  'fast',
#  'perfect',
#  'needed',
#  'work',
#  'computer',
#  'time',
#  'really',
#  'felt',
#  'home',
#  'wish',
#  'could',
#  'stay',
#  'airbnb',
#  'quiet',
#  'place',
#  'except',
#  'neighbor',
#  'arrived',
#  'one',
#  'day',
#  'unfortunately',
#  'really',
#  'respectful',
#  'others',
#  'taylan',
#  'responsive',
#  'told',
#  'behave',
#  'load',
#  'restaurant',
#  'bar',
#  'supermarket',
#  'around',
#  'definitely',
#  'recommend',
#  'place',
#  'come',
#  'back',
#  'excellent',
#  'location',
#  'sparkling',
#  'clean',
#  'welcoming',
#  'host',
#  'good',
#  'breakfast',
#  'quiet',
#  'delightful',
#  'stay',
#  'geraldine',
#  'place',
#  'truly',
#  'kind',
#  'welcoming',
#  'host',
#  'ensured',
#  'comfort',
#  'provided',
#  'everything',
#  'needed',
#  'area',
#  'wonderfully',
#  'peaceful',
#  'pleasant',
#  'business',
#  'obligation',
#  'near',
#  'tower',
#  'hill',
#  'minute',
#  'walk',
#  'southfields',
#  'tube',
#  'station',
#  'made',
#  'daily',
#  'commute',
#  'smooth',
#  'experience',
#  'house',
#  'beautifully',
#  'decorated',
#  'clean',
#  'comfortable',
#  'bedroom',
#  'necessary',
#  'amenity',
#  'stay',
#  'highly',
#  'recommend',
#  'accommodation',
#  'london',
#  'visit',
#  'especially',
#  'want',
#  'stay',
#  'safe',
#  'central',
#  'area',
#  'cristina',
#  'extremely',
#  'responsive',
#  'location',
#  'absolutely',
#  'perfect',
#  'dad',
#  'made',
#  'trip',
#  'see',
#  'beautiful',
#  'spur',
#  'play',
#  'great',
#  'time',
#  'thanks',
#  'much',
#  'wonderful',
#  'option',
#  'give',
#  'unique',
#  'experience',
#  'london',
#  'lifestyle',
#  'friendly',
#  'neighborhood',
#  'traveling',
#  'alone',
#  'make',
#  'new',
#  'friend',
#  'great',
#  'stay',
#  'everything',
#  'great',
#  'clean',
#  'comfy',
#  'immaculate',
#  'good',
#  'bed',
#  'shower',
#  'nice',
#  'thick',
#  'carpet',
#  'thank',
#  'good',
#  'airbnb',
#  'spot',
#  'super',
#  'well',
#  'located',
#  'dalston',
#  'lane',
#  'shoreditch',
#  'lot',
#  'place',
#  'go',
#  'drink',
#  'grab',
#  'bite',
#  'around',
#  'room',
#  'clean',
#  'bed',
#  'comfy',
#  'perfect',
#  'stay',
#  'spent',
#  'weekend',
#  'russell',
#  'apartment',
#  'comfortable',
#  'great',
#  'place',
#  'explore',
#  'city',
#  'good',
#  'host',
#  'great',
#  'stay',
#  'fantastic',
#  'base',
#  'explore',
#  'london',
#  'brilliant',
#  'two',
#  'bedroom',
#  'apartment',
#  'exactly',
#  'looking',
#  'highly',
#  'recommend',
#  'oliver',
#  'friendly',
#  'attentive',
#  'host',
#  'provided',
#  'u',
#  'hand',
#  'drawn',
#  'map',
#  'london',
#  'well',
#  'sightseeing',
#  'tipps',
#  'appreciated',
#  'warm',
#  'welcome',
#  'received',
#  'even',
#  'though',
#  'arrived',
#  'much',
#  'later',
#  'anticiparted',
#  'apartment',
#  'superbly',
#  'located',
#  'le',
#  'minute',
#  'marble',
#  'arch',
#  'wish',
#  'place',
#  'cleaner',
#  'looked',
#  'neat',
#  'picture',
#  'anything',
#  'else',
#  'fine',
#  'room',
#  'realy',
#  'nice',
#  'clean',
#  'everything',
#  'new',
#  'look',
#  'like',
#  'photo',
#  'bed',
#  'comfortabe',
#  'alex',
#  'best',
#  'host',
#  'picked',
#  'tube',
#  'station',
#  'near',
#  'house',
#  'helped',
#  'luggage',
#  'thankfull',
#  'first',
#  'visit',
#  'london',
#  'first',
#  'time',
#  'traveling',
#  'solo',
#  'amazing',
#  'time',
#  'jenny',
#  'family',
#  'really',
#  'nice',
#  'people',
#  'studio',
#  'perfect',
#  'tidy',
#  'lot',
#  'useful',
#  'appliance',
#  'like',
#  'washing',
#  'machine',
#  'nice',
#  'safe',
#  'neighborhood',
#  'easy',
#  'reach',
#  'town',
#  'city',
#  'via',
#  'public',
#  'transport',
#  'would',
#  'love',
#  'stay',
#  'sometime',
#  'read',
#  'review',
#  'booked',
#  'one',
#  'slightly',
#  'concerned',
#  'say',
#  'place',
#  'exceeded',
#  'expectation',
#  'better',
#  'picture',
#  'suggested',
#  'dead',
#  'easy',
#  'find',
#  'great',
#  'instruction',
#  'good',
#  'location',
#  'fantastic',
#  'time',
#  'london',
#  'cindy',
#  'place',
#  'roomy',
#  'comfortable',
#  'stylish',
#  'accessible',
#  'city',
#  'couple',
#  'time',
#  'day',
#  'garden',
#  'back',
#  'lovely',
#  'neighborhood',
#  'good',
#  'cute',
#  'little',
#  'restaurant',
#  'within',
#  'couple',
#  'block',
#  'reached',
#  'cindy',
#  'always',
#  'responded',
#  'definitely',
#  'recommend',
#  'nice',
#  'room',
#  'good',
#  'host',
#  'wonderful',
#  'place',
#  'setting',
#  'absolutely',
#  'beautiful',
#  'host',
#  'friendly',
#  'welcoming',
#  'close',
#  'transportation',
#  'help',
#  'sally',
#  'chris',
#  'able',
#  'find',
#  'way',
#  'splendidly',
#  'would',
#  'highly',
#  'recommend',
#  'true',
#  'bnb',
#  'great',
#  'staff',
#  'amazing',
#  'location',
#  'lovely',
#  'room',
#  'great',
#  'host',
#  'room',
#  'clean',
#  'easy',
#  'location',
#  'definitely',
#  'come',
#  'back',
#  'thanks',
#  'great',
#  'place',
#  'fantastic',
#  'host',
#  'lovely',
#  'location',
#  'check',
#  'smooth',
#  'brilliant',
#  'continental',
#  'breakfast',
#  'available',
#  'house',
#  'clean',
#  'tidy',
#  'lovely',
#  'stay',
#  'beautiful',
#  'apartment',
#  'richard',
#  'perfect',
#  'host',
#  'recommendable',
#  'great',
#  'place',
#  'nice',
#  'view',
#  'canal',
#  'serena',
#  'apartment',
#  'ideally',
#  'located',
#  'right',
#  'vauxhall',
#  'station',
#  'really',
#  'comfortable',
#  'place',
#  'base',
#  'returned',
#  'several',
#  'time',
#  'always',
#  'enjoy',
#  'stay',
#  'always',
#  'make',
#  'sure',
#  'well',
#  'looked',
#  'value',
#  'money',
#  'want',
#  'simple',
#  'stay',
#  'sleep',
#  'shower',
#  'first',
#  'time',
#  'using',
#  'airbnb',
#  'laurent',
#  'great',
#  'unit',
#  'exactly',
#  'expected',
#  'super',
#  'responsive',
#  'hard',
#  'find',
#  'hotel',
#  'accommodation',
#  'family',
#  'glad',
#  'stayed',
#  'really',
#  'seemed',
#  'like',
#  'home',
#  'away',
#  'home',
#  'thr',
#  'room',
#  'airy',
#  'good',
#  'sunshine',
#  'location',
#  'great',
#  'bus',
#  'central',
#  'walking',
#  'distance',
#  'haggerston',
#  'overground',
#  'walking',
#  'distance',
#  'kingsland',
#  'road',
#  'pub',
#  'vietnamese',
#  'restaurant',
#  'broadway',
#  'market',
#  'walk',
#  'min',
#  'along',
#  'canal',
#  'kitchen',
#  'fully',
#  'equipped',
#  'water',
#  'boiler',
#  'door',
#  'lock',
#  'may',
#  'bit',
#  'difficult',
#  'anne',
#  'give',
#  'tip',
#  ...]

# %%
# file_name = '../../../../data/Airbnb_London/20000_word_list.txt' 

# with open(file_name, 'w+') as file :
#     file.write('\n'.join(word_list))

# %%
pd.Series(word_list).value_counts().head(20)
# Out:
# great          10519
# stay           10145
# place           8995
# location        7122
# host            6735
# london          6149
# clean           6000
# room            5468
# nice            4669
# would           4639
# recommend       4018
# good            3989
# lovely          3987
# flat            3878
# apartment       3863
# comfortable     3743
# really          3632
# everything      3373
# u               3250
# well            3174
# Name: count, dtype: int64

# %% [markdown]
# 불용어 추가 제거

# %%
def remove_stopword(word_list, stopwords):
    return [word for word in word_list if word not in stopwords]

word_list = word_list 
stopwords = ['great', 'good', 'nice', 'would', 'place', 'stay','apartment','house','room','host','comfortable', 
             'amazing','perfect','wonderful','excellent','lovely','highly','recommend','definitely', 'really',
             'london','u', 'everything', 'well', 'home','helpful','also']
filtered_word_list = remove_stopword(word_list, stopwords)
filtered_word_list
# Out:
# ['suzan',
#  'lorinka',
#  'professional',
#  'manager',
#  'flat',
#  'extremely',
#  'situated',
#  'west',
#  'surrey',
#  'border',
#  'mark',
#  'called',
#  'hotel',
#  'missed',
#  'whole',
#  'welcoming',
#  'part',
#  'real',
#  'shame',
#  'expensive',
#  'terrible',
#  'communication',
#  'wifi',
#  'info',
#  'missing',
#  'one',
#  'answered',
#  'message',
#  'hour',
#  'found',
#  'owner',
#  'detail',
#  'downstairs',
#  'repeatedly',
#  'assured',
#  'wrong',
#  'password',
#  'got',
#  'sorted',
#  'following',
#  'day',
#  'bed',
#  'comfy',
#  'clean',
#  'location',
#  'though',
#  'street',
#  'noise',
#  'loud',
#  'carpet',
#  'old',
#  'extremely',
#  'clean',
#  'tidy',
#  'homely',
#  'guest',
#  'warm',
#  'welcome',
#  'reliance',
#  'little',
#  'noisy',
#  'isabelle',
#  'quiet',
#  'spacious',
#  'need',
#  'photo',
#  'describe',
#  'extremely',
#  'accurate',
#  'thank',
#  'isabelle',
#  'friend',
#  'peaceful',
#  'spot',
#  'notting',
#  'hill',
#  'away',
#  'busyness',
#  'central',
#  'super',
#  'close',
#  'shopping',
#  'eating',
#  'neighborhood',
#  'offer',
#  'space',
#  'organized',
#  'blend',
#  'modern',
#  'cozy',
#  'clifford',
#  'super',
#  'easy',
#  'communicate',
#  'generous',
#  'seamless',
#  'glad',
#  'landed',
#  'scared',
#  'say',
#  'ho',
#  'always',
#  'denize',
#  'robert',
#  'may',
#  'get',
#  'need',
#  'fantastic',
#  'susan',
#  'location',
#  'outside',
#  'main',
#  'hub',
#  'bub',
#  'city',
#  'short',
#  'walking',
#  'distance',
#  'shop',
#  'restaurant',
#  'pub',
#  'tube',
#  'big',
#  'bed',
#  'large',
#  'master',
#  'suite',
#  'bathroom',
#  'three',
#  'could',
#  'fit',
#  'two',
#  'nicely',
#  'susan',
#  'town',
#  'responded',
#  'quickly',
#  'request',
#  'happy',
#  'clean',
#  'designed',
#  'julija',
#  'vilius',
#  'outstanding',
#  'two',
#  'week',
#  'aida',
#  'could',
#  'visit',
#  'area',
#  'due',
#  'self',
#  'isolation',
#  'aida',
#  'anyways',
#  'close',
#  'tube',
#  'restaurant',
#  'shopping',
#  'unique',
#  'part',
#  'town',
#  'building',
#  'flat',
#  'de',
#  'communicative',
#  'provided',
#  'instruction',
#  'enter',
#  'flat',
#  'lot',
#  'cozy',
#  'homey',
#  'touch',
#  'bit',
#  'far',
#  'central',
#  'bar',
#  'club',
#  'light',
#  'sleeper',
#  'might',
#  'best',
#  'choice',
#  'naomi',
#  'accomodating',
#  'clean',
#  'advertised',
#  'decent',
#  'kitchen',
#  'equipped',
#  'tenant',
#  'friendly',
#  'location',
#  'family',
#  'live',
#  'area',
#  'second',
#  'time',
#  'booking',
#  'spacious',
#  'river',
#  'view',
#  'parking',
#  'code',
#  'bit',
#  'hassle',
#  'contact',
#  'sort',
#  'quickly',
#  'second',
#  'juan',
#  'carlos',
#  'clean',
#  'quiet',
#  'close',
#  'plenty',
#  'restaurant',
#  'tube',
#  'complaint',
#  'always',
#  'real',
#  'pleasure',
#  'spend',
#  'time',
#  'alice',
#  'alice',
#  'lively',
#  'immediately',
#  'respond',
#  'friendly',
#  'many',
#  'thanks',
#  'location',
#  'easy',
#  'jump',
#  'underground',
#  'lot',
#  'shopping',
#  'ton',
#  'restaurant',
#  'tourist',
#  'site',
#  'within',
#  'walking',
#  'distance',
#  'mary',
#  'especially',
#  'thing',
#  'brixton',
#  'general',
#  'friend',
#  'book',
#  'amit',
#  'understanding',
#  'studio',
#  'set',
#  'location',
#  'close',
#  'transport',
#  'link',
#  'restaurant',
#  'option',
#  'needed',
#  'including',
#  'fridge',
#  'washer',
#  'dryer',
#  'communication',
#  'antonio',
#  'night',
#  'bus',
#  'stop',
#  'outside',
#  'flat',
#  'close',
#  'proximity',
#  'underground',
#  'min',
#  'walking',
#  'distance',
#  'attraction',
#  'min',
#  'local',
#  'tip',
#  'term',
#  'see',
#  'especially',
#  'restaurant',
#  'welcoming',
#  'friendly',
#  'clean',
#  'much',
#  'enjoyed',
#  'hospitality',
#  'exactly',
#  'described',
#  'breakfast',
#  'thanks',
#  'anna',
#  'needed',
#  'look',
#  'forward',
#  'staying',
#  'warm',
#  'stylish',
#  'flat',
#  'ideal',
#  'location',
#  'near',
#  'family',
#  'public',
#  'transit',
#  'shopping',
#  'michael',
#  'pleasure',
#  'deal',
#  'always',
#  'responsive',
#  'stayed',
#  'month',
#  'truly',
#  'made',
#  'away',
#  'feature',
#  'include',
#  'separate',
#  'equipped',
#  'kitchen',
#  'bedroom',
#  'probably',
#  'bed',
#  'ever',
#  'slept',
#  'size',
#  'living',
#  'balcony',
#  'versatile',
#  'dining',
#  'area',
#  'enough',
#  'seating',
#  'make',
#  'hanging',
#  'easy',
#  'liked',
#  'looking',
#  'arsenal',
#  'watching',
#  'neighborhood',
#  'folk',
#  'take',
#  'advantage',
#  'public',
#  'plaza',
#  'insulated',
#  'window',
#  'made',
#  'noise',
#  'non',
#  'issue',
#  'neighborhood',
#  'lot',
#  'international',
#  'restaurant',
#  'grocery',
#  'store',
#  'building',
#  'resident',
#  'friendly',
#  'best',
#  'time',
#  'taylan',
#  'clean',
#  'bathroom',
#  'kitchen',
#  'need',
#  'wifi',
#  'fast',
#  'needed',
#  'work',
#  'computer',
#  'time',
#  'felt',
#  'wish',
#  'could',
#  'airbnb',
#  'quiet',
#  'except',
#  'neighbor',
#  'arrived',
#  'one',
#  'day',
#  'unfortunately',
#  'respectful',
#  'others',
#  'taylan',
#  'responsive',
#  'told',
#  'behave',
#  'load',
#  'restaurant',
#  'bar',
#  'supermarket',
#  'around',
#  'come',
#  'back',
#  'location',
#  'sparkling',
#  'clean',
#  'welcoming',
#  'breakfast',
#  'quiet',
#  'delightful',
#  'geraldine',
#  'truly',
#  'kind',
#  'welcoming',
#  'ensured',
#  'comfort',
#  'provided',
#  'needed',
#  'area',
#  'wonderfully',
#  'peaceful',
#  'pleasant',
#  'business',
#  'obligation',
#  'near',
#  'tower',
#  'hill',
#  'minute',
#  'walk',
#  'southfields',
#  'tube',
#  'station',
#  'made',
#  'daily',
#  'commute',
#  'smooth',
#  'experience',
#  'beautifully',
#  'decorated',
#  'clean',
#  'bedroom',
#  'necessary',
#  'amenity',
#  'accommodation',
#  'visit',
#  'especially',
#  'want',
#  'safe',
#  'central',
#  'area',
#  'cristina',
#  'extremely',
#  'responsive',
#  'location',
#  'absolutely',
#  'dad',
#  'made',
#  'trip',
#  'see',
#  'beautiful',
#  'spur',
#  'play',
#  'time',
#  'thanks',
#  'much',
#  'option',
#  'give',
#  'unique',
#  'experience',
#  'lifestyle',
#  'friendly',
#  'neighborhood',
#  'traveling',
#  'alone',
#  'make',
#  'new',
#  'friend',
#  'clean',
#  'comfy',
#  'immaculate',
#  'bed',
#  'shower',
#  'thick',
#  'carpet',
#  'thank',
#  'airbnb',
#  'spot',
#  'super',
#  'located',
#  'dalston',
#  'lane',
#  'shoreditch',
#  'lot',
#  'go',
#  'drink',
#  'grab',
#  'bite',
#  'around',
#  'clean',
#  'bed',
#  'comfy',
#  'spent',
#  'weekend',
#  'russell',
#  'explore',
#  'city',
#  'fantastic',
#  'base',
#  'explore',
#  'brilliant',
#  'two',
#  'bedroom',
#  'exactly',
#  'looking',
#  'oliver',
#  'friendly',
#  'attentive',
#  'provided',
#  'hand',
#  'drawn',
#  'map',
#  'sightseeing',
#  'tipps',
#  'appreciated',
#  'warm',
#  'welcome',
#  'received',
#  'even',
#  'though',
#  'arrived',
#  'much',
#  'later',
#  'anticiparted',
#  'superbly',
#  'located',
#  'le',
#  'minute',
#  'marble',
#  'arch',
#  'wish',
#  'cleaner',
#  'looked',
#  'neat',
#  'picture',
#  'anything',
#  'else',
#  'fine',
#  'realy',
#  'clean',
#  'new',
#  'look',
#  'like',
#  'photo',
#  'bed',
#  'comfortabe',
#  'alex',
#  'best',
#  'picked',
#  'tube',
#  'station',
#  'near',
#  'helped',
#  'luggage',
#  'thankfull',
#  'first',
#  'visit',
#  'first',
#  'time',
#  'traveling',
#  'solo',
#  'time',
#  'jenny',
#  'family',
#  'people',
#  'studio',
#  'tidy',
#  'lot',
#  'useful',
#  'appliance',
#  'like',
#  'washing',
#  'machine',
#  'safe',
#  'neighborhood',
#  'easy',
#  'reach',
#  'town',
#  'city',
#  'via',
#  'public',
#  'transport',
#  'love',
#  'sometime',
#  'read',
#  'review',
#  'booked',
#  'one',
#  'slightly',
#  'concerned',
#  'say',
#  'exceeded',
#  'expectation',
#  'better',
#  'picture',
#  'suggested',
#  'dead',
#  'easy',
#  'find',
#  'instruction',
#  'location',
#  'fantastic',
#  'time',
#  'cindy',
#  'roomy',
#  'stylish',
#  'accessible',
#  'city',
#  'couple',
#  'time',
#  'day',
#  'garden',
#  'back',
#  'neighborhood',
#  'cute',
#  'little',
#  'restaurant',
#  'within',
#  'couple',
#  'block',
#  'reached',
#  'cindy',
#  'always',
#  'responded',
#  'setting',
#  'absolutely',
#  'beautiful',
#  'friendly',
#  'welcoming',
#  'close',
#  'transportation',
#  'help',
#  'sally',
#  'chris',
#  'able',
#  'find',
#  'way',
#  'splendidly',
#  'true',
#  'bnb',
#  'staff',
#  'location',
#  'clean',
#  'easy',
#  'location',
#  'come',
#  'back',
#  'thanks',
#  'fantastic',
#  'location',
#  'check',
#  'smooth',
#  'brilliant',
#  'continental',
#  'breakfast',
#  'available',
#  'clean',
#  'tidy',
#  'beautiful',
#  'richard',
#  'recommendable',
#  'view',
#  'canal',
#  'serena',
#  'ideally',
#  'located',
#  'right',
#  'vauxhall',
#  'station',
#  'base',
#  'returned',
#  'several',
#  'time',
#  'always',
#  'enjoy',
#  'always',
#  'make',
#  'sure',
#  'looked',
#  'value',
#  'money',
#  'want',
#  'simple',
#  'sleep',
#  'shower',
#  'first',
#  'time',
#  'using',
#  'airbnb',
#  'laurent',
#  'unit',
#  'exactly',
#  'expected',
#  'super',
#  'responsive',
#  'hard',
#  'find',
#  'hotel',
#  'accommodation',
#  'family',
#  'glad',
#  'stayed',
#  'seemed',
#  'like',
#  'away',
#  'thr',
#  'airy',
#  'sunshine',
#  'location',
#  'bus',
#  'central',
#  'walking',
#  'distance',
#  'haggerston',
#  'overground',
#  'walking',
#  'distance',
#  'kingsland',
#  'road',
#  'pub',
#  'vietnamese',
#  'restaurant',
#  'broadway',
#  'market',
#  'walk',
#  'min',
#  'along',
#  'canal',
#  'kitchen',
#  'fully',
#  'equipped',
#  'water',
#  'boiler',
#  'door',
#  'lock',
#  'may',
#  'bit',
#  'difficult',
#  'anne',
#  'give',
#  'tip',
#  'weekly',
#  'cleaner',
#  'keep',
#  'clean',
#  'nick',
#  'friendly',
#  'welcoming',
#  'although',
#  'somewhat',
#  'small',
#  'common',
#  'kitchen',
#  'living',
#  'area',
#  'located',
#  'next',
#  'mortlake',
#  'train',
#  'station',
#  'within',
#  'short',
#  'walk',
#  'bus',
#  'central',
#  'shop',
#  'grocery',
#  'store',
#  'minute',
#  'away',
#  'surrounding',
#  'area',
#  'without',
#  'question',
#  'nick',
#  'future',
#  'location',
#  'comfort',
#  'could',
#  'setting',
#  'ballet',
#  'titled',
#  'american',
#  'hard',
#  'overstate',
#  'regent',
#  'park',
#  'transportation',
#  'doorstep',
#  'every',
#  'direction',
#  'returning',
#  'felt',
#  'like',
#  'coming',
#  'grab',
#  'one',
#  'location',
#  'david',
#  'responsive',
#  'check',
#  'easy',
#  'fantastic',
#  'loved',
#  'cozy',
#  'located',
#  'close',
#  'metro',
#  'bus',
#  'park',
#  'walk',
#  'around',
#  'liked',
#  'neighborhood',
#  'often',
#  'market',
#  'lot',
#  'food',
#  'offer',
#  'hostess',
#  'attentive',
#  'communication',
#  'enjoyed',
#  'quiet',
#  'quiet',
#  'neighborhood',
#  'clean',
#  'go',
#  'family',
#  'hope',
#  'return',
#  'soon',
#  'thank',
#  'much',
#  'alex',
#  'graciously',
#  'accommodated',
#  'short',
#  'notice',
#  'location',
#  'fantastic',
#  'clean',
#  'requirement',
#  'thoroughly',
#  'enjoyed',
#  'come',
#  'back',
#  'george',
#  'comfy',
#  'communicator',
#  'location',
#  'space',
#  'incredible',
#  'view',
#  'impeccable',
#  'facility',
#  'lot',
#  'small',
#  'touch',
#  'flat',
#  'clear',
#  'accurate',
#  'information',
#  'stunning',
#  'building',
#  'strong',
#  'security',
#  'moment',
#  'arrived',
#  'isabelle',
#  'made',
#  'feel',
#  'offering',
#  'practically',
#  'entire',
#  'nothing',
#  'suggest',
#  'exceeded',
#  'expectation',
#  'sad',
#  'leave',
#  'miss',
#  'long',
#  'morning',
#  'chat',
#  'extended',
#  'delicious',
#  'breakfast',
#  'know',
#  'away',
#  'isabelle',
#  'value',
#  'accommodating',
#  'close',
#  'tube',
#  'station',
#  'rated',
#  'expected',
#  'due',
#  'fact',
#  'expected',
#  'fantastic',
#  'fantastic',
#  'accommodation',
#  'easy',
#  'get',
#  'super',
#  'clean',
#  'david',
#  'quick',
#  'respond',
#  'inquiry',
#  'enjoyed',
#  'katherine',
#  'might',
#  'occasionally',
#  'see',
#  'throughout',
#  'day',
#  'know',
#  'silently',
#  'operating',
#  'background',
#  'making',
#  'sure',
#  'cared',
#  'location',
#  'next',
#  'pimlico',
#  'station',
#  'short',
#  'walk',
#  'thames',
#  'trail',
#  'take',
#  'directly',
#  'central',
#  'kind',
#  'hearted',
#  'flexible',
#  'miss',
#  'lot',
#  'sheila',
#  'irma',
#  'best',
#  'gave',
#  'lot',
#  'tip',
#  'welcoming',
#  'friendly',
#  'super',
#  'clean',
#  'located',
#  'minute',
#  'walk',
#  'overground',
#  'station',
#  'made',
#  'getting',
#  'city',
#  'easy',
#  'super',
#  'market',
#  'next',
#  'station',
#  'convenient',
#  'karen',
#  'exceptional',
#  'equipped',
#  'need',
#  'kesha',
#  'kind',
#  'able',
#  'use',
#  'kundalini',
#  'yoga',
#  'morning',
#  'important',
#  'thank',
#  'kesha',
#  'hope',
#  'see',
#  'soon',
#  'warm',
#  'welcome',
#  'personal',
#  'touch',
#  ...]

# %%
pd.Series(filtered_word_list).value_counts().head(20)
# Out:
# location      7122
# clean         6000
# flat          3878
# station       3108
# easy          2968
# close         2867
# time          2730
# walk          2708
# friendly      2244
# quiet         2221
# area          2197
# tube          2166
# bed           2160
# minute        2030
# need          1960
# bus           1787
# get           1750
# check         1710
# restaurant    1670
# like          1605
# Name: count, dtype: int64

# %% [markdown]
# 불용어를 더 제거할 필요가 있어보임

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

word_counts = pd.Series(filtered_word_list).value_counts().head(100)

# 워드클라우드를 생성
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_counts)

# 워드클라우드 시각화
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# TF-IDF 실행

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.0-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\master\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\master\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\master\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.4.2)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.5.0-cp310-cp310-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 10.0 MB/s eta 0:00:02
#    ------ --------------------------------- 1.9/11.0 MB 20.4 MB/s eta 0:00:01
#    -------- ------------------------------- 2.4/11.0 MB 17.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.0/11.0 MB 16.1 MB/s eta 0:00:01
#    --------------- ------------------------ 4.3/11.0 MB 17.1 MB/s eta 0:00:01
#    ------------------------- -------------- 6.9/11.0 MB 24.6 MB/s eta 0:00:01
#    --------------------------------- ------ 9.1/11.0 MB 27.8 MB/s eta 0:00:01
#    -------------------------------------- - 10.5/11.0 MB 28.5 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 25.2 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scikit-learn
# Successfully installed scikit-learn-1.5.0 threadpoolctl-3.5.0

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 예시 리뷰 데이터
reviews = random_sample['리뷰'].tolist() * 20000

# 불용어 리스트 정의
stopwords = ['a', 'an', 'the', 'and', 'or', 'but', 'if', 'then', 'when', 'at', 'by', 'for', 'with', 
             'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 
             'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 
             'further', 'then', 'once', 'here', 'there', 'all', 'any', 'both', 'each', 'few', 'more', 
             'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 
             'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now', 'place', 'stay', 
             'apartment', 'house', 'room', 'host', 'location', 'nice', 'great', 'good', 'clean', 
             'comfortable', 'amazing', 'perfect', 'wonderful', 'excellent', 'lovely', 'highly', 
             'recommend', 'would', 'definitely', 'check-in', 'check-out','was', 'we', 'it', 'of', 
             'you', 'london','had', 'flat','really', 'as', 'everything','this','our','easy','my','close','friendly','well','helpful']

# 리뷰 데이터에서 불용어를 제거하는 함수 정의
def remove_stopwords(text):
    return ' '.join([word for word in text.lower().split() if word not in stopwords])

# 불용어 제거된 리뷰 데이터 생성
processed_reviews = [remove_stopwords(review) for review in reviews]
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[45], line 7
#       4 import matplotlib.pyplot as plt
#       6 # 예시 리뷰 데이터
# ----> 7 reviews = random_sample['리뷰'].tolist() * 20000
#       9 # 불용어 리스트 정의
#      10 stopwords = ['a', 'an', 'the', 'and', 'or', 'but', 'if', 'then', 'when', 'at', 'by', 'for', 'with',
#      11              'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above',
#      12              'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again',
#    (...)
#      18              'recommend', 'would', 'definitely', 'check-in', 'check-out','was', 'we', 'it', 'of',
#      19              'you', 'london','had', 'flat','really', 'as', 'everything','this','our','easy','my','close','friendly','well','helpful']
#
# MemoryError:

# %%
# TF-IDF 벡터라이저 초기화 (불용어 포함)
vectorizer = TfidfVectorizer(stop_words=stopwords)

# 리뷰 데이터를 TF-IDF 매트릭스로 변환
tfidf_matrix = vectorizer.fit_transform(reviews)

# 단어 리스트 (피처 이름)
feature_names = vectorizer.get_feature_names_out()

# TF-IDF 매트릭스를 데이터프레임으로 변환
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=feature_names)

# TF-IDF 값을 합산하여 단어별로 점수 계산
tfidf_scores = tfidf_df.sum(axis=0)

# 상위 20개의 단어 추출
top_tfidf_words = tfidf_scores.sort_values(ascending=False).head(20)

print(top_tfidf_words)
# Out:
# c:\Users\Master\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_extraction\text.py:408: UserWarning:
#
# Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['check'] not in stop_words.
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[43], line 5
#       2 vectorizer = TfidfVectorizer(stop_words=stopwords)
#       4 # 리뷰 데이터를 TF-IDF 매트릭스로 변환
# ----> 5 tfidf_matrix = vectorizer.fit_transform(reviews)
#       7 # 단어 리스트 (피처 이름)
#       8 feature_names = vectorizer.get_feature_names_out()
#
# File c:\Users\Master\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_extraction\text.py:2093, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2086 self._check_params()
#    2087 self._tfidf = TfidfTransformer(
#    2088     norm=self.norm,
#    2089     use_idf=self.use_idf,
#    2090     smooth_idf=self.smooth_idf,
#    2091     sublinear_tf=self.sublinear_tf,
#    2092 )
# -> 2093 X = super().fit_transform(raw_documents)
#    2094 self._tfidf.fit(X)
#    2095 # X is already a transformed view of raw_documents so
#    2096 # we set copy to False
#
# File c:\Users\Master\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Master\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_extraction\text.py:1374, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1366             warnings.warn(
#    1367                 "Upper case characters found in"
#    1368                 " vocabulary while 'lowercase'"
#    1369                 " is True. These entries will not"
#    1370                 " be matched with any documents"
#    1371             )
#    1372             break
# -> 1374 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1376 if self.binary:
#    1377     X.data.fill(1)
#
# File c:\Users\Master\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_extraction\text.py:1272, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1268     except KeyError:
#    1269         # Ignore out-of-vocabulary items for fixed_vocab=True
#    1270         continue
# -> 1272 j_indices.extend(feature_counter.keys())
#    1273 values.extend(feature_counter.values())
#    1274 indptr.append(len(j_indices))
#
# MemoryError:

# %%
# from textblob import TextBlob

# def translate_to_english(text):
#     # TextBlob 객체 생성
#     blob = TextBlob(text)

#     # 언어 감지
#     detected_language = blob.detect_language()

#     # 감지된 언어가 영어인 경우 원본 텍스트 반환
#     if detected_language == 'en':
#         return text

#     # 번역
#     translated_blob = blob.translate(to='en')

#     return translated_blob.raw

# # 테스트를 위한 예시 텍스트
# example_text = "안녕하세요, 반갑습니다."

# # 언어 감지 및 번역
# translated_text = translate_to_english(example_text)

# print("원본 텍스트:", example_text)
# print("번역된 텍스트:", translated_text)

# %%
# !pip install openai pandas tqdm
# !pip install openai==0.28

# %% [markdown]
# openai 코드

# %%
# import openai
# import pandas as pd
# from tqdm import tqdm

# openai.api_key = 'api key 입력'

# %%
# def translate_text(text):
#     response = openai.ChatCompletion.create(
#          model = 'gpt-3.5-turbo',
#          messages = [
#              {'role' : 'user', 'content' : f"이 리뷰를 영어로 번역해줘 : \n\n{text}"},

#             ],
#         max_tokens=100,
#         n=1,
#         stop=None,
#         temperature=0.5
#     )
#     translated_text = response.choices[0].message['content']
#     return translated_text

# #진행사항 표시
# tqdm.pandas()

# matching_rows['리뷰_영어'] = matching_rows['리뷰'].progress_apply(translate_text)

# %%
# !pip install googletrans==4.0.0-rc1
# !pip install langdetect googletrans==4.0.0-rc1

# %% [markdown]
# 구글 번역 api 제한 1일 16000자 까지 가능

# %%
# from langdetect import detect
# from googletrans import Translator


# def translate_to_english(text):
#     # Google Translate 객체 생성
#     translator = Translator()

#     # 번역된 텍스트를 저장할 리스트
#     translated_texts = []

#     for t in text:
#         # 텍스트의 언어 감지
#         detected_language = detect(t)

#         # 감지된 언어가 영어인 경우 원본 텍스트를 저장
#         if detected_language == 'en':
#             translated_texts.append(t)
#         else:
#             # 번역
#             translation = translator.translate(t, src=detected_language, dest='en')
#             translated_texts.append(translation.text)

#     return translated_texts

# # 텍스트를 영어로 번역하여 '리뷰_영어' 열에 저장
# english_reviews = translate_to_english(matching_rows['리뷰'][:10])

# %% [markdown]
# 파파고 api 제한 1일 최대 5000자

# %%
# import requests

# def detect_language(text, client_id, client_secret):
#     # 파파고 API 호출을 위한 URL 및 요청 데이터 설정
#     url = ''
#     headers = {
#         'X-Naver-Client-Id': client_id,
#         'X-Naver-Client-Secret': client_secret
#     }
#     data = {'query': text}

#     # 파파고 API 호출
#     response = requests.post(url, headers=headers, data=data)

#     # 응답 확인 및 언어 감지 결과 반환
#     if response.status_code == 200:
#         detected_language = response.json()['langCode']
#         return detected_language
#     else:
#         print(f"언어 감지 중 오류 발생: {response.status_code}")
#         return None

# def translate_to_english(text, client_id, client_secret):
#     # 언어 감지
#     detected_language = detect_language(text, client_id, client_secret)

#     # 감지된 언어가 이미 영어인 경우 원본 텍스트 반환
#     if detected_language == 'en':
#         return text

#     # 파파고 API 호출을 위한 URL 및 요청 데이터 설정
#     url = ''
#     headers = {
#         'X-Naver-Client-Id': client_id,
#         'X-Naver-Client-Secret': client_secret
#     }
#     data = {
#         'source': detected_language,
#         'target': 'en',
#         'text': text
#     }

#     # 파파고 API 호출
#     response = requests.post(url, headers=headers, data=data)

#     # 응답 확인 및 번역 결과 반환
#     if response.status_code == 200:
#         translated_text = response.json()['message']['result']['translatedText']
#         return translated_text
#     else:
#         print(f"번역 중 오류 발생: {response.status_code}")
#         return None

# # 네이버 개발자 센터에서 발급받은 클라이언트 ID와 클라이언트 시크릿
# client_id = 'your_client_id'
# client_secret = 'your_client_secret'

# # 테스트를 위한 예시 텍스트
# example_text = "안녕하세요, 반갑습니다."

# # 언어 감지 및 번역
# translated_text = translate_to_english(example_text, client_id, client_secret)

# print("원본 텍스트:", example_text)
# print("번역된 텍스트:", translated_text)
