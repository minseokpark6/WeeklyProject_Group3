# %% [markdown]
# 리뷰데이터 가져오기 / 전처리

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 기본 패키지 불러오기

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import matplotlib as mpl
from matplotlib import font_manager, rc

# 그래프를 노트북 안에 그리기 위해 설정
# %matplotlib inline

# 글꼴 경로 지정
font_path = '/content/drive/MyDrive/예진/malgun.ttf'

# 폰트 이름 얻어오기
font_name = font_manager.FontProperties(fname=font_path).get_name()

# matplotlib의 rc(run command) 기능을 이용하여 글꼴 설정
mpl.rc('font', family=font_name)

# 유니코드에서  음수 부호 설정
mpl.rc('axes', unicode_minus=False)

# 데이터 불러오기

path = '/content/drive/MyDrive/Data/Airbnb_London/combined_reviews.csv'


df_review = pd.read_csv(path, encoding='utf-8')

df_review.dropna(subset=['리뷰'],inplace=True)

#date >> 데이터타입 변경 datatime

df_review['리뷰날짜'] = pd.to_datetime(df_review['리뷰날짜'])

# %%
df_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 671964 entries, 0 to 671965
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   숙소_id   671964 non-null  int64
#  1   리뷰날짜    671964 non-null  datetime64[ns]
#  2   리뷰      671964 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 20.5+ MB

# %%
df_review.head()
# Out:
#    숙소_id       리뷰날짜                                                 리뷰
# 0  13913 2010-08-18  My girlfriend and I hadn't known Alina before ...
# 1  13913 2011-07-11  Alina was a really good host. The flat is clea...
# 2  13913 2011-09-13  Alina is an amazing host. She made me feel rig...
# 3  13913 2011-10-03  Alina's place is so nice, the room is big and ...
# 4  13913 2011-10-09  Nice location in Islington area, good for shor...

# %% [markdown]
# 랜덤 20000만개 데이터 추출

# %%
import pandas as pd

# 리뷰 데이터가 담긴 DataFrame (예: df)
# 예시로 df를 생성합니다. 실제 데이터 프레임을 사용하세요.
# df = pd.read_csv('path_to_your_file.csv')

# 10,000개의 랜덤 샘플 추출
random_sample = df_review.sample(n=20000, random_state=42)

# 결과를 확인합니다.
print(random_sample)
# Out:
#            숙소_id       리뷰날짜                                                 리뷰
# 475762  28599087 2022-03-20  We had a great trip, the airbnb is great and v...
# 266231  14378646 2022-11-18      Great Area, great hosts and a very comfy bed.
# 555       165336 2022-08-25  Had a wonderful stay at Nathan’s. Loved the ec...
# 495255  30536724 2023-12-02  Clean,Comfy and a Peaceful space..There are 5 ...
# 409887  22592225 2019-11-15  Yvonne’s place was lovely and comfortable. She...
# ...          ...        ...                                                ...
# 73289    1739911 2015-06-02  This is the perfect place to stay for Brick La...
# 622110  15996748 2018-02-18  A private room in a shared apartment. It is ne...
# 316021  17231704 2018-07-18  Very small room and not enough room for a chai...
# 20097     390750 2017-06-16  Great location and easy access to transportati...
# 420177  23638870 2021-01-11  This space has wonderful views  along with a g...
#
# [20000 rows x 3 columns]

# %%
# random_sample.to_csv('/content/drive/MyDrive/Data/Airbnb_London/random_reivew_20000.csv', encoding='utf-8', index=False)

# %%
# !pip install nltk
# !pip install wordcloud

# %%
# !pip install textblob

import nltk
nltk.download('brown')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('conll2000')
nltk.download('movie_reviews')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %% [markdown]
# 텍스트 전처리
#
#
# - 소문자로 변경
# - 토큰화
# - 불용어 제거
# - 어간 추출

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import glob
import re  #정규표현식

from functools import reduce #2차원 >> 1차원

from nltk.tokenize import word_tokenize # word >> token
from nltk.corpus import stopwords  #stopwords >> 불용어
from nltk.stem import WordNetLemmatizer # 어간 분석

from collections import Counter

from wordcloud import STOPWORDS, WordCloud

stopWords = set(stopwords.words('english'))
lemma = WordNetLemmatizer()

words = []
def Pretreatment(text):

    for title in random_sample['리뷰']:
        en_words = re.sub(r"[^a-zA-Z]+"," ",str(title)) #정규표현식 사용, 영문 대소문자 ^ 제외한 문자를 공백 (" ")변경
        en_words_token = word_tokenize(en_words.lower()) # 변환 된 단어를 토큰화
        en_words_stop = [word for word in en_words_token if not word in stopWords] # 불용어 제거
        en_words_lemma = [lemma.lemmatize(word) for word in en_words_stop]  #어간 추출
        words.append(en_words_lemma)

# #진행사항 표시
tqdm.pandas()


Pretreatment(random_sample['리뷰'])

# %%
word_list = list(reduce(lambda x, y: x + y, words))

# %%
word_list
# Out:
# ['great',
#  'trip',
#  'airbnb',
#  'great',
#  'well',
#  'located',
#  'great',
#  'area',
#  'great',
#  'host',
#  'comfy',
#  'bed',
#  'wonderful',
#  'stay',
#  'nathan',
#  'loved',
#  'eclectic',
#  'decor',
#  'prime',
#  'location',
#  'notting',
#  'hill',
#  'step',
#  'tube',
#  'communication',
#  'great',
#  'able',
#  'personally',
#  'check',
#  'walk',
#  'everything',
#  'house',
#  'plus',
#  'left',
#  'detailed',
#  'instruction',
#  'everything',
#  'worked',
#  'great',
#  'lovely',
#  'comfortable',
#  'base',
#  'time',
#  'london',
#  'would',
#  'definitely',
#  'stay',
#  'clean',
#  'comfy',
#  'peaceful',
#  'space',
#  'room',
#  'house',
#  'everything',
#  'peaceful',
#  'felt',
#  'like',
#  'one',
#  'shower',
#  'bathroom',
#  'hardly',
#  'luck',
#  'need',
#  'kitchen',
#  'clean',
#  'cupboard',
#  'refrigerator',
#  'shelf',
#  'partitioned',
#  'labelled',
#  'room',
#  'storage',
#  'standard',
#  'shared',
#  'accommodation',
#  'aspire',
#  'thanks',
#  'ben',
#  'yvonne',
#  'place',
#  'lovely',
#  'comfortable',
#  'great',
#  'host',
#  'location',
#  'perfect',
#  'seeing',
#  'gig',
#  'alexandra',
#  'palace',
#  'lovely',
#  'flat',
#  'close',
#  'several',
#  'tube',
#  'station',
#  'restaurant',
#  'fantastic',
#  'host',
#  'communicative',
#  'code',
#  'enabled',
#  'door',
#  'tricky',
#  'manage',
#  'room',
#  'close',
#  'station',
#  'convenient',
#  'everything',
#  'advertised',
#  'worked',
#  'perfectly',
#  'london',
#  'plan',
#  'emphasized',
#  'enough',
#  'central',
#  'great',
#  'location',
#  'james',
#  'also',
#  'great',
#  'work',
#  'check',
#  'viktor',
#  'amazing',
#  'flat',
#  'well',
#  'located',
#  'comfy',
#  'clean',
#  'friend',
#  'enjoyed',
#  'well',
#  'vacation',
#  'could',
#  'barely',
#  'notice',
#  'host',
#  'soon',
#  'needed',
#  'responding',
#  'quickly',
#  'phone',
#  'totally',
#  'recommend',
#  'place',
#  'want',
#  'travel',
#  'london',
#  'back',
#  'sure',
#  'zhuoli',
#  'wonderful',
#  'host',
#  'arrived',
#  'london',
#  'different',
#  'airbnb',
#  'ran',
#  'many',
#  'trouble',
#  'thankfully',
#  'airbnb',
#  'super',
#  'helpful',
#  'helping',
#  'u',
#  'relocate',
#  'zhuoli',
#  'also',
#  'amazing',
#  'last',
#  'minute',
#  'change',
#  'took',
#  'u',
#  'hr',
#  'time',
#  'made',
#  'change',
#  'time',
#  'able',
#  'enter',
#  'new',
#  'apt',
#  'zhuoli',
#  'apt',
#  'certainly',
#  'meet',
#  'criterion',
#  'super',
#  'host',
#  'comment',
#  'change',
#  'five',
#  'star',
#  'rating',
#  'include',
#  'mindful',
#  'area',
#  'apartment',
#  'amazing',
#  'come',
#  'loud',
#  'noise',
#  'people',
#  'outside',
#  'especially',
#  'later',
#  'week',
#  'weekend',
#  'three',
#  'bar',
#  'near',
#  'second',
#  'really',
#  'difficulty',
#  'figuring',
#  'heat',
#  'wish',
#  'bit',
#  'easier',
#  'navigate',
#  'otherwise',
#  'bed',
#  'great',
#  'heated',
#  'bathroom',
#  'floor',
#  'wonderful',
#  'addition',
#  'ease',
#  'check',
#  'check',
#  'great',
#  'mo',
#  'paul',
#  'superb',
#  'host',
#  'always',
#  'ready',
#  'help',
#  'willing',
#  'provide',
#  'best',
#  'service',
#  'possible',
#  'great',
#  'stay',
#  'beautiful',
#  'flat',
#  'amazing',
#  'location',
#  'clean',
#  'interior',
#  'great',
#  'communication',
#  'recommend',
#  'anyone',
#  'wish',
#  'staying',
#  'london',
#  'weekend',
#  'holiday',
#  'clean',
#  'comfy',
#  'bedroom',
#  'bathroom',
#  'david',
#  'partner',
#  'welcoming',
#  'helpful',
#  'friendly',
#  'dog',
#  'need',
#  'get',
#  'around',
#  'vauxhall',
#  'stockwell',
#  'tube',
#  'station',
#  'easily',
#  'reached',
#  'great',
#  'place',
#  'area',
#  'nice',
#  'flat',
#  'clean',
#  'cosy',
#  'confortable',
#  'bathroom',
#  'cool',
#  'building',
#  'really',
#  'nice',
#  'commun',
#  'part',
#  'quite',
#  'dirty',
#  'liked',
#  'stay',
#  'real',
#  'airbnb',
#  'exp',
#  'rience',
#  'never',
#  'met',
#  'owner',
#  'contact',
#  'agency',
#  'house',
#  'perfect',
#  'position',
#  'soho',
#  'well',
#  'decorated',
#  'service',
#  'provided',
#  'host',
#  'perfect',
#  'price',
#  'quality',
#  'ratio',
#  'convenient',
#  'partner',
#  'spent',
#  'three',
#  'night',
#  'staying',
#  'may',
#  'place',
#  'week',
#  'whilst',
#  'working',
#  'locally',
#  'overall',
#  'much',
#  'add',
#  'suggests',
#  'may',
#  'great',
#  'host',
#  'friendly',
#  'excellent',
#  'communication',
#  'room',
#  'good',
#  'value',
#  'money',
#  'unfortunately',
#  'realise',
#  'would',
#  'several',
#  'guest',
#  'staying',
#  'time',
#  'resulting',
#  'noise',
#  'late',
#  'night',
#  'also',
#  'queue',
#  'bathroom',
#  'although',
#  'issue',
#  'first',
#  'two',
#  'night',
#  'last',
#  'one',
#  'overall',
#  'would',
#  'recommend',
#  'looking',
#  'basic',
#  'accommodation',
#  'great',
#  'host',
#  'would',
#  'book',
#  'booked',
#  'simon',
#  'place',
#  'weekend',
#  'london',
#  'catch',
#  'concert',
#  'wembley',
#  'loved',
#  'found',
#  'perfect',
#  'wanted',
#  'even',
#  'bottle',
#  'something',
#  'fizzy',
#  'waiting',
#  'u',
#  'would',
#  'highly',
#  'recommend',
#  'stopping',
#  'garden',
#  'perfect',
#  'thanks',
#  'lovely',
#  'spacious',
#  'bright',
#  'flat',
#  'comfortable',
#  'really',
#  'well',
#  'located',
#  'amenity',
#  'would',
#  'need',
#  'short',
#  'longer',
#  'stay',
#  'stephanie',
#  'team',
#  'prompt',
#  'response',
#  'question',
#  'recommend',
#  'place',
#  'would',
#  'definitely',
#  'stay',
#  'collin',
#  'friendly',
#  'host',
#  'room',
#  'bathroom',
#  'super',
#  'clean',
#  'definitely',
#  'recommend',
#  'comfy',
#  'place',
#  'good',
#  'area',
#  'absolute',
#  'gem',
#  'stay',
#  'beautifully',
#  'decorated',
#  'comfortable',
#  'well',
#  'connected',
#  'stayed',
#  'two',
#  'month',
#  'felt',
#  'like',
#  'home',
#  'truly',
#  'sad',
#  'leave',
#  'mathilde',
#  'phenomenal',
#  'host',
#  'regularly',
#  'sent',
#  'u',
#  'event',
#  'saw',
#  'going',
#  'might',
#  'interested',
#  'recommend',
#  'thank',
#  'mike',
#  'maria',
#  'everything',
#  'everything',
#  'perfect',
#  'location',
#  'good',
#  'close',
#  'overground',
#  'safe',
#  'room',
#  'clean',
#  'bathtub',
#  'must',
#  'hesitate',
#  'outstanding',
#  'nice',
#  'flat',
#  'located',
#  'directly',
#  'train',
#  'station',
#  'area',
#  'shop',
#  'restaurant',
#  'nice',
#  'pub',
#  'way',
#  'cheaper',
#  'one',
#  'center',
#  'great',
#  'host',
#  'friendly',
#  'lovely',
#  'chat',
#  'arrived',
#  'room',
#  'large',
#  'spotlessly',
#  'clean',
#  'bed',
#  'super',
#  'comfortable',
#  'minute',
#  'walk',
#  'forest',
#  'gate',
#  'station',
#  'lovely',
#  'quiet',
#  'street',
#  'yet',
#  'close',
#  'lot',
#  'shop',
#  'highly',
#  'recommend',
#  'isabel',
#  'nice',
#  'warm',
#  'welcoming',
#  'h',
#  'te',
#  'sunny',
#  'house',
#  'nice',
#  'garden',
#  'accept',
#  'sleep',
#  'tiny',
#  'tiny',
#  'bedroom',
#  'small',
#  'bed',
#  'b',
#  'mol',
#  'otherwise',
#  'perfect',
#  'location',
#  'great',
#  'public',
#  'transportation',
#  'felt',
#  'secured',
#  'place',
#  'small',
#  'perfect',
#  'solo',
#  'traveller',
#  'bathroom',
#  'separate',
#  'room',
#  'hallway',
#  'great',
#  'short',
#  'stay',
#  'great',
#  'place',
#  'stay',
#  'great',
#  'host',
#  'recommend',
#  'great',
#  'host',
#  'great',
#  'calm',
#  'place',
#  'live',
#  'short',
#  'long',
#  'trip',
#  'nearly',
#  'hammersmith',
#  'commodity',
#  'inge',
#  'wonderful',
#  'host',
#  'great',
#  'location',
#  'convenient',
#  'highly',
#  'recommend',
#  'rick',
#  'nice',
#  'quick',
#  'response',
#  'thank',
#  'much',
#  'helping',
#  'lot',
#  'best',
#  'place',
#  'ever',
#  'stayed',
#  'london',
#  'thanks',
#  'anne',
#  'kindness',
#  'everything',
#  'perfect',
#  'perfect',
#  'stay',
#  'boris',
#  'wife',
#  'amazing',
#  'second',
#  'visit',
#  'sure',
#  'many',
#  'alison',
#  'david',
#  'welcoming',
#  'make',
#  'u',
#  'feel',
#  'home',
#  'thanks',
#  'week',
#  'long',
#  'stay',
#  'amazing',
#  'jenny',
#  'kenny',
#  'welcoming',
#  'informative',
#  'place',
#  'perfect',
#  'cozy',
#  'well',
#  'perfect',
#  'location',
#  'walking',
#  'food',
#  'store',
#  'perfect',
#  'job',
#  'making',
#  'feel',
#  'like',
#  'home',
#  'away',
#  'home',
#  'everything',
#  'friend',
#  'get',
#  'chance',
#  'meet',
#  'toby',
#  'anetta',
#  'person',
#  'housekeeper',
#  'darek',
#  'kind',
#  'enough',
#  'show',
#  'u',
#  'around',
#  'apartment',
#  'must',
#  'say',
#  'apartment',
#  'extremely',
#  'gorgeous',
#  'fitting',
#  'well',
#  'done',
#  'everything',
#  'look',
#  'new',
#  'house',
#  'neat',
#  'tidy',
#  'checked',
#  'extremely',
#  'important',
#  'noteworthy',
#  'finding',
#  'place',
#  'easy',
#  'truly',
#  'recommend',
#  'place',
#  'whether',
#  'weekend',
#  'getaway',
#  'short',
#  'trip',
#  'long',
#  'trip',
#  'worth',
#  'every',
#  'penny',
#  'thanks',
#  'toby',
#  'anetta',
#  'cheer',
#  'great',
#  'location',
#  'quick',
#  'access',
#  'hyde',
#  'park',
#  'underground',
#  'tube',
#  'station',
#  'relatively',
#  'quiet',
#  'clean',
#  'well',
#  'overall',
#  'nice',
#  'price',
#  'room',
#  'lovely',
#  'clean',
#  'farheen',
#  'family',
#  'nice',
#  'also',
#  'listing',
#  'say',
#  'premise',
#  'parking',
#  'street',
#  'parking',
#  'free',
#  'get',
#  'busy',
#  'aniqa',
#  'family',
#  'truly',
#  'welcoming',
#  'helpful',
#  'enjoyed',
#  'staying',
#  'would',
#  'recommend',
#  'wonderful',
#  'stay',
#  'chris',
#  'lucien',
#  'place',
#  'welcoming',
#  'helpful',
#  'room',
#  'nice',
#  'clean',
#  'recommended',
#  'mark',
#  'kind',
#  'proactive',
#  'trouble',
#  'lock',
#  'got',
#  'fixed',
#  'asap',
#  'dog',
#  'also',
#  'adorable',
#  'felt',
#  'safe',
#  'would',
#  'definitely',
#  'go',
#  'back',
#  'spotlessly',
#  'clean',
#  'appliance',
#  'new',
#  'perfect',
#  'working',
#  'order',
#  'carl',
#  'welcoming',
#  'helpful',
#  'great',
#  'time',
#  'staying',
#  'ben',
#  'place',
#  'communicating',
#  'ben',
#  'easy',
#  'room',
#  'small',
#  'perfect',
#  'weekend',
#  'trip',
#  'clean',
#  'well',
#  'equipped',
#  'simon',
#  'place',
#  'spotless',
#  'stylish',
#  'located',
#  'right',
#  'heart',
#  'west',
#  'hampstead',
#  'walking',
#  'property',
#  'first',
#  'time',
#  'wowed',
#  'far',
#  'nicer',
#  'hotel',
#  'could',
#  'find',
#  'london',
#  'simon',
#  'team',
#  'also',
#  'incredibly',
#  'accommodating',
#  'kind',
#  'quick',
#  'response',
#  'message',
#  'sent',
#  'truly',
#  'lovely',
#  'property',
#  'great',
#  'time',
#  'london',
#  'euans',
#  'place',
#  'one',
#  'reason',
#  'check',
#  'easy',
#  'euan',
#  'nice',
#  'likeable',
#  'guy',
#  'gave',
#  'great',
#  'suggestion',
#  'recomandations',
#  'regarding',
#  'neighborhood',
#  'getting',
#  'around',
#  'hackney',
#  'really',
#  'cool',
#  'plenty',
#  'bar',
#  'restaurant',
#  'around',
#  'corner',
#  'broadway',
#  'market',
#  'saturday',
#  'far',
#  'away',
#  'crowded',
#  'stressy',
#  'part',
#  'london',
#  'nice',
#  'mix',
#  'people',
#  'well',
#  'come',
#  'back',
#  'london',
#  'definitely',
#  'stay',
#  'euans',
#  'room',
#  'shown',
#  'big',
#  'nice',
#  'relaxed',
#  'vibe',
#  'private',
#  'bathroom',
#  'also',
#  'perfectly',
#  'fine',
#  'two',
#  'thumb',
#  'place',
#  'owner',
#  'location',
#  'neighborhood',
#  'provided',
#  'little',
#  'thing',
#  'like',
#  'tea',
#  'coffee',
#  'soup',
#  'etc',
#  'also',
#  'welcome',
#  'nice',
#  'gesture',
#  'ilja',
#  'nadine',
#  'tony',
#  'great',
#  'host',
#  'gave',
#  'u',
#  'recommendation',
#  'place',
#  'go',
#  'always',
#  'attentive',
#  'need',
#  'home',
#  'modern',
#  'clean',
#  'connected',
#  'point',
#  'city',
#  'centre',
#  'le',
#  'minute',
#  'would',
#  'definitely',
#  'recommend',
#  'option',
#  'stunning',
#  'space',
#  'loved',
#  'every',
#  'minute',
#  'highly',
#  'recommended',
#  'thank',
#  'jacqui',
#  'best',
#  'place',
#  'stay',
#  'london',
#  'already',
#  'excited',
#  'staying',
#  'fernando',
#  'flat',
#  'central',
#  'london',
#  'flat',
#  'look',
#  'amazing',
#  'beautiful',
#  'interior',
#  'design',
#  'central',
#  'minute',
#  'walking',
#  'victoria',
#  'underground',
#  'station',
#  'plenty',
#  'restaurant',
#  'bar',
#  'supermarket',
#  'around',
#  'great',
#  'take',
#  'gatwick',
#  'express',
#  'airport',
#  'able',
#  'walk',
#  'flat',
#  'bed',
#  'comfortable',
#  'place',
#  'quiet',
#  'great',
#  'sleep',
#  'flat',
#  'lot',
#  'daylight',
#  'small',
#  'luxury',
#  'nespresso',
#  ...]

# %%
# file_name = '../../../../data/Airbnb_London/20000_word_list.txt'

# with open(file_name, 'w+') as file :
#     file.write('\n'.join(word_list))

# %%
pd.Series(word_list).value_counts().head(20)
# Out:
# great          9696
# stay           9555
# place          7867
# location       6625
# host           6346
# london         6191
# clean          5767
# room           5523
# apartment      4612
# nice           4500
# good           4259
# would          4184
# comfortable    3840
# recommend      3810
# really         3532
# well           3483
# everything     3477
# lovely         3414
# flat           3390
# u              3381
# Name: count, dtype: int64

# %% [markdown]
# 불용어 추가 제거

# %%
def remove_stopword(word_list, stopwords):
    return [word for word in word_list if word not in stopwords]

word_list = word_list
stopwords = ['great', 'good', 'nice', 'would', 'place', 'stay','apartment','house','room','host','comfortable',
             'amazing','perfect','wonderful','excellent','lovely','highly','recommend','definitely', 'really',
             'london','u', 'everything', 'well', 'home','helpful','also','like','location','staying','could','need']
filtered_word_list = remove_stopword(word_list, stopwords)
filtered_word_list
# Out:
# ['trip',
#  'airbnb',
#  'located',
#  'area',
#  'comfy',
#  'bed',
#  'nathan',
#  'loved',
#  'eclectic',
#  'decor',
#  'prime',
#  'notting',
#  'hill',
#  'step',
#  'tube',
#  'communication',
#  'able',
#  'personally',
#  'check',
#  'walk',
#  'plus',
#  'left',
#  'detailed',
#  'instruction',
#  'worked',
#  'base',
#  'time',
#  'clean',
#  'comfy',
#  'peaceful',
#  'space',
#  'peaceful',
#  'felt',
#  'one',
#  'shower',
#  'bathroom',
#  'hardly',
#  'luck',
#  'kitchen',
#  'clean',
#  'cupboard',
#  'refrigerator',
#  'shelf',
#  'partitioned',
#  'labelled',
#  'storage',
#  'standard',
#  'shared',
#  'accommodation',
#  'aspire',
#  'thanks',
#  'ben',
#  'yvonne',
#  'seeing',
#  'gig',
#  'alexandra',
#  'palace',
#  'flat',
#  'close',
#  'several',
#  'tube',
#  'station',
#  'restaurant',
#  'fantastic',
#  'communicative',
#  'code',
#  'enabled',
#  'door',
#  'tricky',
#  'manage',
#  'close',
#  'station',
#  'convenient',
#  'advertised',
#  'worked',
#  'perfectly',
#  'plan',
#  'emphasized',
#  'enough',
#  'central',
#  'james',
#  'work',
#  'check',
#  'viktor',
#  'flat',
#  'located',
#  'comfy',
#  'clean',
#  'friend',
#  'enjoyed',
#  'vacation',
#  'barely',
#  'notice',
#  'soon',
#  'needed',
#  'responding',
#  'quickly',
#  'phone',
#  'totally',
#  'want',
#  'travel',
#  'back',
#  'sure',
#  'zhuoli',
#  'arrived',
#  'different',
#  'airbnb',
#  'ran',
#  'many',
#  'trouble',
#  'thankfully',
#  'airbnb',
#  'super',
#  'helping',
#  'relocate',
#  'zhuoli',
#  'last',
#  'minute',
#  'change',
#  'took',
#  'hr',
#  'time',
#  'made',
#  'change',
#  'time',
#  'able',
#  'enter',
#  'new',
#  'apt',
#  'zhuoli',
#  'apt',
#  'certainly',
#  'meet',
#  'criterion',
#  'super',
#  'comment',
#  'change',
#  'five',
#  'star',
#  'rating',
#  'include',
#  'mindful',
#  'area',
#  'come',
#  'loud',
#  'noise',
#  'people',
#  'outside',
#  'especially',
#  'later',
#  'week',
#  'weekend',
#  'three',
#  'bar',
#  'near',
#  'second',
#  'difficulty',
#  'figuring',
#  'heat',
#  'wish',
#  'bit',
#  'easier',
#  'navigate',
#  'otherwise',
#  'bed',
#  'heated',
#  'bathroom',
#  'floor',
#  'addition',
#  'ease',
#  'check',
#  'check',
#  'mo',
#  'paul',
#  'superb',
#  'always',
#  'ready',
#  'help',
#  'willing',
#  'provide',
#  'best',
#  'service',
#  'possible',
#  'beautiful',
#  'flat',
#  'clean',
#  'interior',
#  'communication',
#  'anyone',
#  'wish',
#  'weekend',
#  'holiday',
#  'clean',
#  'comfy',
#  'bedroom',
#  'bathroom',
#  'david',
#  'partner',
#  'welcoming',
#  'friendly',
#  'dog',
#  'get',
#  'around',
#  'vauxhall',
#  'stockwell',
#  'tube',
#  'station',
#  'easily',
#  'reached',
#  'area',
#  'flat',
#  'clean',
#  'cosy',
#  'confortable',
#  'bathroom',
#  'cool',
#  'building',
#  'commun',
#  'part',
#  'quite',
#  'dirty',
#  'liked',
#  'real',
#  'airbnb',
#  'exp',
#  'rience',
#  'never',
#  'met',
#  'owner',
#  'contact',
#  'agency',
#  'position',
#  'soho',
#  'decorated',
#  'service',
#  'provided',
#  'price',
#  'quality',
#  'ratio',
#  'convenient',
#  'partner',
#  'spent',
#  'three',
#  'night',
#  'may',
#  'week',
#  'whilst',
#  'working',
#  'locally',
#  'overall',
#  'much',
#  'add',
#  'suggests',
#  'may',
#  'friendly',
#  'communication',
#  'value',
#  'money',
#  'unfortunately',
#  'realise',
#  'several',
#  'guest',
#  'time',
#  'resulting',
#  'noise',
#  'late',
#  'night',
#  'queue',
#  'bathroom',
#  'although',
#  'issue',
#  'first',
#  'two',
#  'night',
#  'last',
#  'one',
#  'overall',
#  'looking',
#  'basic',
#  'accommodation',
#  'book',
#  'booked',
#  'simon',
#  'weekend',
#  'catch',
#  'concert',
#  'wembley',
#  'loved',
#  'found',
#  'wanted',
#  'even',
#  'bottle',
#  'something',
#  'fizzy',
#  'waiting',
#  'stopping',
#  'garden',
#  'thanks',
#  'spacious',
#  'bright',
#  'flat',
#  'located',
#  'amenity',
#  'short',
#  'longer',
#  'stephanie',
#  'team',
#  'prompt',
#  'response',
#  'question',
#  'collin',
#  'friendly',
#  'bathroom',
#  'super',
#  'clean',
#  'comfy',
#  'area',
#  'absolute',
#  'gem',
#  'beautifully',
#  'decorated',
#  'connected',
#  'stayed',
#  'two',
#  'month',
#  'felt',
#  'truly',
#  'sad',
#  'leave',
#  'mathilde',
#  'phenomenal',
#  'regularly',
#  'sent',
#  'event',
#  'saw',
#  'going',
#  'might',
#  'interested',
#  'thank',
#  'mike',
#  'maria',
#  'close',
#  'overground',
#  'safe',
#  'clean',
#  'bathtub',
#  'must',
#  'hesitate',
#  'outstanding',
#  'flat',
#  'located',
#  'directly',
#  'train',
#  'station',
#  'area',
#  'shop',
#  'restaurant',
#  'pub',
#  'way',
#  'cheaper',
#  'one',
#  'center',
#  'friendly',
#  'chat',
#  'arrived',
#  'large',
#  'spotlessly',
#  'clean',
#  'bed',
#  'super',
#  'minute',
#  'walk',
#  'forest',
#  'gate',
#  'station',
#  'quiet',
#  'street',
#  'yet',
#  'close',
#  'lot',
#  'shop',
#  'isabel',
#  'warm',
#  'welcoming',
#  'h',
#  'te',
#  'sunny',
#  'garden',
#  'accept',
#  'sleep',
#  'tiny',
#  'tiny',
#  'bedroom',
#  'small',
#  'bed',
#  'b',
#  'mol',
#  'otherwise',
#  'public',
#  'transportation',
#  'felt',
#  'secured',
#  'small',
#  'solo',
#  'traveller',
#  'bathroom',
#  'separate',
#  'hallway',
#  'short',
#  'calm',
#  'live',
#  'short',
#  'long',
#  'trip',
#  'nearly',
#  'hammersmith',
#  'commodity',
#  'inge',
#  'convenient',
#  'rick',
#  'quick',
#  'response',
#  'thank',
#  'much',
#  'helping',
#  'lot',
#  'best',
#  'ever',
#  'stayed',
#  'thanks',
#  'anne',
#  'kindness',
#  'boris',
#  'wife',
#  'second',
#  'visit',
#  'sure',
#  'many',
#  'alison',
#  'david',
#  'welcoming',
#  'make',
#  'feel',
#  'thanks',
#  'week',
#  'long',
#  'jenny',
#  'kenny',
#  'welcoming',
#  'informative',
#  'cozy',
#  'walking',
#  'food',
#  'store',
#  'job',
#  'making',
#  'feel',
#  'away',
#  'friend',
#  'get',
#  'chance',
#  'meet',
#  'toby',
#  'anetta',
#  'person',
#  'housekeeper',
#  'darek',
#  'kind',
#  'enough',
#  'show',
#  'around',
#  'must',
#  'say',
#  'extremely',
#  'gorgeous',
#  'fitting',
#  'done',
#  'look',
#  'new',
#  'neat',
#  'tidy',
#  'checked',
#  'extremely',
#  'important',
#  'noteworthy',
#  'finding',
#  'easy',
#  'truly',
#  'whether',
#  'weekend',
#  'getaway',
#  'short',
#  'trip',
#  'long',
#  'trip',
#  'worth',
#  'every',
#  'penny',
#  'thanks',
#  'toby',
#  'anetta',
#  'cheer',
#  'quick',
#  'access',
#  'hyde',
#  'park',
#  'underground',
#  'tube',
#  'station',
#  'relatively',
#  'quiet',
#  'clean',
#  'overall',
#  'price',
#  'clean',
#  'farheen',
#  'family',
#  'listing',
#  'say',
#  'premise',
#  'parking',
#  'street',
#  'parking',
#  'free',
#  'get',
#  'busy',
#  'aniqa',
#  'family',
#  'truly',
#  'welcoming',
#  'enjoyed',
#  'chris',
#  'lucien',
#  'welcoming',
#  'clean',
#  'recommended',
#  'mark',
#  'kind',
#  'proactive',
#  'trouble',
#  'lock',
#  'got',
#  'fixed',
#  'asap',
#  'dog',
#  'adorable',
#  'felt',
#  'safe',
#  'go',
#  'back',
#  'spotlessly',
#  'clean',
#  'appliance',
#  'new',
#  'working',
#  'order',
#  'carl',
#  'welcoming',
#  'time',
#  'ben',
#  'communicating',
#  'ben',
#  'easy',
#  'small',
#  'weekend',
#  'trip',
#  'clean',
#  'equipped',
#  'simon',
#  'spotless',
#  'stylish',
#  'located',
#  'right',
#  'heart',
#  'west',
#  'hampstead',
#  'walking',
#  'property',
#  'first',
#  'time',
#  'wowed',
#  'far',
#  'nicer',
#  'hotel',
#  'find',
#  'simon',
#  'team',
#  'incredibly',
#  'accommodating',
#  'kind',
#  'quick',
#  'response',
#  'message',
#  'sent',
#  'truly',
#  'property',
#  'time',
#  'euans',
#  'one',
#  'reason',
#  'check',
#  'easy',
#  'euan',
#  'likeable',
#  'guy',
#  'gave',
#  'suggestion',
#  'recomandations',
#  'regarding',
#  'neighborhood',
#  'getting',
#  'around',
#  'hackney',
#  'cool',
#  'plenty',
#  'bar',
#  'restaurant',
#  'around',
#  'corner',
#  'broadway',
#  'market',
#  'saturday',
#  'far',
#  'away',
#  'crowded',
#  'stressy',
#  'part',
#  'mix',
#  'people',
#  'come',
#  'back',
#  'euans',
#  'shown',
#  'big',
#  'relaxed',
#  'vibe',
#  'private',
#  'bathroom',
#  'perfectly',
#  'fine',
#  'two',
#  'thumb',
#  'owner',
#  'neighborhood',
#  'provided',
#  'little',
#  'thing',
#  'tea',
#  'coffee',
#  'soup',
#  'etc',
#  'welcome',
#  'gesture',
#  'ilja',
#  'nadine',
#  'tony',
#  'gave',
#  'recommendation',
#  'go',
#  'always',
#  'attentive',
#  'modern',
#  'clean',
#  'connected',
#  'point',
#  'city',
#  'centre',
#  'le',
#  'minute',
#  'option',
#  'stunning',
#  'space',
#  'loved',
#  'every',
#  'minute',
#  'recommended',
#  'thank',
#  'jacqui',
#  'best',
#  'already',
#  'excited',
#  'fernando',
#  'flat',
#  'central',
#  'flat',
#  'look',
#  'beautiful',
#  'interior',
#  'design',
#  'central',
#  'minute',
#  'walking',
#  'victoria',
#  'underground',
#  'station',
#  'plenty',
#  'restaurant',
#  'bar',
#  'supermarket',
#  'around',
#  'take',
#  'gatwick',
#  'express',
#  'airport',
#  'able',
#  'walk',
#  'flat',
#  'bed',
#  'quiet',
#  'sleep',
#  'flat',
#  'lot',
#  'daylight',
#  'small',
#  'luxury',
#  'nespresso',
#  'coffee',
#  'machine',
#  'favourite',
#  'beautiful',
#  'bath',
#  'internet',
#  'connection',
#  'fast',
#  'lot',
#  'work',
#  'done',
#  'day',
#  'happier',
#  'choice',
#  'fernando',
#  'took',
#  'time',
#  'tell',
#  'facility',
#  'gave',
#  'tip',
#  'restaurant',
#  'life',
#  'thanks',
#  'fernando',
#  'correspond',
#  'image',
#  'floor',
#  'fairly',
#  'steep',
#  'staircase',
#  'cleanliness',
#  'calm',
#  'neighborhood',
#  'solved',
#  'problem',
#  'doubt',
#  'clean',
#  'quite',
#  'neighborhood',
#  'dariusz',
#  'super',
#  'flat',
#  'close',
#  'portobello',
#  'road',
#  'despite',
#  'central',
#  'peaceful',
#  'quiet',
#  'ta',
#  'gave',
#  'quick',
#  'communication',
#  'described',
#  'enjoyed',
#  'daniela',
#  'sorting',
#  'direction',
#  'transport',
#  'despite',
#  'fact',
#  'took',
#  'wrong',
#  'train',
#  'line',
#  'daniela',
#  'offered',
#  'drive',
#  'train',
#  'station',
#  'supermarket',
#  'fantastic',
#  'needed',
#  'access',
#  'garden',
#  'space',
#  'stunning',
#  'local',
#  'park',
#  'beautiful',
#  'family',
#  'daniela',
#  'little',
#  'touristy',
#  'path',
#  'looking',
#  'local',
#  'feel',
#  'convenient',
#  'getting',
#  'around',
#  'enjoyed',
#  'masha',
#  'warm',
#  'friendly',
#  'time',
#  'respected',
#  'privacy',
#  'bed',
#  'settee',
#  'flat',
#  'quiet',
#  'experienced',
#  'noise',
#  'neighbour',
#  'took',
#  'ten',
#  'minute',
#  'walk',
#  'blackheath',
#  'selection',
#  'independent',
#  'shop',
#  'eat',
#  'happily',
#  'stephen',
#  'exactly',
#  'described',
#  'photo',
#  'accurate',
#  'clean',
#  'situated',
#  'cooked',
#  'one',
#  'dinner',
#  'breakfast',
#  'found',
#  'needed',
#  'term',
#  'dish',
#  'utensil',
#  'bed',
#  'sofa',
#  'living',
#  'flop',
#  'long',
#  'day',
#  'seeing',
#  'sight',
#  'take',
#  'long',
#  'get',
#  'handle',
#  'walked',
#  'almost',
#  'every',
#  'day',
#  'bricklane',
#  'spitafields',
#  'market',
#  'area',
#  'lot',
#  'around',
#  'area',
#  'nicely',
#  'tucked',
#  'quiet',
#  'street',
#  'sleep',
#  'certainly',
#  'travel',
#  'back',
#  'delightful',
#  'flat',
#  'bustling',
#  'lewisham',
#  'set',
#  'high',
#  'street',
#  'quiet',
#  'leafy',
#  'park',
#  'antoine',
#  'super',
#  'organised',
#  'communicative',
#  'made',
#  'effortless',
#  'happy',
#  'provide',
#  'local',
#  'info',
#  'got',
#  'marathon',
#  'start',
#  'bang',
#  'time',
#  'got',
#  'bad',
#  'thing',
#  'say',
#  'want',
#  'fully',
#  'renovated',
#  'big',
#  'comfy',
#  'bed',
#  'shower',
#  'bathroom',
#  'busy',
#  'day',
#  'go',
#  'back',
#  'quiet',
#  'space',
#  'plenty',
#  'family',
#  'four',
#  'little',
#  'way',
#  'easily',
#  'figured',
#  'tube',
#  'fulham',
#  'broadway',
#  'short',
#  'walk',
#  'bus',
#  'right',
#  'corner',
#  'go',
#  'victoria',
#  'station',
#  'flat',
#  'short',
#  'walk',
#  'tube',
#  'convenient',
#  'restaurant',
#  'grocery',
#  'store',
#  'julia',
#  'kind',
#  'spacious',
#  'super',
#  'bed',
#  'sufficient',
#  'storage',
#  'space',
#  'whole',
#  'clean',
#  'quiet',
#  'overally',
#  'cozy',
#  'plus',
#  'shepherd',
#  'bush',
#  'market',
#  'station',
#  'around',
#  'corner',
#  'recommended',
#  'fantastic',
#  'quiet',
#  'residence',
#  'close',
#  'underground',
#  'station',
#  'sharon',
#  'byron',
#  'friendly',
#  'flat',
#  'appartment',
#  'gorgeous',
#  'light',
#  'spacious',
#  'equipped',
#  'byron',
#  'best',
#  'living',
#  'second',
#  'floor',
#  'made',
#  'feel',
#  'welcome',
#  'first',
#  'minute',
#  'arrived',
#  'check',
#  'able',
#  'leave',
#  'luggage',
#  'collection',
#  ...]

# %%
pd.Series(filtered_word_list).value_counts().head(20)
# Out:
# clean         5767
# flat          3390
# station       2964
# easy          2856
# close         2843
# time          2510
# walk          2378
# area          2355
# friendly      2337
# quiet         2322
# minute        2100
# bed           2087
# tube          2009
# bus           1804
# bathroom      1763
# located       1747
# get           1737
# check         1646
# restaurant    1642
# day           1608
# Name: count, dtype: int64

# %% [markdown]
# 불용어를 더 제거할 필요가 있어보임

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

word_counts = pd.Series(filtered_word_list).value_counts().head(100)

# 워드클라우드를 생성
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_counts)

# 워드클라우드 시각화
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (4.66.4)

# %%
reviews = random_sample['리뷰']

# %%
from textblob import TextBlob
import re
from collections import Counter

# 예시 텍스트 리스트
texts = reviews

# 긍정 및 부정 단어 저장을 위한 Counter 초기화
positive_words = Counter()
negative_words = Counter()

# 전체 단어 수를 저장할 변수 초기화
total_word_count = 0

# 각 텍스트에 대해 감성 분석 수행 및 결과 출력
for i, text in enumerate(texts):
    # 텍스트 전처리 (소문자 변환, 특수 문자 제거)
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text)

    # TextBlob을 사용하여 감성 분석 수행
    blob = TextBlob(text)
    sentiment = blob.sentiment

    # 단어를 분할하여 긍정 및 부정 단어로 분류
    words = text.split()
    total_word_count += len(words)  # 현재 텍스트의 단어 수를 전체 단어 수에 더함
    for word in words:
        word_blob = TextBlob(word)
        if word_blob.sentiment.polarity > 0:
            positive_words[word] += 1
        elif word_blob.sentiment.polarity < 0:
            negative_words[word] += 1

# 긍정 단어의 총 수 계산
total_positive_words = sum(positive_words.values())

# 긍정 및 부정 단어 빈도수 출력
print("Positive words frequency:", positive_words)
print("Negative words frequency:", negative_words)
print("Total word count:", total_word_count)
print("Total positive words count:", total_positive_words)
# Out:
# Positive words frequency: Counter({'very': 15980, 'great': 9662, 'clean': 5726, 'nice': 4487, 'good': 4217, 'comfortable': 3815, 'really': 3527, 'lovely': 3405, 'perfect': 2834, 'easy': 2821, 'friendly': 2314, 'highly': 1809, 'excellent': 1513, 'beautiful': 1502, 'super': 1495, 'wonderful': 1395, 'amazing': 1292, 'thanks': 1178, 'much': 1174, 'enjoyed': 1158, 'kind': 1120, 'more': 1055, 'warm': 952, 'fantastic': 940, 'right': 923, 'loved': 866, 'many': 859, 'best': 789, 'near': 782, 'welcome': 775, 'quick': 712, 'pleasant': 697, 'first': 682, 'safe': 668, 'absolutely': 611, 'exactly': 599, 'most': 562, 'better': 561, 'available': 546, 'sure': 522, 'tidy': 510, 'able': 478, 'quickly': 453, 'large': 443, 'far': 441, 'modern': 439, 'love': 426, 'happy': 402, 'easily': 391, 'ideal': 379, 'perfectly': 368, 'light': 358, 'peaceful': 354, 'appreciated': 344, 'own': 333, 'early': 331, 'stylish': 329, 'pretty': 327, 'full': 323, 'clear': 314, 'attentive': 313, 'cute': 313, 'high': 298, 'bright': 292, 'new': 290, 'hot': 290, 'top': 287, 'old': 269, 'enjoy': 263, 'main': 263, 'charming': 255, 'thoughtful': 254, 'fast': 247, 'incredibly': 246, 'fine': 246, 'whole': 236, 'cool': 226, 'busy': 222, 'awesome': 221, 'brilliant': 219, 'accessible': 219, 'fabulous': 211, 'worth': 195, 'beautifully': 187, 'real': 183, 'certainly': 182, 'interesting': 181, 'live': 180, 'free': 179, 'ready': 178, 'fresh': 173, 'smooth': 170, 'nicely': 168, 'ok': 165, 'liked': 162, 'calm': 162, 'handy': 162, 'gorgeous': 161, 'huge': 155, 'useful': 152, 'sweet': 151, 'enjoyable': 148, 'superb': 144, 'delicious': 134, 'incredible': 133, 'fun': 131, 'completely': 125, 'accurate': 120, 'secure': 120, 'special': 118, 'happily': 117, 'ideally': 117, 'major': 113, 'loud': 112, 'important': 110, 'lively': 105, 'kindly': 102, 'offers': 95, 'detailed': 93, 'delightful': 92, 'willing': 91, 'unique': 91, 'strongly': 91, 'stunning': 89, 'straight': 88, 'adorable': 86, 'young': 83, 'outstanding': 82, 'particularly': 82, 'exceptional': 81, 'impeccable': 80, 'cheap': 79, 'directly': 78, 'decent': 77, 'aware': 77, 'suitable': 76, 'lucky': 75, 'fairly': 74, 'warmly': 74, 'satisfied': 74, 'reasonable': 73, 'complete': 69, 'general': 69, 'absolute': 68, 'smoothly': 67, 'true': 67, 'clearly': 66, 'okay': 66, 'soft': 65, 'positive': 65, 'respectful': 64, 'comfortably': 64, 'sound': 63, 'natural': 61, 'fit': 59, 'apt': 58, 'direct': 58, 'vibrant': 57, 'generally': 57, 'fixed': 55, 'filled': 55, 'wants': 55, 'professional': 53, 'wonderfully': 52, 'glad': 51, 'exceptionally': 48, 'surprised': 47, 'pleased': 47, 'adequate': 46, 'greatly': 46, 'newly': 43, 'favorite': 43, 'strong': 41, 'impressed': 40, 'amazingly': 39, 'experienced': 38, 'surprisingly': 37, 'memorable': 36, 'honestly': 36, 'older': 35, 'mostly': 34, 'magnificent': 34, 'gladly': 34, 'delighted': 33, 'precise': 33, 'trendy': 33, 'barely': 32, 'interested': 32, 'particular': 31, 'rich': 31, 'spectacular': 31, 'thoughtfully': 31, 'sensitive': 31, 'fair': 30, 'elegant': 30, 'surely': 30, 'rare': 29, 'importantly': 28, 'impeccably': 28, 'smart': 28, 'straightforward': 28, 'pleasantly': 28, 'popular': 28, 'smile': 27, 'wow': 27, 'gentle': 26, 'supportive': 26, 'enjoying': 25, 'joy': 25, 'authentic': 25, 'courteous': 25, 'famous': 25, 'seamless': 25, 'accurately': 25, 'genuinely': 24, 'consistent': 24, 'reasonably': 24, 'action': 23, 'frequent': 23, 'nearly': 22, 'normal': 22, 'original': 21, 'cheerful': 21, 'certain': 21, 'phenomenal': 20, 'luckily': 20, 'unusual': 20, 'genuine': 20, 'unexpected': 20, 'brilliantly': 19, 'impressive': 19, 'attractive': 18, 'frequently': 18, 'powerful': 18, 'funny': 18, 'wise': 17, 'unforgettable': 17, 'flawless': 16, 'familiar': 16, 'exciting': 15, 'rose': 15, 'originally': 15, 'creative': 15, 'extraordinary': 15, 'honest': 15, 'adult': 14, 'rarely': 14, 'artistic': 14, 'complimentary': 14, 'excellently': 14, 'firstly': 14, 'cultural': 14, 'lovingly': 14, 'mainly': 14, 'colorful': 13, 'splendid': 13, ...
# Negative words frequency: Counter({'flat': 3336, 'little': 1158, 'small': 1089, 'few': 867, 'other': 801, 'cozy': 793, 'extremely': 700, 'center': 514, 'late': 389, 'long': 383, 'down': 321, 'expected': 263, 'spent': 232, 'toilet': 222, 'less': 204, 'due': 192, 'base': 184, 'unfortunately': 175, 'cold': 160, 'bad': 147, 'ill': 138, 'green': 137, 'single': 134, 'common': 123, 'difficult': 120, 'hard': 118, 'dirty': 101, 'half': 92, 'closed': 79, 'narrow': 75, 'slightly': 74, 'least': 73, 'thin': 72, 'expensive': 71, 'broken': 71, 'round': 70, 'uncomfortable': 70, 'trouble': 69, 'negative': 69, 'heavy': 66, 'disappointed': 64, 'previous': 63, 'dark': 57, 'missing': 57, 'careful': 48, 'tight': 43, 'poor': 42, 'minor': 42, 'dry': 41, 'usually': 38, 'behind': 37, 'slow': 37, 'everyday': 35, 'typical': 33, 'tired': 33, 'hidden': 33, 'wrong': 31, 'annoying': 31, 'dusty': 28, 'terrible': 28, 'inconvenient': 28, 'sad': 27, 'past': 27, 'average': 27, 'disappointing': 26, 'wet': 25, 'wide': 25, 'mean': 25, 'sorry': 24, 'black': 24, 'worst': 23, 'complaint': 23, 'unpleasant': 23, 'limited': 22, 'hardly': 21, 'thick': 21, 'game': 21, 'complex': 20, 'weak': 20, 'firm': 19, 'minimal': 19, 'slight': 19, 'impossible': 19, 'usual': 19, 'seriously': 18, 'unable': 18, 'messy': 18, 'weird': 18, 'approximately': 16, 'odd': 16, 'carefully': 16, 'sadly': 16, 'empty': 15, 'disappointment': 15, 'poorly': 15, 'disturbing': 15, 'rude': 14, 'strange': 14, 'fluffy': 13, 'unfortunate': 13, 'frustrating': 12, 'complicated': 12, 'waste': 12, 'awkward': 12, 'serious': 11, 'afraid': 11, 'confusing': 11, 'tough': 11, 'delicate': 11, 'dangerous': 11, 'aged': 11, 'outdated': 11, 'previously': 11, 'secret': 11, 'crazy': 11, 'active': 10, 'worse': 10, 'chilly': 10, 'mere': 10, 'confused': 10, 'random': 10, 'ordinary': 9, 'tries': 9, 'distant': 9, 'scary': 9, 'awful': 8, 'unbelievably': 8, 'loose': 8, 'minus': 8, 'remote': 8, 'vacuum': 8, 'mess': 7, 'badly': 7, 'remotely': 7, 'unbelievable': 7, 'blind': 7, 'drunk': 7, 'sick': 7, 'disgusting': 7, 'heavily': 7, 'pity': 7, 'endless': 6, 'filthy': 6, 'forced': 6, 'plain': 6, 'failed': 6, 'curious': 6, 'typically': 6, 'slowly': 6, 'terribly': 5, 'complained': 5, 'claustrophobic': 5, 'humble': 5, 'lonely': 5, 'dull': 5, 'lazy': 5, 'horrible': 5, 'nasty': 5, 'rough': 5, 'exhausted': 5, 'dead': 4, 'harder': 4, 'extreme': 4, 'useless': 4, 'needless': 4, 'silly': 4, 'cutting': 4, 'dried': 4, 'roughly': 4, 'excuse': 4, 'disabled': 4, 'mediocre': 4, 'chicken': 4, 'drag': 4, 'miserable': 4, 'fail': 4, 'excessive': 3, 'creepy': 3, 'partially': 3, 'partial': 3, 'stiff': 3, 'shocked': 3, 'jammed': 3, 'shy': 3, 'insane': 3, 'passionate': 3, 'crying': 3, 'alas': 3, 'casual': 3, 'unlikely': 3, 'disliked': 3, 'regrets': 3, 'unnecessary': 3, 'wary': 3, 'absence': 3, 'ridiculously': 3, 'rank': 2, 'bland': 2, 'faint': 2, 'brutal': 2, 'blasted': 2, 'crap': 2, 'fanatic': 2, 'foreign': 2, 'unpredictable': 2, 'commonly': 2, 'secondary': 2, 'firmly': 2, 'slick': 2, 'desperately': 2, 'depressing': 2, 'shocking': 2, 'tame': 2, 'sour': 2, 'uncomfortably': 2, 'painful': 2, 'boring': 2, 'edgy': 2, 'frustrated': 2, 'hate': 2, 'characteristic': 2, 'angry': 2, 'muggy': 2, 'askew': 2, 'anger': 2, 'sinks': 2, 'stretched': 2, 'hated': 2, 'ugly': 2, 'artificial': 2, 'unknown': 2, 'mad': 2, 'insanely': 2, 'obsessed': 2, 'mentally': 2, 'shady': 2, 'guilty': 2, 'grim': 2, 'nostalgic': 1, 'imperceptible': 1, 'outrageously': 1, 'bitterly': 1, 'careless': 1, 'secretly': 1, 'false': 1, 'suffocating': 1, 'sec': 1, 'unnecessarily': 1, 'vulnerable': 1, 'deplorable': 1, 'irritating': 1, 'tightly': 1, 'minimally': 1, 'lately': 1, 'grey': 1, 'unaffected': 1, 'impossibly': 1, 'cow': 1, 'icy': 1, 'excessively': 1, 'wan': 1, 'anxious': 1, 'uneven': 1, 'frightening': 1, 'choppy': 1, 'disappointingly': 1, 'trapped': 1, 'widely': 1, 'rudely': 1, 'wonky': 1, 'harsh': 1, 'outrageous': 1, 'ridiculous': 1, 'chilling': 1, 'merely': 1, 'unappealing': 1, 'infuriating': 1, 'insultin ...
# Total word count: 890201
# Total positive words count: 111997

# %%
# 부정 단어의 총 수 계산
total_negative_words = sum(negative_words.values())
total_negative_words
# Out:
# 16337

# %%
# 긍정 단어와 부정 단어에서 명사만 추출
def extract_nouns(word_counter):
    nouns = Counter()
    for word in word_counter:
        word_blob = TextBlob(word)
        pos_tags = nltk.pos_tag([word])
        if pos_tags[0][1] in ['NN', 'NNS', 'NNP', 'NNPS']:  # 명사 태그
            nouns[word] += word_counter[word]
    return nouns

# %%
positive_nouns = extract_nouns(positive_words)
negative_nouns = extract_nouns(negative_words)

# %%
positive_nouns
# Out:
# Counter({'wonderful': 1395,
#          'peaceful': 354,
#          'clean': 5726,
#          'perfect': 2834,
#          'sure': 522,
#          'super': 1495,
#          'apt': 58,
#          'loud': 112,
#          'superb': 144,
#          'beautiful': 1502,
#          'cool': 226,
#          'excellent': 1513,
#          'thanks': 1178,
#          'bright': 292,
#          'absolute': 68,
#          'phenomenal': 20,
#          'warm': 952,
#          'calm': 162,
#          'quick': 712,
#          'kind': 1120,
#          'tidy': 510,
#          'worth': 195,
#          'stylish': 329,
#          'right': 923,
#          'fine': 246,
#          'welcome': 775,
#          'fast': 247,
#          'accurate': 120,
#          'delightful': 92,
#          'light': 358,
#          'pleasant': 697,
#          'awesome': 221,
#          'ideal': 379,
#          'brilliant': 219,
#          'fly': 4,
#          'offers': 95,
#          'cute': 313,
#          'sound': 63,
#          'respectful': 64,
#          'wise': 17,
#          'ok': 165,
#          'love': 426,
#          'decent': 77,
#          'secure': 120,
#          'top': 287,
#          'straight': 88,
#          'adequate': 46,
#          'bare': 9,
#          'fun': 131,
#          'enjoy': 263,
#          'sweet': 151,
#          'gentle': 26,
#          'colorful': 13,
#          'smooth': 170,
#          'unique': 91,
#          'rare': 29,
#          'action': 23,
#          'handy': 162,
#          'fair': 30,
#          'vibrant': 57,
#          'flawless': 16,
#          'fit': 59,
#          'glad': 51,
#          'cheap': 79,
#          'supportive': 26,
#          'genuine': 20,
#          'consistent': 24,
#          'frequent': 23,
#          'splendid': 13,
#          'iconic': 7,
#          'favorite': 43,
#          'faultless': 11,
#          'fitting': 6,
#          'adult': 14,
#          'cheery': 2,
#          'mod': 8,
#          'cheerful': 21,
#          'smile': 27,
#          'smart': 28,
#          'precise': 33,
#          'spectacular': 31,
#          'joy': 25,
#          'straightforward': 28,
#          'elegant': 30,
#          'exquisite': 12,
#          'priceless': 5,
#          'haha': 13,
#          'apparent': 4,
#          'concise': 4,
#          'wow': 27,
#          'complimentary': 14,
#          'okay': 66,
#          'magnificent': 34,
#          'seamless': 25,
#          'trendy': 33,
#          'crisp': 5,
#          'stellar': 8,
#          'confident': 4,
#          'obedient': 2,
#          'honest': 15,
#          'epic': 2,
#          'happiness': 5,
#          'evident': 3,
#          'success': 8,
#          'abundant': 7,
#          'pure': 7,
#          'primary': 3,
#          'worthy': 5,
#          'breathtaking': 5,
#          'wild': 5,
#          'classy': 9,
#          'deluxe': 1,
#          'intelligent': 10,
#          'relevant': 9,
#          'exact': 6,
#          'funny': 18,
#          'sober': 1,
#          'wealthy': 1,
#          'handsome': 2,
#          'pregnant': 5,
#          'appropriate': 9,
#          'worthwhile': 6,
#          'magic': 5,
#          'marked': 3,
#          'fortunate': 7,
#          'lol': 9,
#          'intense': 12,
#          'meaningful': 1,
#          'convincing': 1,
#          'prominent': 1,
#          'agile': 3,
#          'vivid': 1,
#          'balmy': 1,
#          'proud': 3,
#          'intimate': 4,
#          'promising': 2,
#          'resourceful': 1,
#          'lenient': 1,
#          'clever': 4,
#          'adamant': 1,
#          'wins': 1,
#          'lush': 5,
#          'concrete': 1,
#          'competent': 2,
#          'surprising': 5,
#          'truthful': 1,
#          'dim': 1,
#          'stainless': 1,
#          'vital': 1,
#          'laugh': 1,
#          'cheaply': 2,
#          'loyal': 1,
#          'win': 1,
#          'avid': 1,
#          'attendant': 2,
#          'bewitching': 1,
#          'surreal': 1,
#          'developed': 1,
#          'proves': 1,
#          'youngish': 1,
#          'distinct': 1})

# %%
negative_nouns
# Out:
# Counter({'base': 184,
#          'dirty': 101,
#          'spent': 232,
#          'sad': 27,
#          'center': 514,
#          'cozy': 793,
#          'dusty': 28,
#          'cold': 160,
#          'dark': 57,
#          'toilet': 222,
#          'firm': 19,
#          'complaint': 23,
#          'wet': 25,
#          'fluffy': 13,
#          'dry': 41,
#          'round': 70,
#          'mean': 25,
#          'ill': 138,
#          'rude': 14,
#          'nostalgic': 1,
#          'inconvenient': 28,
#          'creepy': 3,
#          'rank': 2,
#          'bland': 2,
#          'minimal': 19,
#          'mess': 7,
#          'past': 27,
#          'half': 92,
#          'sorry': 24,
#          'tries': 9,
#          'broken': 71,
#          'faint': 2,
#          'endless': 6,
#          'afraid': 11,
#          'narrow': 75,
#          'brutal': 2,
#          'filthy': 6,
#          'disappointment': 15,
#          'careful': 48,
#          'everyday': 35,
#          'thin': 72,
#          'crap': 2,
#          'messy': 18,
#          'odd': 16,
#          'minor': 42,
#          'trouble': 69,
#          'harder': 4,
#          'slight': 19,
#          'tight': 43,
#          'weird': 18,
#          'delicate': 11,
#          'stiff': 3,
#          'extreme': 4,
#          'plain': 6,
#          'hidden': 33,
#          'unfortunate': 13,
#          'claustrophobic': 5,
#          'useless': 4,
#          'distant': 9,
#          'jammed': 3,
#          'thick': 21,
#          'strange': 14,
#          'careless': 1,
#          'game': 21,
#          'slick': 2,
#          'waste': 12,
#          'blind': 7,
#          'sec': 1,
#          'dull': 5,
#          'drunk': 7,
#          'awful': 8,
#          'awkward': 12,
#          'needless': 4,
#          'shy': 3,
#          'insane': 3,
#          'tame': 2,
#          'secret': 11,
#          'lazy': 5,
#          'sick': 7,
#          'passionate': 3,
#          'excuse': 4,
#          'random': 10,
#          'sour': 2,
#          'minus': 8,
#          'mediocre': 4,
#          'grey': 1,
#          'painful': 2,
#          'boring': 2,
#          'remote': 8,
#          'cow': 1,
#          'icy': 1,
#          'crazy': 11,
#          'edgy': 2,
#          'wan': 1,
#          'chicken': 4,
#          'hate': 2,
#          'rough': 5,
#          'alas': 3,
#          'drag': 4,
#          'wonky': 1,
#          'harsh': 1,
#          'vacuum': 8,
#          'muggy': 2,
#          'askew': 2,
#          'anger': 2,
#          'sinks': 2,
#          'fail': 4,
#          'flashy': 1,
#          'disliked': 3,
#          'repetitive': 1,
#          'fake': 1,
#          'pity': 7,
#          'regrets': 3,
#          'mad': 2,
#          'parade': 1,
#          'absence': 3,
#          'shady': 2,
#          'duh': 1,
#          'monkey': 1,
#          'desperate': 1,
#          'grim': 2,
#          'swill': 1,
#          'abrupt': 1,
#          'vague': 1,
#          'grotesque': 1,
#          'stinks': 1,
#          'shallow': 1})

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 긍정 명사 워드클라우드 생성 및 시각화
positive_wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(positive_nouns)
plt.figure(figsize=(10, 5))
plt.imshow(positive_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Positive Nouns Word Cloud')
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.

# %%
# 부정 명사 워드클라우드 생성 및 시각화
negative_wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(negative_nouns)
plt.figure(figsize=(10, 5))
plt.imshow(negative_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Negative Nouns Word Cloud')
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.

# %% [markdown]
# TF-IDF 실행

# %%
# !pip install scikit-learn

# %%
import re

random_sample['리뷰'] = reviews.apply(lambda x: re.sub(r'[^a-zA-Z\s]+', '', x))
random_sample.head()
# Out:
#            숙소_id       리뷰날짜                                                 리뷰
# 475762  28599087 2022-03-20  We had a great trip the airbnb is great and ve...
# 266231  14378646 2022-11-18        Great Area great hosts and a very comfy bed
# 555       165336 2022-08-25  Had a wonderful stay at Nathans Loved the ecle...
# 495255  30536724 2023-12-02  CleanComfy and a Peaceful spaceThere are  room...
# 409887  22592225 2019-11-15  Yvonnes place was lovely and comfortable She w...

# %%
import re

def reviews_Pretreatment(texts):
    cleaned_texts = []
    for text in texts:
        cleaned_text = text.lower()  # 소문자로 변환
        cleaned_text = re.sub(r'[^a-zA-Z\s]+', '', cleaned_text)  # 특수문자 제거
        cleaned_texts.append(cleaned_text)
    return cleaned_texts


# 텍스트 전처리 수행
cleaned_reviews = reviews_Pretreatment(random_sample['리뷰'])

# 전처리된 텍스트로 '리뷰' 컬럼 업데이트
random_sample['리뷰'] = cleaned_reviews

# 결과 출력
random_sample.head()
# Out:
#            숙소_id       리뷰날짜  \
# 475762  28599087 2022-03-20
# 266231  14378646 2022-11-18
# 555       165336 2022-08-25
# 495255  30536724 2023-12-02
# 409887  22592225 2019-11-15
#
#                                                        리뷰  감성분류
# 475762  we had a great trip the airbnb is great and ve...     1
# 266231        great area great hosts and a very comfy bed     1
# 555     had a wonderful stay at nathans loved the ecle...     1
# 495255  cleancomfy and a peaceful spacethere are  room...     1
# 409887  yvonnes place was lovely and comfortable she w...     1

# %%
reviews = random_sample['리뷰']

# %% [markdown]
# 분석 모델 구축

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from textblob import TextBlob
import re

# tf-idf 벡터화
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')
tfidf = tfidf_vectorizer.fit_transform(reviews)

# %% [markdown]
# 토픽 모델링
#
# - distribution 값은 이 리뷰가 각 토픽에 속할 확률

# %%
# LDA 모델 생성 및 학습
lda_model = LatentDirichletAllocation(n_components=5, max_iter=5, learning_method='online', learning_offset=50., random_state=0)
lda_model.fit(tfidf)

# 리뷰별 토픽 분포 예측
topic_distribution = lda_model.transform(tfidf)

# 각 리뷰의 토픽 분포 확인
for i, review in enumerate(reviews[:10]):  # 첫 10개의 리뷰만 출력
    print(f"Review {i+1}:")
    print(review)
    print(f"Topic Distribution: {topic_distribution[i]}")
    print()
# Out:
# Review 1:
# we had a great trip the airbnb is great and very well located
# Topic Distribution: [0.06687063 0.0669043  0.06726565 0.06687033 0.73208908]
#
# Review 2:
# great area great hosts and a very comfy bed
# Topic Distribution: [0.06208429 0.06211014 0.06261544 0.06208407 0.75110606]
#
# Review 3:
# had a wonderful stay at nathans loved the eclectic decor and prime location in notting hill just steps from the tube communication was great and he was able to personally check me in and walk me through everything in the house plus he left detailed instructions everything worked great and i had a lovely and comfortable base for my time in london would definitely stay here again
# Topic Distribution: [0.03205742 0.0851387  0.03296659 0.03205377 0.81778351]
#
# Review 4:
# cleancomfy and a peaceful spacethere are  rooms in the house and everything was peaceful i felt like i was the only one there there are  showers and  bathrooms so you are hardly out of luck when you need themkitchen is clean and cupboards and refrigerator shelves partitioned and labelled for each rooms storagethis is the standard all shared accommodations should aspire to bethanks ben
# Topic Distribution: [0.03909901 0.15125991 0.50299313 0.0390955  0.26755245]
#
# Review 5:
# yvonnes place was lovely and comfortable she was a great host and the location was perfect for seeing a gig at alexandra palace
# Topic Distribution: [0.04963694 0.04963858 0.04964266 0.04977799 0.80130382]
#
# Review 6:
# lovely flat very close to several tube stations and restaurants fantastic host very communicative the codeenabled door was very tricky to manage
# Topic Distribution: [0.04713125 0.04713032 0.32380572 0.04712935 0.53480335]
#
# Review 7:
# the room is very close from the station very convenient
# Topic Distribution: [0.06712047 0.0671204  0.06743221 0.0671203  0.73120662]
#
# Review 8:
# everything was as advertised and worked out perfectly for our london plans it cant be emphasized enough how central and great this location is james was also great to work with on check inout
# Topic Distribution: [0.04660664 0.046613   0.04737933 0.14541664 0.7139844 ]
#
# Review 9:
# viktor have an amazing flat so welllocated comfy and clean my friend and i enjoyed so well our vacation we could barely notice the host but he was there as soon as when we needed him responding quickly on the phone  we totally recommend this place if you want to travel in london well be back for sure
# Topic Distribution: [0.09539249 0.0358373  0.15047822 0.03583581 0.68245618]
#
# Review 10:
# zhuoli was a wonderful host we arrived in london at a different airbnb where we ran into many troubles thankfully airbnb was super helpful and helping us relocate  zhuoli was also amazing during this very last minute change it took us about  hrs from the time we made the change to the time we were able to enter the new apt  zhuoli and the apt certainly meet the criteria for super host  my only comments  which dont change my five star rating include be mindful that the area of this apartment is amazing but with that comes very loud noisepeople outside especially later in the weekweekend  you have three bars near by  second we really had difficulty with figuring out the heat so wish that was a bit easier to navigate  otherwise the beds were great the heated bathroom floors were a wonderful addition and the ease of check incheck out was great
# Topic Distribution: [0.02512535 0.05204681 0.5194624  0.04416557 0.35919988]

# %%
# 각 토픽에 해당하는 단어 추출
def get_top_words(model, feature_names, n_top_words):
    top_words_dict = {}
    for topic_idx, topic in enumerate(model.components_):
        top_words = [feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]
        top_words_dict[f"Topic {topic_idx}"] = top_words
    return top_words_dict

n_top_words = 10
feature_names = tfidf_vectorizer.get_feature_names_out()
top_words = get_top_words(lda_model, feature_names, n_top_words)

# 각 토픽의 상위 단어 출력
for topic, words in top_words.items():
    print(f"{topic}: {', '.join(words)}")
# Out:
# Topic 0: discreet, justin, finish, jess, conference, helena, cheaper, boris, monica, vanessas
# Topic 1: value, money, mary, setting, apt, defo, accurately, sylvan, sadaf, hilda
# Topic 2: good, bit, room, bathroom, small, didnt, kitchen, shower, noise, floor
# Topic 3: perfect, max, anna, billie, sally, excel, hassle, extended, bush, reception
# Topic 4: great, stay, place, location, host, nice, clean, london, lovely, apartment

# %% [markdown]
# 감성 분석

# %% [markdown]
# <예시> <br>
#
# Review 1:
# We had a great trip, the airbnb is great and very well located <br>
# Topic Distribution: <br>
# [0.0668716   0.06687163  0.06861975
#  0.06687151  0.73076551] <br>
#
# <br>
#
# - 각 확률이 5개가 있다. (토픽이 5개가 나왔다는 의미)
# - 각 수치가 높을수록 해당 토픽에 속할 확률이 높다는 것
#
# - 5개중 가장 높은 수치가 0.7307 >> 토픽 5번에 속할 확률이 높다는 뜻

# %%
from textblob import TextBlob
import re

def sentiment_analysis(texts):
    sentiment_labels = []

    for text in texts:
        cleaned_text = text.lower() # 소문자로
        cleaned_text = re.sub(r'[^a-zA-Z\s]+', '', cleaned_text) # 특수문자 제거

        #감성분석
        blob = TextBlob(cleaned_text)
        sentiment = blob.sentiment

        # 감성 분석 결과를 1(긍정) 또는 0(부정)으로 저장
        if sentiment.polarity > 0:
            sentiment_labels.append(1)
        else:
            sentiment_labels.append(0)

    return sentiment_labels

texts = random_sample['리뷰']

# 함수 사용 예시
sentiment_labels = sentiment_analysis(texts)
random_sample['감성분류'] = sentiment_labels

# %%
random_sample['감성분류'].value_counts()
# Out:
# 감성분류
# 1    19426
# 0      574
# Name: count, dtype: int64
